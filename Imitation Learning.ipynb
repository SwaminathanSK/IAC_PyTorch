# %% [markdown]
# # Imitation Learning with Neural Network Policies
# In this notebook, you will implement the supervised losses for behavior cloning and use it to train policies for locomotion tasks.

# %%
#@title imports
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import torch

import deeprl.infrastructure.pytorch_util as ptu

from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import BC_Trainer
from deeprl.agents.bc_agent import BCAgent
from deeprl.policies.loaded_gaussian_policy import LoadedGaussianPolicy
from deeprl.policies.MLP_policy import MLPPolicySL

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
bc_base_args_dict = dict(
    expert_policy_file = 'deeprl/policies/experts/Hopper.pkl', #@param
    expert_data = 'deeprl/expert_data/expert_data_Hopper-v2.pkl', #@param
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_bc', #@param
    do_dagger = True, #@param {type: "boolean"}
    ep_len = 1000, #@param {type: "integer"}
    save_params = False, #@param {type: "boolean"}

    # Training
    num_agent_train_steps_per_iter = 1000, #@param {type: "integer"})
    n_iter = 1, #@param {type: "integer"})

    # batches & buffers
    batch_size = 10000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 100, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown network
    n_layers = 2, #@param {type: "integer"}
    size = 64, #@param {type: "integer"}
    learning_rate = 5e-3, #@param {type: "number"}

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# # Infrastructure
# **Policies**: We have provided implementations of simple neural network policies for your convenience. For discrete environments, the neural network takes in the current state and outputs the logits of the policy's action distribution at this state. The policy then outputs a categorical distribution using those logits. In environments with continuous action spaces, the network will output the mean of a diagonal Gaussian distribution, as well as having a separate single parameter for the log standard deviations of the Gaussian.
#
# Calling forward on the policy will output a torch distribution object, so look at the documentation at https://pytorch.org/docs/stable/distributions.html.
# Look at <code>policies/MLP_policy</code> to make sure you understand the implementation.
#
# **RL Training Loop**: The reinforcement learning training loop, which alternates between gathering samples from the environment and updating the policy (and other learned functions) can be found in <code>infrastructure/rl_trainer.py</code>. While you won't need to understand this for the basic behavior cloning part (as you only use a fixed set of expert data), you should read through and understand the run_training_loop function before starting the Dagger implementation.

# %% [markdown]
# # Basic Behavior Cloning
# The first part of the assignment will be a familiar exercise in supervised learning. Given a dataset of expert trajectories, we will simply train our policy to imitate the expert via maximum likelihood. Fill out the update method in the MLPPolicySL class in <code>policies/MLP_policy.py</code>.

# %%
### Basic test for correctness of loss and gradients
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicySL(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))

first_weight_before = np.array(ptu.to_numpy(next(policy.mean_net.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts)['Training Loss']

print(loss)
expected_loss = 2.628419
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.mean_net.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 0.04385546, -0.4614172,  -1.0613215 ],
                            [ 0.20986436, -1.2060736,  -1.0026767 ]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.00432252  0.30971584 -0.47518533]
#  [-0.4248946  -0.22236897  0.15482073]]
# 2.628419
# Loss Error 1.4757100142599302e-08 should be on the order of 1e-6 or lower
# Weight after update [[ 0.03953294 -0.15170135 -1.5365069 ]
#  [-0.21503024 -1.4284426  -0.84785604]]
# Change in weights [[ 0.04385546 -0.4614172  -1.0613215 ]
#  [ 0.20986436 -1.2060736  -1.0026767 ]]
# Weight Update Error 2.5347942329768053e-08 should be on the order of 1e-6 or lower

# %% [markdown]
# Having implemented our behavior cloning loss, we can now start training some policies to imitate the expert policies provided.
#
# Run the following cell to train policies with simple behavior cloning on the HalfCheetah environment.

# %%
bc_args = dict(bc_base_args_dict)

env_str = 'HalfCheetah'
bc_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
bc_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
bc_args['env_name'] = '{}-v2'.format(env_str)

# Delete all previous logs
remove_folder('logs/behavior_cloning/{}'.format(env_str))

for seed in range(3):
    print("Running behavior cloning experiment with seed", seed)
    bc_args['seed'] = seed
    bc_args['logdir'] = 'logs/behavior_cloning/{}/seed{}'.format(env_str, seed)
    bctrainer = BC_Trainer(bc_args)
    bctrainer.run_training_loop()
# Out:
# Clearing old results at logs/behavior_cloning/HalfCheetah
# Running behavior cloning experiment with seed 0
# ########################
# logging outputs to  logs/behavior_cloning/HalfCheetah/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
# Loading expert policy from... deeprl/policies/experts/HalfCheetah.pkl
# obs (1, 17) (1, 17)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3983.004638671875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3983.004638671875
# Eval_MinReturn : 3983.004638671875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 4205.7783203125
# Train_StdReturn : 83.038818359375
# Train_MaxReturn : 4288.81689453125
# Train_MinReturn : 4122.7392578125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.2378032207489014
# Training Loss : -7.846368312835693
# Initial_DataCollection_AverageReturn : 4205.7783203125
# Done logging...
#
#
# Running behavior cloning experiment with seed 1
# ########################
# logging outputs to  logs/behavior_cloning/HalfCheetah/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
# Loading expert policy from... deeprl/policies/experts/HalfCheetah.pkl
# obs (1, 17) (1, 17)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3673.63134765625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3673.63134765625
# Eval_MinReturn : 3673.63134765625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 4205.7783203125
# Train_StdReturn : 83.038818359375
# Train_MaxReturn : 4288.81689453125
# Train_MinReturn : 4122.7392578125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.2318434715270996
# Training Loss : -8.3496732711792
# Initial_DataCollection_AverageReturn : 4205.7783203125
# Done logging...
#
#
# Running behavior cloning experiment with seed 2
# ########################
# logging outputs to  logs/behavior_cloning/HalfCheetah/seed2
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# HalfCheetah-v2
# Loading expert policy from... deeprl/policies/experts/HalfCheetah.pkl
# obs (1, 17) (1, 17)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 4077.1728515625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 4077.1728515625
# Eval_MinReturn : 4077.1728515625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 4205.7783203125
# Train_StdReturn : 83.038818359375
# Train_MaxReturn : 4288.81689453125
# Train_MinReturn : 4122.7392578125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.3255999088287354
# Training Loss : -9.08505916595459
# Initial_DataCollection_AverageReturn : 4205.7783203125
# Done logging...

# %% [markdown]
# Visualize your results using Tensorboard. You should see that on HalfCheetah, the returns of your learned policies (Eval_AverageReturn) are fairly similar (thought a bit lower) to that of the expert (Initial_DataCollection_Average_Return).

# %%
### Visualize behavior cloning results on HalfCheetah
# %load_ext tensorboard
# %tensorboard --logdir logs/behavior_cloning/HalfCheetah
# Out:
#       <iframe id="tensorboard-frame-10cbde244906a2ab" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-10cbde244906a2ab");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Now run the following cell to train policies with simple behavior cloning on Hopper.

# %%
bc_args = dict(bc_base_args_dict)

env_str = 'Hopper'
bc_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
bc_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
bc_args['env_name'] = '{}-v2'.format(env_str)

# Delete all previous logs
remove_folder('logs/behavior_cloning/{}'.format(env_str))

for seed in range(3):
    print("Running behavior cloning experiment on Hopper with seed", seed)
    bc_args['seed'] = seed
    bc_args['logdir'] = 'logs/behavior_cloning/{}/seed{}'.format(env_str, seed)
    bctrainer = BC_Trainer(bc_args)
    bctrainer.run_training_loop()
# Out:
# Folder logs/behavior_cloning/Hopper does not exist yet. No old results to delete
# Running behavior cloning experiment on Hopper with seed 0
# ########################
# logging outputs to  logs/behavior_cloning/Hopper/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 818.9223022460938
# Eval_StdReturn : 247.2313690185547
# Eval_MaxReturn : 1057.8177490234375
# Eval_MinReturn : 438.45037841796875
# Eval_AverageEpLen : 262.25
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.7785699367523193
# Training Loss : -3.9606518745422363
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running behavior cloning experiment on Hopper with seed 1
# ########################
# logging outputs to  logs/behavior_cloning/Hopper/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1007.5135498046875
# Eval_StdReturn : 106.77484130859375
# Eval_MaxReturn : 1135.0887451171875
# Eval_MinReturn : 900.1021728515625
# Eval_AverageEpLen : 293.5
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.7944073677062988
# Training Loss : -3.558018207550049
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running behavior cloning experiment on Hopper with seed 2
# ########################
# logging outputs to  logs/behavior_cloning/Hopper/seed2
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1240.209228515625
# Eval_StdReturn : 146.07655334472656
# Eval_MaxReturn : 1446.787109375
# Eval_MinReturn : 1135.60693359375
# Eval_AverageEpLen : 359.3333333333333
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.7659475803375244
# Training Loss : -3.5959057807922363
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...

# %% [markdown]
# Visualize your results using Tensorboard. You should see that on Hopper, the returns of your learned policies (Eval_AverageReturn) are substantially lower than that of the expert (Initial_DataCollection_Average_Return), due to the distribution shift issues that arise when doing naive behavior cloning.

# %%
### Visualize behavior cloning results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/behavior_cloning/Hopper
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 278277), started 12:03:04 ago. (Use '!kill 278277' to kill it.)
#       <iframe id="tensorboard-frame-96324cd42c957bae" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-96324cd42c957bae");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Dataset Aggregation
# As discussed in lecture, behavior cloning can suffer from distribution shift, as a small mismatch between the learned and expert policy can take the learned policy to new states that were unseen during training, on which the learned policy hasn't been trained. In Dagger, we will address this issue iteratively, where we use our expert policy to provide labels for the new states we encounter with our learned policy, and then retrain our policy on these newly labeled states.
#
# Implement the <code>do_relabel_with_expert</code> function in <code>infrastructure/rl_trainer.py</code>. The errors in the expert actions should be on the order of 1e-6 or less.

# %%
### Test do relabel function
bc_args = dict(bc_base_args_dict)

env_str = 'Hopper'
bc_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
bc_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
bc_args['env_name'] = '{}-v2'.format(env_str)
bctrainer = BC_Trainer(bc_args)

np.random.seed(0)
T = 2
ob_dim = 11
ac_dim = 3

paths = []
for i in range(3):
    obs = np.random.normal(size=(T, ob_dim))
    acs = np.random.normal(size=(T, ac_dim))
    paths.append(dict(observation=obs,
                      action=acs))
    
rl_trainer = bctrainer.rl_trainer
relabeled_paths = rl_trainer.do_relabel_with_expert(bctrainer.loaded_expert_policy, paths)

expert_actions = np.array([[[-1.7814021, -0.11137983,  1.763353  ],
                            [-2.589222,   -5.463195,    2.4301376 ]],
                           [[-2.8287444, -5.298558,   3.0320463],
                            [ 3.9611065,  2.626403,  -2.8639293]],
                           [[-0.3055225,  -0.9865407,   0.80830705],
                            [ 2.8788857,   3.5550566,  -0.92875874]]])

for i, (path, relabeled_path) in enumerate(zip(paths, relabeled_paths)):
    assert np.all(path['observation'] == relabeled_path['observation'])
    print("Path {} expert action error".format(i), rel_error(expert_actions[i], relabeled_path['action']))
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
# Relabelling collected observations with labels from an expert policy...
# Path 0 expert action error 1.399300851855153e-08
# Path 1 expert action error 2.2191740840943456e-08
# Path 2 expert action error 1.2587788480400697e-08

# %% [markdown]
# We can run Dagger on the Hopper env again.

# %%
dagger_args = dict(bc_base_args_dict)

dagger_args['do_dagger'] = True
dagger_args['n_iter'] = 10

env_str = 'Hopper'
dagger_args['expert_policy_file'] = 'deeprl/policies/experts/{}.pkl'.format(env_str)
dagger_args['expert_data'] = 'deeprl/expert_data/expert_data_{}-v2.pkl'.format(env_str)
dagger_args['env_name'] = '{}-v2'.format(env_str)

# %%
# Delete all previous logs
remove_folder('logs/dagger/{}'.format(env_str))

for seed in range(3):
    print("Running Dagger experiment with seed", seed)
    dagger_args['seed'] = seed
    dagger_args['logdir'] = 'logs/dagger/{}/seed{}'.format(env_str, seed)
    bctrainer = BC_Trainer(dagger_args)
    bctrainer.run_training_loop()
# Out:
# Clearing old results at logs/dagger/Hopper
# Running Dagger experiment with seed 0
# ########################
# logging outputs to  logs/dagger/Hopper/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 818.9223022460938
# Eval_StdReturn : 247.2313690185547
# Eval_MaxReturn : 1057.8177490234375
# Eval_MinReturn : 438.45037841796875
# Eval_AverageEpLen : 262.25
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.3165545463562012
# Training Loss : -3.9606518745422363
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10423 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1835.6705322265625
# Eval_StdReturn : 425.8375244140625
# Eval_MaxReturn : 2252.198486328125
# Eval_MinReturn : 1250.730712890625
# Eval_AverageEpLen : 489.6666666666667
# Train_AverageReturn : 876.8661499023438
# Train_StdReturn : 378.4655456542969
# Train_MaxReturn : 1815.9554443359375
# Train_MinReturn : 410.14898681640625
# Train_AverageEpLen : 274.2894736842105
# Train_EnvstepsSoFar : 10423
# TimeSinceStart : 6.208587408065796
# Training Loss : -1.913375735282898
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10200 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3757.16455078125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3757.16455078125
# Eval_MinReturn : 3757.16455078125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 2701.688232421875
# Train_StdReturn : 967.6780395507812
# Train_MaxReturn : 3704.9560546875
# Train_MinReturn : 1277.8297119140625
# Train_AverageEpLen : 728.5714285714286
# Train_EnvstepsSoFar : 20623
# TimeSinceStart : 10.974305868148804
# Training Loss : -2.2740867137908936
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10898 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3766.778564453125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3766.778564453125
# Eval_MinReturn : 3766.778564453125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3414.751708984375
# Train_StdReturn : 758.2359008789062
# Train_MaxReturn : 3803.487060546875
# Train_MinReturn : 1498.798095703125
# Train_AverageEpLen : 908.1666666666666
# Train_EnvstepsSoFar : 31521
# TimeSinceStart : 16.053476095199585
# Training Loss : -1.7754616737365723
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3674.289306640625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3674.289306640625
# Eval_MinReturn : 3674.289306640625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3751.67724609375
# Train_StdReturn : 13.992714881896973
# Train_MaxReturn : 3769.416748046875
# Train_MinReturn : 3718.384765625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 41521
# TimeSinceStart : 21.021453619003296
# Training Loss : -1.5700677633285522
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3625.068359375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3625.068359375
# Eval_MinReturn : 3625.068359375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3650.95556640625
# Train_StdReturn : 15.673233032226562
# Train_MaxReturn : 3674.80419921875
# Train_MinReturn : 3628.35498046875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 51521
# TimeSinceStart : 26.067118883132935
# Training Loss : -2.440584897994995
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3782.979248046875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3782.979248046875
# Eval_MinReturn : 3782.979248046875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3641.138671875
# Train_StdReturn : 36.21141815185547
# Train_MaxReturn : 3700.118896484375
# Train_MinReturn : 3558.11962890625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 61521
# TimeSinceStart : 31.159788370132446
# Training Loss : -3.683025598526001
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3769.85595703125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3769.85595703125
# Eval_MinReturn : 3769.85595703125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3779.660888671875
# Train_StdReturn : 7.414803981781006
# Train_MaxReturn : 3789.062255859375
# Train_MinReturn : 3762.990234375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 71521
# TimeSinceStart : 36.5296196937561
# Training Loss : -4.113703727722168
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3770.494384765625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3770.494384765625
# Eval_MinReturn : 3770.494384765625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3770.22216796875
# Train_StdReturn : 5.032541275024414
# Train_MaxReturn : 3775.927490234375
# Train_MinReturn : 3760.939697265625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 81521
# TimeSinceStart : 41.93962597846985
# Training Loss : -4.366313457489014
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3763.9296875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3763.9296875
# Eval_MinReturn : 3763.9296875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3772.38330078125
# Train_StdReturn : 4.040258407592773
# Train_MaxReturn : 3778.48681640625
# Train_MinReturn : 3765.566650390625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 91521
# TimeSinceStart : 47.54043698310852
# Training Loss : -4.749293327331543
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running Dagger experiment with seed 1
# ########################
# logging outputs to  logs/dagger/Hopper/seed1
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1007.5135498046875
# Eval_StdReturn : 106.77484130859375
# Eval_MaxReturn : 1135.0887451171875
# Eval_MinReturn : 900.1021728515625
# Eval_AverageEpLen : 293.5
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.3590786457061768
# Training Loss : -3.558018207550049
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 2019.17724609375
# Eval_StdReturn : 972.305908203125
# Eval_MaxReturn : 2991.483154296875
# Eval_MinReturn : 1046.871337890625
# Eval_AverageEpLen : 582.5
# Train_AverageReturn : 1080.3692626953125
# Train_StdReturn : 309.01422119140625
# Train_MaxReturn : 2038.9931640625
# Train_MinReturn : 369.8787841796875
# Train_AverageEpLen : 313.65625
# Train_EnvstepsSoFar : 10037
# TimeSinceStart : 6.147677421569824
# Training Loss : -2.1197452545166016
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10282 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3099.7763671875
# Eval_StdReturn : 181.22705078125
# Eval_MaxReturn : 3281.00341796875
# Eval_MinReturn : 2918.54931640625
# Eval_AverageEpLen : 806.0
# Train_AverageReturn : 2169.8896484375
# Train_StdReturn : 690.5663452148438
# Train_MaxReturn : 3596.423828125
# Train_MinReturn : 1246.53955078125
# Train_AverageEpLen : 642.625
# Train_EnvstepsSoFar : 20319
# TimeSinceStart : 11.17348599433899
# Training Loss : -2.0619826316833496
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10497 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3723.986572265625
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3723.986572265625
# Eval_MinReturn : 3723.986572265625
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 2838.10546875
# Train_StdReturn : 798.5438842773438
# Train_MaxReturn : 3802.20703125
# Train_MinReturn : 1571.8150634765625
# Train_AverageEpLen : 749.7857142857143
# Train_EnvstepsSoFar : 30816
# TimeSinceStart : 16.267369031906128
# Training Loss : -2.625760555267334
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3772.816162109375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3772.816162109375
# Eval_MinReturn : 3772.816162109375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3698.758544921875
# Train_StdReturn : 28.50035858154297
# Train_MaxReturn : 3762.97021484375
# Train_MinReturn : 3666.51123046875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 40816
# TimeSinceStart : 21.247855186462402
# Training Loss : -2.7864580154418945
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3631.43359375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3631.43359375
# Eval_MinReturn : 3631.43359375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3720.64501953125
# Train_StdReturn : 36.43669509887695
# Train_MaxReturn : 3781.698486328125
# Train_MinReturn : 3670.0439453125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 50816
# TimeSinceStart : 26.260254383087158
# Training Loss : -3.2194771766662598
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3623.5205078125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3623.5205078125
# Eval_MinReturn : 3623.5205078125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3636.594970703125
# Train_StdReturn : 26.18071937561035
# Train_MaxReturn : 3680.64306640625
# Train_MinReturn : 3594.278076171875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 60816
# TimeSinceStart : 31.41665816307068
# Training Loss : -3.26962947845459
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3765.715576171875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3765.715576171875
# Eval_MinReturn : 3765.715576171875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3610.591064453125
# Train_StdReturn : 29.27410125732422
# Train_MaxReturn : 3659.90625
# Train_MinReturn : 3561.70068359375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 70816
# TimeSinceStart : 36.78067922592163
# Training Loss : -4.170958995819092
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3771.24658203125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3771.24658203125
# Eval_MinReturn : 3771.24658203125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3775.961669921875
# Train_StdReturn : 22.983604431152344
# Train_MaxReturn : 3795.2939453125
# Train_MinReturn : 3712.0625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 80816
# TimeSinceStart : 42.12467694282532
# Training Loss : -3.91715931892395
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3791.702392578125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3791.702392578125
# Eval_MinReturn : 3791.702392578125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3774.73974609375
# Train_StdReturn : 2.9227399826049805
# Train_MaxReturn : 3778.53759765625
# Train_MinReturn : 3768.61083984375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 90816
# TimeSinceStart : 47.500277042388916
# Training Loss : -4.2020769119262695
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
# Running Dagger experiment with seed 2
# ########################
# logging outputs to  logs/dagger/Hopper/seed2
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
# Loading expert policy from... deeprl/policies/experts/Hopper.pkl
# obs (1, 11) (1, 11)
# Done restoring expert policy...
#
#
# ********** Iteration 0 ************
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1240.209228515625
# Eval_StdReturn : 146.07655334472656
# Eval_MaxReturn : 1446.787109375
# Eval_MinReturn : 1135.60693359375
# Eval_AverageEpLen : 359.3333333333333
# Train_AverageReturn : 3772.67041015625
# Train_StdReturn : 1.9483642578125
# Train_MaxReturn : 3774.61865234375
# Train_MinReturn : 3770.721923828125
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 0
# TimeSinceStart : 1.2816486358642578
# Training Loss : -3.5959057807922363
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10080 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 1264.78076171875
# Eval_StdReturn : 488.33642578125
# Eval_MaxReturn : 2092.458251953125
# Eval_MinReturn : 835.315185546875
# Eval_AverageEpLen : 350.25
# Train_AverageReturn : 1040.7540283203125
# Train_StdReturn : 194.30662536621094
# Train_MaxReturn : 1326.931640625
# Train_MinReturn : 432.27471923828125
# Train_AverageEpLen : 315.0
# Train_EnvstepsSoFar : 10080
# TimeSinceStart : 5.996697187423706
# Training Loss : -2.3866770267486572
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3702.912841796875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3702.912841796875
# Eval_MinReturn : 3702.912841796875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 1019.4214477539062
# Train_StdReturn : 91.10919952392578
# Train_MaxReturn : 1390.4609375
# Train_MinReturn : 845.036376953125
# Train_AverageEpLen : 287.62857142857143
# Train_EnvstepsSoFar : 20147
# TimeSinceStart : 10.686020612716675
# Training Loss : -2.23909854888916
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3765.04296875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3765.04296875
# Eval_MinReturn : 3765.04296875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3658.223876953125
# Train_StdReturn : 28.177600860595703
# Train_MaxReturn : 3691.3046875
# Train_MinReturn : 3611.4462890625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 30147
# TimeSinceStart : 15.429461002349854
# Training Loss : -2.506903648376465
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3795.285888671875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3795.285888671875
# Eval_MinReturn : 3795.285888671875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3709.66357421875
# Train_StdReturn : 38.62483215332031
# Train_MaxReturn : 3757.603515625
# Train_MinReturn : 3638.74560546875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 40147
# TimeSinceStart : 20.348981857299805
# Training Loss : -2.4072136878967285
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10212 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3763.34375
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3763.34375
# Eval_MinReturn : 3763.34375
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3518.71630859375
# Train_StdReturn : 492.9730529785156
# Train_MaxReturn : 3792.63232421875
# Train_MinReturn : 2214.06689453125
# Train_AverageEpLen : 928.3636363636364
# Train_EnvstepsSoFar : 50359
# TimeSinceStart : 25.470026969909668
# Training Loss : -3.7240469455718994
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3771.04248046875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3771.04248046875
# Eval_MinReturn : 3771.04248046875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3773.016357421875
# Train_StdReturn : 7.751763343811035
# Train_MaxReturn : 3792.61376953125
# Train_MinReturn : 3765.2587890625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 60359
# TimeSinceStart : 30.791000843048096
# Training Loss : -4.190187931060791
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3783.420654296875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3783.420654296875
# Eval_MinReturn : 3783.420654296875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3767.903564453125
# Train_StdReturn : 2.4840683937072754
# Train_MaxReturn : 3770.74462890625
# Train_MinReturn : 3763.937255859375
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 70359
# TimeSinceStart : 36.196802854537964
# Training Loss : -4.047860622406006
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3775.17578125
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3775.17578125
# Eval_MinReturn : 3775.17578125
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3779.98046875
# Train_StdReturn : 6.642668724060059
# Train_MaxReturn : 3792.138671875
# Train_MinReturn : 3770.2978515625
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 80359
# TimeSinceStart : 41.74654722213745
# Training Loss : -4.4026055335998535
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Relabelling collected observations with labels from an expert policy...
#
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 3777.03076171875
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 3777.03076171875
# Eval_MinReturn : 3777.03076171875
# Eval_AverageEpLen : 1000.0
# Train_AverageReturn : 3776.830810546875
# Train_StdReturn : 4.718177795410156
# Train_MaxReturn : 3782.46728515625
# Train_MinReturn : 3764.838623046875
# Train_AverageEpLen : 1000.0
# Train_EnvstepsSoFar : 90359
# TimeSinceStart : 47.273250102996826
# Training Loss : -4.437106609344482
# Initial_DataCollection_AverageReturn : 3772.67041015625
# Done logging...

# %% [markdown]
# Visualizing the Dagger results on Hopper, we see that Dagger is able to recover the performance of the expert policy after a few iterations of online interaction and expert relabeling.

# %%
### Visualize Dagger results on Hopper
# !kill 278277
# %reload_ext tensorboard
# %tensorboard --logdir logs/dagger/Hopper
# Out:
#       <iframe id="tensorboard-frame-32c01dda7da68b44" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-32c01dda7da68b44");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
