# %% [markdown]
# # Policy Gradients
# The goal in policy gradient algorithms is to maximize the expected returns of a policy $\pi_\theta$ with parameters $\theta$. Letting $\tau=((s_0, a_0, r_0), \ldots, (s_T, a_T, r_T) )$ denote a trajectory and $R(\tau)$ the return of $\tau$, this objective can be written as
# $$\max_{\theta} \mathbb E_{\tau \sim \pi_{\theta}}[R(\tau)].$$
#
# Using the REINFORCE trick, we can compute the policy gradient (the gradient of expected policy returns) as
# $$\sum_{t=0}^T \mathbb E_{s_t, a_t \sim \pi(\tau)} \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
#
# We can then estimate this with a very simple scheme.
# We first sample a trajectory $\tau = ((s_t, a_t, r_t))_{t=0}^\infty$ from our current policy, compute the discounted return of the trajectory as $R$, then take a stochastic estimate of the policy gradient as
#
# $$\sum_{t=0}^T \mathbb \nabla_{\theta} \log \pi_{\theta}(a_t \vert s_t) R(\tau).$$
# We can then repeat sample more trajectories to average the estimate over multiple samples.
# In practice, we will often use _discounted_ returns $\tilde R(\tau) = \sum_{t=0}^T \gamma^t r_t$ where $\gamma$ is the discount factor and our policy gradient estimate will simply replace the undiscounted returns with $\tilde R(\tau)$.

# %%
#@title imports
# As usual, a bit of setup
import os
import shutil
import time
import numpy as np
import gym
import torch

import deeprl.infrastructure.pytorch_util as ptu

from deeprl.infrastructure.rl_trainer import RL_Trainer
from deeprl.infrastructure.trainers import PG_Trainer
from deeprl.infrastructure.trainers import BC_Trainer

from deeprl.agents.pg_agent import PGAgent
from deeprl.policies.MLP_policy import MLPPolicyPG

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

def remove_folder(path):
    # check if folder exists
    if os.path.exists(path): 
        print("Clearing old results at {}".format(path))
        # remove if exists
        shutil.rmtree(path)
    else:
        print("Folder {} does not exist yet. No old results to delete".format(path))

# %%
pg_base_args_dict = dict(
    env_name = 'Hopper-v2', #@param ['Ant-v2', 'Humanoid-v2', 'Walker2d-v2', 'HalfCheetah-v2', 'Hopper-v2']
    exp_name = 'test_pg', #@param
    save_params = False, #@param {type: "boolean"}
    
    ep_len = 200, #@param {type: "integer"}
    discount = 0.95, #@param {type: "number"}

    reward_to_go = True, #@param {type: "boolean"}
    nn_baseline = False, #@param {type: "boolean"}
    dont_standardize_advantages = True, #@param {type: "boolean"}

    # Training
    num_agent_train_steps_per_iter = 1, #@param {type: "integer"})
    n_iter = 100, #@param {type: "integer"})

    # batches & buffers
    batch_size = 1000, #@param {type: "integer"})
    eval_batch_size = 1000, #@param {type: "integer"}
    train_batch_size = 1000, #@param {type: "integer"}
    max_replay_buffer_size = 1000000, #@param {type: "integer"}

    #@markdown network
    n_layers = 2, #@param {type: "integer"}
    size = 64, #@param {type: "integer"}
    learning_rate = 5e-3, #@param {type: "number"}

    #@markdown logging
    video_log_freq = -1, #@param {type: "integer"}
    scalar_log_freq = 1, #@param {type: "integer"}

    #@markdown gpu & run-time settings
    no_gpu = False, #@param {type: "boolean"}
    which_gpu = 0, #@param {type: "integer"}
    seed = 2, #@param {type: "integer"}
    logdir = 'test',
)

# %% [markdown]
# ## Implementing policy gradients
# We will first compute a very naive policy gradient calculation by taking the whole discounted return of a trajectory. Fill out the method <code>_discounted_return</code> in <code>pg_agent.py</code>. Your error should be 1e-6 or lower.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_returns = pgagent._discounted_return(rewards)

expected_return = 6.49674307
return_error = rel_error(discounted_returns, expected_return)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Error in return estimate is 1.3988385848769778e-10

# %% [markdown]
# Next, we'll consider a return estimate with lower variance by taking the discounted reward-to-go at each timestep instead of the entire discounted return. More precisely, instead of taking $\sum_{t'=0}^T \gamma^{t'} r_{t'}$ as the return estimate for all timesteps $t$, we will instead use $\sum_{t'=t}^T \gamma^{t' - t} r_{t'}$ for the return estimate at timestep $t$. Fill out the method <code>_discounted_cumsum</code> in <code>pg_agent.py</code>.   Your error should be 1e-6 or lower.

# %%
### Test reward to go computations
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

T = 10
np.random.seed(0)
rewards = np.random.normal(size=T)
discounted_cumsum = pgagent._discounted_cumsum(rewards)
expected_cumsum = np.array([6.49674307, 4.98177971, 4.82276053, 4.04633952, 1.90046981, 0.03464402,
 1.06518095, 0.12115003, 0.28684973, 0.4105985])

return_error = rel_error(discounted_cumsum, expected_cumsum)
print("Error in return estimate is", return_error)
# Out:
# ########################
# logging outputs to  test
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
# Error in return estimate is 1.0143652473004211e-08

# %% [markdown]
# Finally, we'll use our return estimates to compute a policy gradient. Fill out the surrogate loss computation in the <code>update</code> method in MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
### Test policy gradient (check gradients match what we expect)
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))

first_weight_before = np.array(ptu.to_numpy(next(policy.mean_net.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs)['Training Loss']

print(loss)
expected_loss = -6142.9116
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.mean_net.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 1.035012, 1.0455959, 0.11085394],
                            [-1.1532364, -0.5915445, 0.557522]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")
# Out:
# Weight before update [[-0.00432252  0.30971584 -0.47518533]
#  [-0.4248946  -0.22236897  0.15482073]]
# -6142.9116
# Loss Error 1.7169178864173362e-09 should be on the order of 1e-6 or lower
# Weight after update [[ 1.0306895   1.3553118  -0.3643314 ]
#  [-1.578131   -0.81391346  0.71234274]]
# Change in weights [[ 1.035012    1.0455959   0.11085394]
#  [-1.1532364  -0.5915445   0.557522  ]]
# Weight Update Error 7.551436028905091e-09 should be on the order of 1e-6 or lower

# %% [markdown]
# We can compare the two return estimators on a simple environment and compare how well they do.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = False
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/CartPole/full_returns/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 29.285715103149414
# Eval_StdReturn : 16.32451629638672
# Eval_MaxReturn : 86.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 29.285714285714285
# Train_AverageReturn : 22.0
# Train_StdReturn : 10.642409324645996
# Train_MaxReturn : 51.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 22.0
# Train_EnvstepsSoFar : 1012
# TimeSinceStart : 0.24466753005981445
# Training Loss : 9.748507499694824
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 28.2500
# Eval_StdReturn : 13.697880744934082
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 12.0
# Eval_AverageEpLen : 28.25
# Train_AverageReturn : 23.627906799316406
# Train_StdReturn : 11.442522048950195
# Train_MaxReturn : 58.0
# Train_MinReturn : 13.0
# Train_AverageEpLen : 23.627906976744185
# Train_EnvstepsSoFar : 2028
# TimeSinceStart : 0.44460105895996094
# Training Loss : 9.987648010253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1079 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.027027130126953
# Eval_StdReturn : 13.28377628326416
# Eval_MaxReturn : 63.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 27.027027027027028
# Train_AverageReturn : 29.16216278076172
# Train_StdReturn : 17.249385833740234
# Train_MaxReturn : 98.0
# Train_MinReturn : 8.0
# Train_AverageEpLen : 29.16216216216216
# Train_EnvstepsSoFar : 3107
# TimeSinceStart : 0.6689403057098389
# Training Loss : 10.928592681884766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.84375
# Eval_StdReturn : 14.809433937072754
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 31.84375
# Train_AverageReturn : 29.41176414489746
# Train_StdReturn : 14.167314529418945
# Train_MaxReturn : 75.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 29.41176470588235
# Train_EnvstepsSoFar : 4107
# TimeSinceStart : 0.8635029792785645
# Training Loss : 10.722437858581543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1058 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.31999969482422
# Eval_StdReturn : 27.21575927734375
# Eval_MaxReturn : 125.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 40.32
# Train_AverageReturn : 32.06060791015625
# Train_StdReturn : 22.581756591796875
# Train_MaxReturn : 98.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 32.06060606060606
# Train_EnvstepsSoFar : 5165
# TimeSinceStart : 1.107076644897461
# Training Loss : 11.185359001159668
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1042 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.128204345703125
# Eval_StdReturn : 14.0277738571167
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 26.128205128205128
# Train_AverageReturn : 30.647058486938477
# Train_StdReturn : 16.591781616210938
# Train_MaxReturn : 84.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 30.647058823529413
# Train_EnvstepsSoFar : 6207
# TimeSinceStart : 1.4366438388824463
# Training Loss : 10.851187705993652
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 25.049999237060547
# Eval_StdReturn : 15.287168502807617
# Eval_MaxReturn : 84.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 25.05
# Train_AverageReturn : 24.095237731933594
# Train_StdReturn : 10.919204711914062
# Train_MaxReturn : 57.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 24.095238095238095
# Train_EnvstepsSoFar : 7219
# TimeSinceStart : 1.6779251098632812
# Training Loss : 9.761499404907227
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1050 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 21.84782600402832
# Eval_StdReturn : 7.703661918640137
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 21.847826086956523
# Train_AverageReturn : 24.418603897094727
# Train_StdReturn : 17.236024856567383
# Train_MaxReturn : 104.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.41860465116279
# Train_EnvstepsSoFar : 8269
# TimeSinceStart : 1.8631277084350586
# Training Loss : 9.838366508483887
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1060 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 20.219999313354492
# Eval_StdReturn : 9.61933422088623
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 20.22
# Train_AverageReturn : 20.384614944458008
# Train_StdReturn : 12.580745697021484
# Train_MaxReturn : 86.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 20.384615384615383
# Train_EnvstepsSoFar : 9329
# TimeSinceStart : 2.077860116958618
# Training Loss : 8.916958808898926
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.581396102905273
# Eval_StdReturn : 10.796710014343262
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 9.0
# Eval_AverageEpLen : 23.58139534883721
# Train_AverageReturn : 22.04347801208496
# Train_StdReturn : 10.46725082397461
# Train_MaxReturn : 57.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 22.043478260869566
# Train_EnvstepsSoFar : 10343
# TimeSinceStart : 2.270756244659424
# Training Loss : 9.301703453063965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 26.736841201782227
# Eval_StdReturn : 17.958555221557617
# Eval_MaxReturn : 88.0
# Eval_MinReturn : 10.0
# Eval_AverageEpLen : 26.736842105263158
# Train_AverageReturn : 19.921567916870117
# Train_StdReturn : 6.927759170532227
# Train_MaxReturn : 38.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 19.92156862745098
# Train_EnvstepsSoFar : 11359
# TimeSinceStart : 2.4700753688812256
# Training Loss : 8.595572471618652
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 23.744186401367188
# Eval_StdReturn : 9.298894882202148
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 23.74418604651163
# Train_AverageReturn : 22.44444465637207
# Train_StdReturn : 9.083698272705078
# Train_MaxReturn : 56.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 22.444444444444443
# Train_EnvstepsSoFar : 12369
# TimeSinceStart : 2.674050807952881
# Training Loss : 9.202675819396973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 24.9761905670166
# Eval_StdReturn : 15.09255313873291
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 24.976190476190474
# Train_AverageReturn : 24.452381134033203
# Train_StdReturn : 11.658232688903809
# Train_MaxReturn : 64.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 24.452380952380953
# Train_EnvstepsSoFar : 13396
# TimeSinceStart : 2.8855903148651123
# Training Loss : 9.670610427856445
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.176469802856445
# Eval_StdReturn : 17.550716400146484
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 31.176470588235293
# Train_AverageReturn : 28.714284896850586
# Train_StdReturn : 17.815837860107422
# Train_MaxReturn : 88.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 28.714285714285715
# Train_EnvstepsSoFar : 14401
# TimeSinceStart : 3.1061034202575684
# Training Loss : 10.350377082824707
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1011 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.19355010986328
# Eval_StdReturn : 15.567583084106445
# Eval_MaxReturn : 65.0
# Eval_MinReturn : 14.0
# Eval_AverageEpLen : 33.193548387096776
# Train_AverageReturn : 29.735294342041016
# Train_StdReturn : 15.810102462768555
# Train_MaxReturn : 92.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 29.735294117647058
# Train_EnvstepsSoFar : 15412
# TimeSinceStart : 3.2947425842285156
# Training Loss : 10.250404357910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.89655303955078
# Eval_StdReturn : 16.942794799804688
# Eval_MaxReturn : 72.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 35.89655172413793
# Train_AverageReturn : 39.57692337036133
# Train_StdReturn : 17.78973960876465
# Train_MaxReturn : 95.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 39.57692307692308
# Train_EnvstepsSoFar : 16441
# TimeSinceStart : 3.519197463989258
# Training Loss : 11.268746376037598
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1110 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 49.0000
# Eval_StdReturn : 26.56169891357422
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 49.0
# Train_AverageReturn : 44.400001525878906
# Train_StdReturn : 35.090736389160156
# Train_MaxReturn : 137.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 44.4
# Train_EnvstepsSoFar : 17551
# TimeSinceStart : 3.7918944358825684
# Training Loss : 11.600893020629883
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1001 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.52631759643555
# Eval_StdReturn : 36.80727767944336
# Eval_MaxReturn : 177.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 55.526315789473685
# Train_AverageReturn : 43.5217399597168
# Train_StdReturn : 23.8580379486084
# Train_MaxReturn : 138.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 43.52173913043478
# Train_EnvstepsSoFar : 18552
# TimeSinceStart : 3.9959940910339355
# Training Loss : 11.457797050476074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 47.272727966308594
# Eval_StdReturn : 21.0738582611084
# Eval_MaxReturn : 100.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 47.27272727272727
# Train_AverageReturn : 41.75
# Train_StdReturn : 22.666513442993164
# Train_MaxReturn : 123.0
# Train_MinReturn : 18.0
# Train_AverageEpLen : 41.75
# Train_EnvstepsSoFar : 19554
# TimeSinceStart : 4.17822003364563
# Training Loss : 11.096564292907715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1077 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.7931022644043
# Eval_StdReturn : 18.41921615600586
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 35.793103448275865
# Train_AverageReturn : 51.28571319580078
# Train_StdReturn : 33.38825225830078
# Train_MaxReturn : 133.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 51.285714285714285
# Train_EnvstepsSoFar : 20631
# TimeSinceStart : 4.451219081878662
# Training Loss : 11.529394149780273
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1015 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.04166793823242
# Eval_StdReturn : 14.76617431640625
# Eval_MaxReturn : 74.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 42.041666666666664
# Train_AverageReturn : 36.25
# Train_StdReturn : 13.083864212036133
# Train_MaxReturn : 65.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 36.25
# Train_EnvstepsSoFar : 21646
# TimeSinceStart : 4.666593551635742
# Training Loss : 10.678284645080566
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1042 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 35.89285659790039
# Eval_StdReturn : 16.303680419921875
# Eval_MaxReturn : 91.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 35.892857142857146
# Train_AverageReturn : 37.21428680419922
# Train_StdReturn : 14.069615364074707
# Train_MaxReturn : 78.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 37.214285714285715
# Train_EnvstepsSoFar : 22688
# TimeSinceStart : 4.845764398574829
# Training Loss : 10.772427558898926
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1019 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.599998474121094
# Eval_StdReturn : 25.285568237304688
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 40.6
# Train_AverageReturn : 36.39285659790039
# Train_StdReturn : 17.50783348083496
# Train_MaxReturn : 106.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 36.392857142857146
# Train_EnvstepsSoFar : 23707
# TimeSinceStart : 5.1011152267456055
# Training Loss : 10.389925003051758
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.66666793823242
# Eval_StdReturn : 19.400745391845703
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 41.666666666666664
# Train_AverageReturn : 35.89285659790039
# Train_StdReturn : 19.317533493041992
# Train_MaxReturn : 104.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 35.892857142857146
# Train_EnvstepsSoFar : 24712
# TimeSinceStart : 5.433088779449463
# Training Loss : 10.532183647155762
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 44.130435943603516
# Eval_StdReturn : 15.255232810974121
# Eval_MaxReturn : 71.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 44.130434782608695
# Train_AverageReturn : 37.33333206176758
# Train_StdReturn : 17.68657112121582
# Train_MaxReturn : 103.0
# Train_MinReturn : 11.0
# Train_AverageEpLen : 37.333333333333336
# Train_EnvstepsSoFar : 25720
# TimeSinceStart : 5.697429895401001
# Training Loss : 10.478879928588867
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.54166793823242
# Eval_StdReturn : 17.387685775756836
# Eval_MaxReturn : 83.0
# Eval_MinReturn : 15.0
# Eval_AverageEpLen : 43.541666666666664
# Train_AverageReturn : 51.849998474121094
# Train_StdReturn : 39.05288314819336
# Train_MaxReturn : 174.0
# Train_MinReturn : 14.0
# Train_AverageEpLen : 51.85
# Train_EnvstepsSoFar : 26757
# TimeSinceStart : 5.874728441238403
# Training Loss : 11.09473705291748
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.70833206176758
# Eval_StdReturn : 15.616442680358887
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 41.708333333333336
# Train_AverageReturn : 38.653846740722656
# Train_StdReturn : 17.946378707885742
# Train_MaxReturn : 107.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 38.65384615384615
# Train_EnvstepsSoFar : 27762
# TimeSinceStart : 6.0936808586120605
# Training Loss : 10.619898796081543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.040000915527344
# Eval_StdReturn : 17.512235641479492
# Eval_MaxReturn : 80.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 42.04
# Train_AverageReturn : 46.40909194946289
# Train_StdReturn : 22.266279220581055
# Train_MaxReturn : 106.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 46.40909090909091
# Train_EnvstepsSoFar : 28783
# TimeSinceStart : 6.31818962097168
# Training Loss : 11.114814758300781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1081 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.5217399597168
# Eval_StdReturn : 19.92566680908203
# Eval_MaxReturn : 99.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 45.52173913043478
# Train_AverageReturn : 54.04999923706055
# Train_StdReturn : 30.408016204833984
# Train_MaxReturn : 138.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 54.05
# Train_EnvstepsSoFar : 29864
# TimeSinceStart : 6.50287389755249
# Training Loss : 11.040983200073242
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.68421173095703
# Eval_StdReturn : 29.943897247314453
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 16.0
# Eval_AverageEpLen : 52.68421052631579
# Train_AverageReturn : 48.19047546386719
# Train_StdReturn : 15.734763145446777
# Train_MaxReturn : 86.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 48.19047619047619
# Train_EnvstepsSoFar : 30876
# TimeSinceStart : 6.764998197555542
# Training Loss : 10.9463529586792
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.5000
# Eval_StdReturn : 35.00892639160156
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 66.5
# Train_AverageReturn : 45.434783935546875
# Train_StdReturn : 16.314373016357422
# Train_MaxReturn : 79.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 45.43478260869565
# Train_EnvstepsSoFar : 31921
# TimeSinceStart : 6.940425157546997
# Training Loss : 10.755820274353027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 64.0625
# Eval_StdReturn : 37.327049255371094
# Eval_MaxReturn : 168.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 64.0625
# Train_AverageReturn : 59.29411697387695
# Train_StdReturn : 23.957719802856445
# Train_MaxReturn : 121.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 59.294117647058826
# Train_EnvstepsSoFar : 32929
# TimeSinceStart : 7.177006721496582
# Training Loss : 11.542814254760742
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 61.764705657958984
# Eval_StdReturn : 27.967479705810547
# Eval_MaxReturn : 141.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 61.76470588235294
# Train_AverageReturn : 55.83333206176758
# Train_StdReturn : 26.955209732055664
# Train_MaxReturn : 157.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 55.833333333333336
# Train_EnvstepsSoFar : 33934
# TimeSinceStart : 7.386434316635132
# Training Loss : 11.143712997436523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1122 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.5625
# Eval_StdReturn : 38.634456634521484
# Eval_MaxReturn : 172.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 65.5625
# Train_AverageReturn : 86.30769348144531
# Train_StdReturn : 38.31124496459961
# Train_MaxReturn : 154.0
# Train_MinReturn : 16.0
# Train_AverageEpLen : 86.3076923076923
# Train_EnvstepsSoFar : 35056
# TimeSinceStart : 7.570839881896973
# Training Loss : 11.609508514404297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1053 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.42857360839844
# Eval_StdReturn : 26.029420852661133
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 74.42857142857143
# Train_AverageReturn : 81.0
# Train_StdReturn : 33.53528594970703
# Train_MaxReturn : 125.0
# Train_MinReturn : 31.0
# Train_AverageEpLen : 81.0
# Train_EnvstepsSoFar : 36109
# TimeSinceStart : 7.843215227127075
# Training Loss : 11.519268035888672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1078 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.64286041259766
# Eval_StdReturn : 21.95322036743164
# Eval_MaxReturn : 135.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 75.64285714285714
# Train_AverageReturn : 63.411766052246094
# Train_StdReturn : 28.832290649414062
# Train_MaxReturn : 146.0
# Train_MinReturn : 28.0
# Train_AverageEpLen : 63.411764705882355
# Train_EnvstepsSoFar : 37187
# TimeSinceStart : 8.026252031326294
# Training Loss : 11.340380668640137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.69999694824219
# Eval_StdReturn : 32.4839973449707
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 45.0
# Eval_AverageEpLen : 101.7
# Train_AverageReturn : 72.92857360839844
# Train_StdReturn : 23.057270050048828
# Train_MaxReturn : 106.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 72.92857142857143
# Train_EnvstepsSoFar : 38208
# TimeSinceStart : 8.276536464691162
# Training Loss : 11.56374740600586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1053 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.66666412353516
# Eval_StdReturn : 29.519296646118164
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 84.66666666666667
# Train_AverageReturn : 87.75
# Train_StdReturn : 51.410316467285156
# Train_MaxReturn : 181.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 87.75
# Train_EnvstepsSoFar : 39261
# TimeSinceStart : 8.460285425186157
# Training Loss : 11.431988716125488
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 70.0000
# Eval_StdReturn : 25.52123260498047
# Eval_MaxReturn : 116.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 70.0
# Train_AverageReturn : 107.19999694824219
# Train_StdReturn : 50.69674301147461
# Train_MaxReturn : 200.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 107.2
# Train_EnvstepsSoFar : 40333
# TimeSinceStart : 8.691966533660889
# Training Loss : 11.579239845275879
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.64286041259766
# Eval_StdReturn : 45.736209869384766
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 34.0
# Eval_AverageEpLen : 82.64285714285714
# Train_AverageReturn : 100.5
# Train_StdReturn : 51.892677307128906
# Train_MaxReturn : 200.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 100.5
# Train_EnvstepsSoFar : 41338
# TimeSinceStart : 8.905175924301147
# Training Loss : 11.626072883605957
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1069 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.9000015258789
# Eval_StdReturn : 47.382381439208984
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 101.9
# Train_AverageReturn : 89.08333587646484
# Train_StdReturn : 21.441619873046875
# Train_MaxReturn : 121.0
# Train_MinReturn : 52.0
# Train_AverageEpLen : 89.08333333333333
# Train_EnvstepsSoFar : 42407
# TimeSinceStart : 9.099646091461182
# Training Loss : 11.43665599822998
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.4000015258789
# Eval_StdReturn : 43.909454345703125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 110.4
# Train_AverageReturn : 87.91666412353516
# Train_StdReturn : 45.71735382080078
# Train_MaxReturn : 164.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 87.91666666666667
# Train_EnvstepsSoFar : 43462
# TimeSinceStart : 9.345913887023926
# Training Loss : 11.287755966186523
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1072 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.5999984741211
# Eval_StdReturn : 46.40732955932617
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 109.6
# Train_AverageReturn : 119.11111450195312
# Train_StdReturn : 55.6146354675293
# Train_MaxReturn : 200.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 119.11111111111111
# Train_EnvstepsSoFar : 44534
# TimeSinceStart : 9.523786067962646
# Training Loss : 11.392969131469727
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1067 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.90908813476562
# Eval_StdReturn : 31.63558006286621
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 94.9090909090909
# Train_AverageReturn : 118.55555725097656
# Train_StdReturn : 33.41360855102539
# Train_MaxReturn : 177.0
# Train_MinReturn : 81.0
# Train_AverageEpLen : 118.55555555555556
# Train_EnvstepsSoFar : 45601
# TimeSinceStart : 9.699845552444458
# Training Loss : 11.232108116149902
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1179 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 93.18181610107422
# Eval_StdReturn : 43.01335144042969
# Eval_MaxReturn : 170.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 93.18181818181819
# Train_AverageReturn : 107.18181610107422
# Train_StdReturn : 57.57969665527344
# Train_MaxReturn : 200.0
# Train_MinReturn : 36.0
# Train_AverageEpLen : 107.18181818181819
# Train_EnvstepsSoFar : 46780
# TimeSinceStart : 9.955565452575684
# Training Loss : 11.453988075256348
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1069 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.500
# Eval_StdReturn : 26.258331298828125
# Eval_MaxReturn : 178.0
# Eval_MinReturn : 94.0
# Eval_AverageEpLen : 133.5
# Train_AverageReturn : 97.18181610107422
# Train_StdReturn : 40.099464416503906
# Train_MaxReturn : 167.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 97.18181818181819
# Train_EnvstepsSoFar : 47849
# TimeSinceStart : 10.137497663497925
# Training Loss : 11.109260559082031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1131 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 96.36363983154297
# Eval_StdReturn : 27.641447067260742
# Eval_MaxReturn : 161.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 96.36363636363636
# Train_AverageReturn : 102.81818389892578
# Train_StdReturn : 31.5791015625
# Train_MaxReturn : 171.0
# Train_MinReturn : 53.0
# Train_AverageEpLen : 102.81818181818181
# Train_EnvstepsSoFar : 48980
# TimeSinceStart : 10.318036317825317
# Training Loss : 11.120253562927246
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.69999694824219
# Eval_StdReturn : 45.23726272583008
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 52.0
# Eval_AverageEpLen : 101.7
# Train_AverageReturn : 103.5999984741211
# Train_StdReturn : 30.233095169067383
# Train_MaxReturn : 157.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 103.6
# Train_EnvstepsSoFar : 50016
# TimeSinceStart : 10.507609605789185
# Training Loss : 11.020126342773438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 98.81818389892578
# Eval_StdReturn : 31.42037010192871
# Eval_MaxReturn : 188.0
# Eval_MinReturn : 61.0
# Eval_AverageEpLen : 98.81818181818181
# Train_AverageReturn : 112.22222137451172
# Train_StdReturn : 56.16993713378906
# Train_MaxReturn : 200.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 112.22222222222223
# Train_EnvstepsSoFar : 51026
# TimeSinceStart : 10.727550268173218
# Training Loss : 11.117839813232422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1081 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 83.41666412353516
# Eval_StdReturn : 31.645057678222656
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 83.41666666666667
# Train_AverageReturn : 83.15384674072266
# Train_StdReturn : 32.58797836303711
# Train_MaxReturn : 146.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 83.15384615384616
# Train_EnvstepsSoFar : 52107
# TimeSinceStart : 10.901284217834473
# Training Loss : 10.874619483947754
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.80000305175781
# Eval_StdReturn : 39.974491119384766
# Eval_MaxReturn : 176.0
# Eval_MinReturn : 56.0
# Eval_AverageEpLen : 103.8
# Train_AverageReturn : 93.54545593261719
# Train_StdReturn : 26.7152099609375
# Train_MaxReturn : 159.0
# Train_MinReturn : 62.0
# Train_AverageEpLen : 93.54545454545455
# Train_EnvstepsSoFar : 53136
# TimeSinceStart : 11.161421298980713
# Training Loss : 10.761917114257812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.63636016845703
# Eval_StdReturn : 33.85603713989258
# Eval_MaxReturn : 160.0
# Eval_MinReturn : 38.0
# Eval_AverageEpLen : 92.63636363636364
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 23.066200256347656
# Train_MaxReturn : 126.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 54177
# TimeSinceStart : 11.33374547958374
# Training Loss : 10.71338939666748
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 79.53845977783203
# Eval_StdReturn : 22.134605407714844
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 47.0
# Eval_AverageEpLen : 79.53846153846153
# Train_AverageReturn : 81.15384674072266
# Train_StdReturn : 30.094329833984375
# Train_MaxReturn : 145.0
# Train_MinReturn : 32.0
# Train_AverageEpLen : 81.15384615384616
# Train_EnvstepsSoFar : 55232
# TimeSinceStart : 11.528366327285767
# Training Loss : 10.629600524902344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.90908813476562
# Eval_StdReturn : 23.643007278442383
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 95.9090909090909
# Train_AverageReturn : 88.08333587646484
# Train_StdReturn : 29.772634506225586
# Train_MaxReturn : 171.0
# Train_MinReturn : 54.0
# Train_AverageEpLen : 88.08333333333333
# Train_EnvstepsSoFar : 56289
# TimeSinceStart : 11.778164625167847
# Training Loss : 10.48952579498291
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.0999984741211
# Eval_StdReturn : 34.24748229980469
# Eval_MaxReturn : 182.0
# Eval_MinReturn : 75.0
# Eval_AverageEpLen : 110.1
# Train_AverageReturn : 93.54545593261719
# Train_StdReturn : 30.158260345458984
# Train_MaxReturn : 159.0
# Train_MinReturn : 48.0
# Train_AverageEpLen : 93.54545454545455
# Train_EnvstepsSoFar : 57318
# TimeSinceStart : 11.958350896835327
# Training Loss : 10.50048542022705
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1068 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.77777862548828
# Eval_StdReturn : 23.827051162719727
# Eval_MaxReturn : 162.0
# Eval_MinReturn : 77.0
# Eval_AverageEpLen : 113.77777777777777
# Train_AverageReturn : 89.0
# Train_StdReturn : 28.27543067932129
# Train_MaxReturn : 144.0
# Train_MinReturn : 54.0
# Train_AverageEpLen : 89.0
# Train_EnvstepsSoFar : 58386
# TimeSinceStart : 12.232967853546143
# Training Loss : 10.509204864501953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1060 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.000
# Eval_StdReturn : 35.71492004394531
# Eval_MaxReturn : 173.0
# Eval_MinReturn : 58.0
# Eval_AverageEpLen : 115.0
# Train_AverageReturn : 81.53845977783203
# Train_StdReturn : 27.071460723876953
# Train_MaxReturn : 144.0
# Train_MinReturn : 46.0
# Train_AverageEpLen : 81.53846153846153
# Train_EnvstepsSoFar : 59446
# TimeSinceStart : 12.407323360443115
# Training Loss : 10.332776069641113
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1033 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.58333587646484
# Eval_StdReturn : 22.998035430908203
# Eval_MaxReturn : 124.0
# Eval_MinReturn : 59.0
# Eval_AverageEpLen : 88.58333333333333
# Train_AverageReturn : 93.90908813476562
# Train_StdReturn : 45.360084533691406
# Train_MaxReturn : 200.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 93.9090909090909
# Train_EnvstepsSoFar : 60479
# TimeSinceStart : 12.64975380897522
# Training Loss : 10.040366172790527
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.5000
# Eval_StdReturn : 26.228166580200195
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 30.0
# Eval_AverageEpLen : 84.5
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 27.919599533081055
# Train_MaxReturn : 168.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 61520
# TimeSinceStart : 12.837109565734863
# Training Loss : 10.414929389953613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 87.2500
# Eval_StdReturn : 29.137962341308594
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 53.0
# Eval_AverageEpLen : 87.25
# Train_AverageReturn : 83.66666412353516
# Train_StdReturn : 21.707653045654297
# Train_MaxReturn : 132.0
# Train_MinReturn : 57.0
# Train_AverageEpLen : 83.66666666666667
# Train_EnvstepsSoFar : 62524
# TimeSinceStart : 13.010377168655396
# Training Loss : 10.434540748596191
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1045 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 81.46154022216797
# Eval_StdReturn : 37.360233306884766
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 81.46153846153847
# Train_AverageReturn : 87.08333587646484
# Train_StdReturn : 34.44187927246094
# Train_MaxReturn : 151.0
# Train_MinReturn : 49.0
# Train_AverageEpLen : 87.08333333333333
# Train_EnvstepsSoFar : 63569
# TimeSinceStart : 13.272780418395996
# Training Loss : 10.335333824157715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 91.38461303710938
# Eval_StdReturn : 37.446449279785156
# Eval_MaxReturn : 190.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 91.38461538461539
# Train_AverageReturn : 96.45454406738281
# Train_StdReturn : 37.23967361450195
# Train_MaxReturn : 200.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 96.45454545454545
# Train_EnvstepsSoFar : 64630
# TimeSinceStart : 13.45970368385315
# Training Loss : 10.252518653869629
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1073 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.09091186523438
# Eval_StdReturn : 47.607208251953125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 56.0
# Eval_AverageEpLen : 97.0909090909091
# Train_AverageReturn : 89.41666412353516
# Train_StdReturn : 49.6763801574707
# Train_MaxReturn : 200.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 89.41666666666667
# Train_EnvstepsSoFar : 65703
# TimeSinceStart : 13.685516595840454
# Training Loss : 10.41189956665039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 116.22222137451172
# Eval_StdReturn : 50.909019470214844
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 44.0
# Eval_AverageEpLen : 116.22222222222223
# Train_AverageReturn : 96.7272720336914
# Train_StdReturn : 37.736141204833984
# Train_MaxReturn : 200.0
# Train_MinReturn : 59.0
# Train_AverageEpLen : 96.72727272727273
# Train_EnvstepsSoFar : 66767
# TimeSinceStart : 13.921668291091919
# Training Loss : 10.184976577758789
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1044 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.55555725097656
# Eval_StdReturn : 37.57987594604492
# Eval_MaxReturn : 175.0
# Eval_MinReturn : 36.0
# Eval_AverageEpLen : 123.55555555555556
# Train_AverageReturn : 94.90908813476562
# Train_StdReturn : 28.311431884765625
# Train_MaxReturn : 156.0
# Train_MinReturn : 61.0
# Train_AverageEpLen : 94.9090909090909
# Train_EnvstepsSoFar : 67811
# TimeSinceStart : 14.103723526000977
# Training Loss : 10.452993392944336
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1027 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.500
# Eval_StdReturn : 56.22943878173828
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 68.0
# Eval_AverageEpLen : 126.5
# Train_AverageReturn : 93.36363983154297
# Train_StdReturn : 24.886186599731445
# Train_MaxReturn : 152.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 93.36363636363636
# Train_EnvstepsSoFar : 68838
# TimeSinceStart : 14.35462474822998
# Training Loss : 10.455167770385742
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.000
# Eval_StdReturn : 53.0994873046875
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 126.0
# Train_AverageReturn : 94.63636016845703
# Train_StdReturn : 37.17348098754883
# Train_MaxReturn : 189.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 94.63636363636364
# Train_EnvstepsSoFar : 69879
# TimeSinceStart : 14.535233497619629
# Training Loss : 10.257109642028809
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.750
# Eval_StdReturn : 38.79674530029297
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 72.0
# Eval_AverageEpLen : 128.75
# Train_AverageReturn : 131.375
# Train_StdReturn : 39.51245880126953
# Train_MaxReturn : 191.0
# Train_MinReturn : 66.0
# Train_AverageEpLen : 131.375
# Train_EnvstepsSoFar : 70930
# TimeSinceStart : 14.706586599349976
# Training Loss : 10.970348358154297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1121 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 190.000
# Eval_StdReturn : 14.329456329345703
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 166.0
# Eval_AverageEpLen : 190.0
# Train_AverageReturn : 124.55555725097656
# Train_StdReturn : 38.032474517822266
# Train_MaxReturn : 200.0
# Train_MinReturn : 84.0
# Train_AverageEpLen : 124.55555555555556
# Train_EnvstepsSoFar : 72051
# TimeSinceStart : 14.985890865325928
# Training Loss : 10.761639595031738
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     1173 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 157.14285278320312
# Eval_StdReturn : 30.267515182495117
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 120.0
# Eval_AverageEpLen : 157.14285714285714
# Train_AverageReturn : 167.57142639160156
# Train_StdReturn : 36.593746185302734
# Train_MaxReturn : 200.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 167.57142857142858
# Train_EnvstepsSoFar : 73224
# TimeSinceStart : 15.187327146530151
# Training Loss : 10.785236358642578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ...
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1059 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 48.761905670166016
# Eval_StdReturn : 12.2703857421875
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 48.76190476190476
# Train_AverageReturn : 48.1363639831543
# Train_StdReturn : 18.572452545166016
# Train_MaxReturn : 96.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 48.13636363636363
# Train_EnvstepsSoFar : 79965
# TimeSinceStart : 14.482455492019653
# Training Loss : 6.1799397468566895
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1040 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 45.34782791137695
# Eval_StdReturn : 13.48302936553955
# Eval_MaxReturn : 81.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 45.34782608695652
# Train_AverageReturn : 45.21739196777344
# Train_StdReturn : 12.683287620544434
# Train_MaxReturn : 81.0
# Train_MinReturn : 29.0
# Train_AverageEpLen : 45.21739130434783
# Train_EnvstepsSoFar : 81005
# TimeSinceStart : 14.671304702758789
# Training Loss : 5.956185340881348
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.88461685180664
# Eval_StdReturn : 12.801223754882812
# Eval_MaxReturn : 92.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 38.88461538461539
# Train_AverageReturn : 40.11538314819336
# Train_StdReturn : 8.872285842895508
# Train_MaxReturn : 60.0
# Train_MinReturn : 27.0
# Train_AverageEpLen : 40.11538461538461
# Train_EnvstepsSoFar : 82048
# TimeSinceStart : 14.856131076812744
# Training Loss : 5.899106979370117
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.0000
# Eval_StdReturn : 12.606215476989746
# Eval_MaxReturn : 73.0
# Eval_MinReturn : 27.0
# Eval_AverageEpLen : 42.0
# Train_AverageReturn : 47.772727966308594
# Train_StdReturn : 13.937952995300293
# Train_MaxReturn : 88.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 47.77272727272727
# Train_EnvstepsSoFar : 83099
# TimeSinceStart : 15.037001848220825
# Training Loss : 5.9198899269104
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.0000
# Eval_StdReturn : 8.03118896484375
# Eval_MaxReturn : 60.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 37.0
# Train_AverageReturn : 43.565216064453125
# Train_StdReturn : 17.695064544677734
# Train_MaxReturn : 107.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 43.56521739130435
# Train_EnvstepsSoFar : 84101
# TimeSinceStart : 15.23050308227539
# Training Loss : 5.693748474121094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.7500
# Eval_StdReturn : 13.410971641540527
# Eval_MaxReturn : 78.0
# Eval_MinReturn : 25.0
# Eval_AverageEpLen : 41.75
# Train_AverageReturn : 42.279998779296875
# Train_StdReturn : 14.19160270690918
# Train_MaxReturn : 90.0
# Train_MinReturn : 25.0
# Train_AverageEpLen : 42.28
# Train_EnvstepsSoFar : 85158
# TimeSinceStart : 15.418516635894775
# Training Loss : 5.584967613220215
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.74074172973633
# Eval_StdReturn : 10.444181442260742
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 38.74074074074074
# Train_AverageReturn : 37.66666793823242
# Train_StdReturn : 10.756566047668457
# Train_MaxReturn : 58.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 37.666666666666664
# Train_EnvstepsSoFar : 86175
# TimeSinceStart : 15.603647470474243
# Training Loss : 4.876347064971924
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1025 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.03703689575195
# Eval_StdReturn : 10.758223533630371
# Eval_MaxReturn : 58.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 37.03703703703704
# Train_AverageReturn : 42.70833206176758
# Train_StdReturn : 9.947693824768066
# Train_MaxReturn : 64.0
# Train_MinReturn : 26.0
# Train_AverageEpLen : 42.708333333333336
# Train_EnvstepsSoFar : 87200
# TimeSinceStart : 15.789820432662964
# Training Loss : 5.394992828369141
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 33.93333435058594
# Eval_StdReturn : 6.786915302276611
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 33.93333333333333
# Train_AverageReturn : 34.53333282470703
# Train_StdReturn : 8.00305461883545
# Train_MaxReturn : 57.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 34.53333333333333
# Train_EnvstepsSoFar : 88236
# TimeSinceStart : 15.984163045883179
# Training Loss : 4.902271270751953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.82758712768555
# Eval_StdReturn : 9.101227760314941
# Eval_MaxReturn : 65.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 34.827586206896555
# Train_AverageReturn : 37.22222137451172
# Train_StdReturn : 8.052298545837402
# Train_MaxReturn : 59.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 37.22222222222222
# Train_EnvstepsSoFar : 89241
# TimeSinceStart : 16.171640634536743
# Training Loss : 5.182760715484619
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1024 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.33333206176758
# Eval_StdReturn : 7.272474765777588
# Eval_MaxReturn : 51.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 34.333333333333336
# Train_AverageReturn : 36.57143020629883
# Train_StdReturn : 9.56342887878418
# Train_MaxReturn : 55.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 36.57142857142857
# Train_EnvstepsSoFar : 90265
# TimeSinceStart : 16.359573125839233
# Training Loss : 5.2338080406188965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 31.5625
# Eval_StdReturn : 7.717421531677246
# Eval_MaxReturn : 52.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 31.5625
# Train_AverageReturn : 32.41935348510742
# Train_StdReturn : 6.241247653961182
# Train_MaxReturn : 55.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 32.41935483870968
# Train_EnvstepsSoFar : 91270
# TimeSinceStart : 16.54567265510559
# Training Loss : 4.8337082862854
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1024 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 29.02857208251953
# Eval_StdReturn : 6.626723766326904
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 29.02857142857143
# Train_AverageReturn : 32.0
# Train_StdReturn : 6.363961219787598
# Train_MaxReturn : 48.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 32.0
# Train_EnvstepsSoFar : 92294
# TimeSinceStart : 16.733986616134644
# Training Loss : 4.841511249542236
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.558822631835938
# Eval_StdReturn : 6.1270432472229
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 30.558823529411764
# Train_AverageReturn : 31.40625
# Train_StdReturn : 7.466003894805908
# Train_MaxReturn : 47.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 31.40625
# Train_EnvstepsSoFar : 93299
# TimeSinceStart : 16.922910690307617
# Training Loss : 5.248834133148193
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1003 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.393939971923828
# Eval_StdReturn : 6.710188865661621
# Eval_MaxReturn : 45.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 30.393939393939394
# Train_AverageReturn : 31.34375
# Train_StdReturn : 7.078176975250244
# Train_MaxReturn : 47.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 31.34375
# Train_EnvstepsSoFar : 94302
# TimeSinceStart : 17.119558095932007
# Training Loss : 4.448338508605957
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.290321350097656
# Eval_StdReturn : 5.826488971710205
# Eval_MaxReturn : 46.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 32.29032258064516
# Train_AverageReturn : 33.56666564941406
# Train_StdReturn : 6.108373641967773
# Train_MaxReturn : 45.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 33.56666666666667
# Train_EnvstepsSoFar : 95309
# TimeSinceStart : 17.328051805496216
# Training Loss : 5.120711803436279
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 28.5000
# Eval_StdReturn : 6.5042724609375
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 20.0
# Eval_AverageEpLen : 28.5
# Train_AverageReturn : 30.66666603088379
# Train_StdReturn : 6.79869270324707
# Train_MaxReturn : 50.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 30.666666666666668
# Train_EnvstepsSoFar : 96321
# TimeSinceStart : 17.528105974197388
# Training Loss : 4.846698760986328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1015 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.74193572998047
# Eval_StdReturn : 6.579380035400391
# Eval_MaxReturn : 48.0
# Eval_MinReturn : 22.0
# Eval_AverageEpLen : 32.74193548387097
# Train_AverageReturn : 29.852941513061523
# Train_StdReturn : 6.117151737213135
# Train_MaxReturn : 44.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 29.852941176470587
# Train_EnvstepsSoFar : 97336
# TimeSinceStart : 17.720436096191406
# Training Loss : 4.723265647888184
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000/ 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.41176414489746
# Eval_StdReturn : 6.005476474761963
# Eval_MaxReturn : 42.0
# Eval_MinReturn : 19.0
# Eval_AverageEpLen : 30.41176470588235
# Train_AverageReturn : 30.81818199157715
# Train_StdReturn : 6.662670612335205
# Train_MaxReturn : 46.0
# Train_MinReturn : 22.0
# Train_AverageEpLen : 30.818181818181817
# Train_EnvstepsSoFar : 98353
# TimeSinceStart : 17.914459466934204
# Training Loss : 4.741652488708496
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1022 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.545454025268555
# Eval_StdReturn : 6.629095077514648
# Eval_MaxReturn : 44.0
# Eval_MinReturn : 17.0
# Eval_AverageEpLen : 30.545454545454547
# Train_AverageReturn : 29.200000762939453
# Train_StdReturn : 5.181285381317139
# Train_MaxReturn : 40.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 29.2
# Train_EnvstepsSoFar : 99375
# TimeSinceStart : 18.11856985092163
# Training Loss : 4.685555458068848
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1005 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 30.606060028076172
# Eval_StdReturn : 5.720454216003418
# Eval_MaxReturn : 43.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 30.606060606060606
# Train_AverageReturn : 32.41935348510742
# Train_StdReturn : 7.495263576507568
# Train_MaxReturn : 49.0
# Train_MinReturn : 20.0
# Train_AverageEpLen : 32.41935483870968
# Train_EnvstepsSoFar : 100380
# TimeSinceStart : 18.313024282455444
# Training Loss : 4.661776542663574
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1036 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 32.83871078491211
# Eval_StdReturn : 6.227393627166748
# Eval_MaxReturn : 49.0
# Eval_MinReturn : 24.0
# Eval_AverageEpLen : 32.83870967741935
# Train_AverageReturn : 31.393939971923828
# Train_StdReturn : 5.799369812011719
# Train_MaxReturn : 45.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 31.393939393939394
# Train_EnvstepsSoFar : 101416
# TimeSinceStart : 18.50539779663086
# Training Loss : 4.275518417358398
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1008 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.39285659790039
# Eval_StdReturn : 8.574626922607422
# Eval_MaxReturn : 57.0
# Eval_MinReturn : 26.0
# Eval_AverageEpLen : 36.392857142857146
# Train_AverageReturn : 32.51612854003906
# Train_StdReturn : 7.665890693664551
# Train_MaxReturn : 51.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 32.516129032258064
# Train_EnvstepsSoFar : 102424
# TimeSinceStart : 18.687997102737427
# Training Loss : 4.199160099029541
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['reward_to_go'] = True
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/CartPole/return_to_go/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/CartPole/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# CartPole-v0
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 27.578947067260742
# Eval_StdReturn : 15.315337181091309
# Eval_MaxReturn : 69.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 27.57894736842105
# Train_AverageReturn : 22.0
# Train_StdReturn : 10.642409324645996
# Train_MaxReturn : 51.0
# Train_MinReturn : 9.0
# Train_AverageEpLen : 22.0
# Train_EnvstepsSoFar : 1012
# TimeSinceStart : 0.20308923721313477
# Training Loss : 6.256053924560547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     1026 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 36.31034469604492
# Eval_StdReturn : 20.996065139770508
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 36.310344827586206
# Train_AverageReturn : 27.0
# Train_StdReturn : 15.096182823181152
# Train_MaxReturn : 75.0
# Train_MinReturn : 10.0
# Train_AverageEpLen : 27.0
# Train_EnvstepsSoFar : 2038
# TimeSinceStart : 0.40192508697509766
# Training Loss : 6.966986656188965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     1017 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 34.7931022644043
# Eval_StdReturn : 13.884696006774902
# Eval_MaxReturn : 68.0
# Eval_MinReturn : 18.0
# Eval_AverageEpLen : 34.793103448275865
# Train_AverageReturn : 37.66666793823242
# Train_StdReturn : 21.108186721801758
# Train_MaxReturn : 100.0
# Train_MinReturn : 12.0
# Train_AverageEpLen : 37.666666666666664
# Train_EnvstepsSoFar : 3055
# TimeSinceStart : 0.613523006439209
# Training Loss : 8.056185722351074
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     1037 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 50.0476188659668
# Eval_StdReturn : 22.697757720947266
# Eval_MaxReturn : 90.0
# Eval_MinReturn : 11.0
# Eval_AverageEpLen : 50.04761904761905
# Train_AverageReturn : 43.20833206176758
# Train_StdReturn : 24.842805862426758
# Train_MaxReturn : 112.0
# Train_MinReturn : 15.0
# Train_AverageEpLen : 43.208333333333336
# Train_EnvstepsSoFar : 4092
# TimeSinceStart : 0.817880392074585
# Training Loss : 8.361367225646973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     1012 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 73.64286041259766
# Eval_StdReturn : 34.79246139526367
# Eval_MaxReturn : 158.0
# Eval_MinReturn : 28.0
# Eval_AverageEpLen : 73.64285714285714
# Train_AverageReturn : 48.19047546386719
# Train_StdReturn : 19.318431854248047
# Train_MaxReturn : 85.0
# Train_MinReturn : 19.0
# Train_AverageEpLen : 48.19047619047619
# Train_EnvstepsSoFar : 5104
# TimeSinceStart : 1.011216402053833
# Training Loss : 8.359642028808594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 55.83333206176758
# Eval_StdReturn : 30.592756271362305
# Eval_MaxReturn : 119.0
# Eval_MinReturn : 21.0
# Eval_AverageEpLen : 55.833333333333336
# Train_AverageReturn : 50.349998474121094
# Train_StdReturn : 34.302005767822266
# Train_MaxReturn : 116.0
# Train_MinReturn : 17.0
# Train_AverageEpLen : 50.35
# Train_EnvstepsSoFar : 6111
# TimeSinceStart : 1.216876745223999
# Training Loss : 8.55781078338623
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     1020 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.80000305175781
# Eval_StdReturn : 42.089111328125
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 23.0
# Eval_AverageEpLen : 68.8
# Train_AverageReturn : 63.75
# Train_StdReturn : 27.102813720703125
# Train_MaxReturn : 109.0
# Train_MinReturn : 24.0
# Train_AverageEpLen : 63.75
# Train_EnvstepsSoFar : 7131
# TimeSinceStart : 1.432809591293335
# Training Loss : 8.91220474243164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     1002 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.46154022216797
# Eval_StdReturn : 25.536144256591797
# Eval_MaxReturn : 160.0
# Eval_MinReturn : 57.0
# Eval_AverageEpLen : 82.46153846153847
# Train_AverageReturn : 62.625
# Train_StdReturn : 35.30027389526367
# Train_MaxReturn : 133.0
# Train_MinReturn : 23.0
# Train_AverageEpLen : 62.625
# Train_EnvstepsSoFar : 8133
# TimeSinceStart : 1.6631369590759277
# Training Loss : 8.810626983642578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     1025 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.2727279663086
# Eval_StdReturn : 60.83971405029297
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 31.0
# Eval_AverageEpLen : 95.27272727272727
# Train_AverageReturn : 68.33333587646484
# Train_StdReturn : 16.381561279296875
# Train_MaxReturn : 105.0
# Train_MinReturn : 44.0
# Train_AverageEpLen : 68.33333333333333
# Train_EnvstepsSoFar : 9158
# TimeSinceStart : 1.8869526386260986
# Training Loss : 8.658376693725586
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     1010 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 124.44444274902344
# Eval_StdReturn : 36.44512176513672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 65.0
# Eval_AverageEpLen : 124.44444444444444
# Train_AverageReturn : 91.81818389892578
# Train_StdReturn : 52.8648681640625
# Train_MaxReturn : 200.0
# Train_MinReturn : 43.0
# Train_AverageEpLen : 91.81818181818181
# Train_EnvstepsSoFar : 10168
# TimeSinceStart : 2.127117872238159
# Training Loss : 9.382179260253906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     1174 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.750
# Eval_StdReturn : 51.09733200073242
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 128.75
# Train_AverageReturn : 146.75
# Train_StdReturn : 45.43608093261719
# Train_MaxReturn : 200.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 146.75
# Train_EnvstepsSoFar : 11342
# TimeSinceStart : 2.395228385925293
# Training Loss : 9.982255935668945
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.500
# Eval_StdReturn : 33.713253021240234
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 112.0
# Eval_AverageEpLen : 169.5
# Train_AverageReturn : 149.57142639160156
# Train_StdReturn : 39.601070404052734
# Train_MaxReturn : 200.0
# Train_MinReturn : 93.0
# Train_AverageEpLen : 149.57142857142858
# Train_EnvstepsSoFar : 12389
# TimeSinceStart : 2.652452230453491
# Training Loss : 10.067048072814941
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     1109 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 185.000
# Eval_StdReturn : 23.3737735748291
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 138.0
# Eval_AverageEpLen : 185.0
# Train_AverageReturn : 158.42857360839844
# Train_StdReturn : 28.489883422851562
# Train_MaxReturn : 200.0
# Train_MinReturn : 117.0
# Train_AverageEpLen : 158.42857142857142
# Train_EnvstepsSoFar : 13498
# TimeSinceStart : 2.926145315170288
# Training Loss : 9.849106788635254
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.8333282470703
# Eval_StdReturn : 9.788030624389648
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 179.0
# Eval_AverageEpLen : 192.83333333333334
# Train_AverageReturn : 149.0
# Train_StdReturn : 32.872047424316406
# Train_MaxReturn : 191.0
# Train_MinReturn : 78.0
# Train_AverageEpLen : 149.0
# Train_EnvstepsSoFar : 14541
# TimeSinceStart : 3.1743862628936768
# Training Loss : 9.738073348999023
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.3333282470703
# Eval_StdReturn : 32.00347137451172
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 119.0
# Eval_AverageEpLen : 178.33333333333334
# Train_AverageReturn : 176.8333282470703
# Train_StdReturn : 27.491918563842773
# Train_MaxReturn : 200.0
# Train_MinReturn : 136.0
# Train_AverageEpLen : 176.83333333333334
# Train_EnvstepsSoFar : 15602
# TimeSinceStart : 3.427483558654785
# Training Loss : 9.779611587524414
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.1666717529297
# Eval_StdReturn : 31.561668395996094
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 106.0
# Eval_AverageEpLen : 171.16666666666666
# Train_AverageReturn : 148.7142791748047
# Train_StdReturn : 49.134552001953125
# Train_MaxReturn : 200.0
# Train_MinReturn : 47.0
# Train_AverageEpLen : 148.71428571428572
# Train_EnvstepsSoFar : 16643
# TimeSinceStart : 3.6726880073547363
# Training Loss : 9.78067398071289
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     1080 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.8333282470703
# Eval_StdReturn : 25.28778839111328
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 139.0
# Eval_AverageEpLen : 169.83333333333334
# Train_AverageReturn : 180.0
# Train_StdReturn : 29.280254364013672
# Train_MaxReturn : 200.0
# Train_MinReturn : 118.0
# Train_AverageEpLen : 180.0
# Train_EnvstepsSoFar : 17723
# TimeSinceStart : 3.9359421730041504
# Training Loss : 9.425920486450195
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     1136 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 154.85714721679688
# Eval_StdReturn : 43.05620574951172
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 84.0
# Eval_AverageEpLen : 154.85714285714286
# Train_AverageReturn : 162.2857208251953
# Train_StdReturn : 27.618391036987305
# Train_MaxReturn : 200.0
# Train_MinReturn : 125.0
# Train_AverageEpLen : 162.28571428571428
# Train_EnvstepsSoFar : 18859
# TimeSinceStart : 4.225552320480347
# Training Loss : 9.482621192932129
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     1088 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.500
# Eval_StdReturn : 44.73533248901367
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 39.0
# Eval_AverageEpLen : 138.5
# Train_AverageReturn : 136.0
# Train_StdReturn : 18.214006423950195
# Train_MaxReturn : 165.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 136.0
# Train_EnvstepsSoFar : 19947
# TimeSinceStart : 4.476878881454468
# Training Loss : 9.117754936218262
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     1047 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 104.000
# Eval_StdReturn : 25.16346549987793
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 50.0
# Eval_AverageEpLen : 104.0
# Train_AverageReturn : 130.875
# Train_StdReturn : 21.612712860107422
# Train_MaxReturn : 165.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 130.875
# Train_EnvstepsSoFar : 20994
# TimeSinceStart : 4.707226753234863
# Training Loss : 8.809989929199219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     1100 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.41666412353516
# Eval_StdReturn : 34.138099670410156
# Eval_MaxReturn : 126.0
# Eval_MinReturn : 43.0
# Eval_AverageEpLen : 89.41666666666667
# Train_AverageReturn : 122.22222137451172
# Train_StdReturn : 26.657405853271484
# Train_MaxReturn : 162.0
# Train_MinReturn : 69.0
# Train_AverageEpLen : 122.22222222222223
# Train_EnvstepsSoFar : 22094
# TimeSinceStart : 4.941662073135376
# Training Loss : 8.893974304199219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     1057 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.9000015258789
# Eval_StdReturn : 19.09162139892578
# Eval_MaxReturn : 123.0
# Eval_MinReturn : 55.0
# Eval_AverageEpLen : 109.9
# Train_AverageReturn : 96.09091186523438
# Train_StdReturn : 29.361244201660156
# Train_MaxReturn : 135.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 96.0909090909091
# Train_EnvstepsSoFar : 23151
# TimeSinceStart : 5.165366888046265
# Training Loss : 8.240012168884277
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.90908813476562
# Eval_StdReturn : 26.868213653564453
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 42.0
# Eval_AverageEpLen : 97.9090909090909
# Train_AverageReturn : 92.18181610107422
# Train_StdReturn : 32.05625534057617
# Train_MaxReturn : 137.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 92.18181818181819
# Train_EnvstepsSoFar : 24165
# TimeSinceStart : 5.380352020263672
# Training Loss : 8.196666717529297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     1083 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.5000
# Eval_StdReturn : 33.86861801147461
# Eval_MaxReturn : 120.0
# Eval_MinReturn : 33.0
# Eval_AverageEpLen : 89.5
# Train_AverageReturn : 98.45454406738281
# Train_StdReturn : 28.30792808532715
# Train_MaxReturn : 127.0
# Train_MinReturn : 33.0
# Train_AverageEpLen : 98.45454545454545
# Train_EnvstepsSoFar : 25248
# TimeSinceStart : 5.60734748840332
# Training Loss : 8.368048667907715
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     1016 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 102.000
# Eval_StdReturn : 18.718975067138672
# Eval_MaxReturn : 122.0
# Eval_MinReturn : 54.0
# Eval_AverageEpLen : 102.0
# Train_AverageReturn : 92.36363983154297
# Train_StdReturn : 26.867595672607422
# Train_MaxReturn : 121.0
# Train_MinReturn : 41.0
# Train_AverageEpLen : 92.36363636363636
# Train_EnvstepsSoFar : 26264
# TimeSinceStart : 5.82606053352356
# Training Loss : 7.945452690124512
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     1020 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.09091186523438
# Eval_StdReturn : 27.4141788482666
# Eval_MaxReturn : 131.0
# Eval_MinReturn : 48.0
# Eval_AverageEpLen : 99.0909090909091
# Train_AverageReturn : 92.7272720336914
# Train_StdReturn : 30.710054397583008
# Train_MaxReturn : 124.0
# Train_MinReturn : 39.0
# Train_AverageEpLen : 92.72727272727273
# Train_EnvstepsSoFar : 27284
# TimeSinceStart : 6.060994863510132
# Training Loss : 8.085885047912598
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     1031 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 105.4000015258789
# Eval_StdReturn : 14.270248413085938
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 74.0
# Eval_AverageEpLen : 105.4
# Train_AverageReturn : 103.0999984741211
# Train_StdReturn : 30.217378616333008
# Train_MaxReturn : 146.0
# Train_MinReturn : 51.0
# Train_AverageEpLen : 103.1
# Train_EnvstepsSoFar : 28315
# TimeSinceStart : 6.302842378616333
# Training Loss : 8.143121719360352
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     1127 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 84.0000
# Eval_StdReturn : 26.242460250854492
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 51.0
# Eval_AverageEpLen : 84.0
# Train_AverageReturn : 93.91666412353516
# Train_StdReturn : 27.369260787963867
# Train_MaxReturn : 128.0
# Train_MinReturn : 34.0
# Train_AverageEpLen : 93.91666666666667
# Train_EnvstepsSoFar : 29442
# TimeSinceStart : 6.525058269500732
# Training Loss : 7.9839911460876465
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     1023 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 114.88888549804688
# Eval_StdReturn : 10.48220157623291
# Eval_MaxReturn : 134.0
# Eval_MinReturn : 100.0
# Eval_AverageEpLen : 114.88888888888889
# Train_AverageReturn : 102.30000305175781
# Train_StdReturn : 12.704723358154297
# Train_MaxReturn : 117.0
# Train_MinReturn : 77.0
# Train_AverageEpLen : 102.3
# Train_EnvstepsSoFar : 30465
# TimeSinceStart : 6.7375288009643555
# Training Loss : 8.034558296203613
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     1073 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 121.55555725097656
# Eval_StdReturn : 12.455352783203125
# Eval_MaxReturn : 144.0
# Eval_MinReturn : 103.0
# Eval_AverageEpLen : 121.55555555555556
# Train_AverageReturn : 119.22222137451172
# Train_StdReturn : 8.189123153686523
# Train_MaxReturn : 132.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 119.22222222222223
# Train_EnvstepsSoFar : 31538
# TimeSinceStart : 6.979059457778931
# Training Loss : 8.0447359085083
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     1127 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.85714721679688
# Eval_StdReturn : 25.77057456970215
# Eval_MaxReturn : 193.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 142.85714285714286
# Train_AverageReturn : 125.22222137451172
# Train_StdReturn : 15.309967041015625
# Train_MaxReturn : 142.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 125.22222222222223
# Train_EnvstepsSoFar : 32665
# TimeSinceStart : 7.223469257354736
# Training Loss : 8.460411071777344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     1134 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 155.42857360839844
# Eval_StdReturn : 17.186847686767578
# Eval_MaxReturn : 182.0
# Eval_MinReturn : 122.0
# Eval_AverageEpLen : 155.42857142857142
# Train_AverageReturn : 141.75
# Train_StdReturn : 10.437313079833984
# Train_MaxReturn : 155.0
# Train_MinReturn : 123.0
# Train_AverageEpLen : 141.75
# Train_EnvstepsSoFar : 33799
# TimeSinceStart : 7.4879419803619385
# Training Loss : 8.515644073486328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.000
# Eval_StdReturn : 30.02776527404785
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 170.0
# Train_AverageReturn : 146.85714721679688
# Train_StdReturn : 11.764699935913086
# Train_MaxReturn : 166.0
# Train_MinReturn : 132.0
# Train_AverageEpLen : 146.85714285714286
# Train_EnvstepsSoFar : 34827
# TimeSinceStart : 7.738645553588867
# Training Loss : 8.483649253845215
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     1063 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 179.500
# Eval_StdReturn : 26.06242561340332
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 179.5
# Train_AverageReturn : 151.85714721679688
# Train_StdReturn : 15.39414119720459
# Train_MaxReturn : 172.0
# Train_MinReturn : 134.0
# Train_AverageEpLen : 151.85714285714286
# Train_EnvstepsSoFar : 35890
# TimeSinceStart : 7.985672235488892
# Training Loss : 8.523860931396484
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     1028 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 184.8333282470703
# Eval_StdReturn : 16.856420516967773
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 154.0
# Eval_AverageEpLen : 184.83333333333334
# Train_AverageReturn : 171.3333282470703
# Train_StdReturn : 25.675323486328125
# Train_MaxReturn : 200.0
# Train_MinReturn : 133.0
# Train_AverageEpLen : 171.33333333333334
# Train_EnvstepsSoFar : 36918
# TimeSinceStart : 8.24066686630249
# Training Loss : 8.57982349395752
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     1142 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 190.3333282470703
# Train_StdReturn : 21.615324020385742
# Train_MaxReturn : 200.0
# Train_MinReturn : 142.0
# Train_AverageEpLen : 190.33333333333334
# Train_EnvstepsSoFar : 38060
# TimeSinceStart : 8.511461734771729
# Training Loss : 8.961383819580078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     1176 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 196.0
# Train_StdReturn : 6.855654716491699
# Train_MaxReturn : 200.0
# Train_MinReturn : 181.0
# Train_AverageEpLen : 196.0
# Train_EnvstepsSoFar : 39236
# TimeSinceStart : 8.793091535568237
# Training Loss : 8.77636432647705
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     1198 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 199.6666717529297
# Train_StdReturn : 0.745356023311615
# Train_MaxReturn : 200.0
# Train_MinReturn : 198.0
# Train_AverageEpLen : 199.66666666666666
# Train_EnvstepsSoFar : 40434
# TimeSinceStart : 9.076703310012817
# Training Loss : 8.923416137695312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 41434
# TimeSinceStart : 9.326152801513672
# Training Loss : 8.957884788513184
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 42434
# TimeSinceStart : 9.578579187393188
# Training Loss : 8.528759002685547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 43434
# TimeSinceStart : 9.833542585372925
# Training Loss : 9.006901741027832
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 44434
# TimeSinceStart : 10.086064577102661
# Training Loss : 9.091992378234863
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 45434
# TimeSinceStart : 10.33638072013855
# Training Loss : 8.559118270874023
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 46434
# TimeSinceStart : 10.589073657989502
# Training Loss : 8.924735069274902
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     1186 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 197.6666717529297
# Train_StdReturn : 5.217492580413818
# Train_MaxReturn : 200.0
# Train_MinReturn : 186.0
# Train_AverageEpLen : 197.66666666666666
# Train_EnvstepsSoFar : 47620
# TimeSinceStart : 10.869940280914307
# Training Loss : 8.914989471435547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 194.3333282470703
# Eval_StdReturn : 10.979778289794922
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 170.0
# Eval_AverageEpLen : 194.33333333333334
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 48620
# TimeSinceStart : 11.149277925491333
# Training Loss : 9.00706672668457
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     1189 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 198.1666717529297
# Train_StdReturn : 4.099457740783691
# Train_MaxReturn : 200.0
# Train_MinReturn : 189.0
# Train_AverageEpLen : 198.16666666666666
# Train_EnvstepsSoFar : 49809
# TimeSinceStart : 11.43580150604248
# Training Loss : 9.110485076904297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 50809
# TimeSinceStart : 11.69144892692566
# Training Loss : 9.039423942565918
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     1111 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.8333282470703
# Eval_StdReturn : 16.02515411376953
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 157.0
# Eval_AverageEpLen : 192.83333333333334
# Train_AverageReturn : 185.1666717529297
# Train_StdReturn : 33.16834259033203
# Train_MaxReturn : 200.0
# Train_MinReturn : 111.0
# Train_AverageEpLen : 185.16666666666666
# Train_EnvstepsSoFar : 51920
# TimeSinceStart : 11.969686269760132
# Training Loss : 9.133000373840332
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     1199 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 191.3333282470703
# Eval_StdReturn : 12.47219181060791
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 170.0
# Eval_AverageEpLen : 191.33333333333334
# Train_AverageReturn : 199.8333282470703
# Train_StdReturn : 0.3726779818534851
# Train_MaxReturn : 200.0
# Train_MinReturn : 199.0
# Train_AverageEpLen : 199.83333333333334
# Train_EnvstepsSoFar : 53119
# TimeSinceStart : 12.26656436920166
# Training Loss : 9.412109375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     1171 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 195.1666717529297
# Train_StdReturn : 10.807662963867188
# Train_MaxReturn : 200.0
# Train_MinReturn : 171.0
# Train_AverageEpLen : 195.16666666666666
# Train_EnvstepsSoFar : 54290
# TimeSinceStart : 12.531620979309082
# Training Loss : 9.134928703308105
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     1099 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.2857208251953
# Eval_StdReturn : 47.5235710144043
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 88.0
# Eval_AverageEpLen : 165.28571428571428
# Train_AverageReturn : 183.1666717529297
# Train_StdReturn : 26.333860397338867
# Train_MaxReturn : 200.0
# Train_MinReturn : 130.0
# Train_AverageEpLen : 183.16666666666666
# Train_EnvstepsSoFar : 55389
# TimeSinceStart : 12.806541681289673
# Training Loss : 9.126344680786133
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     1183 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 197.3333282470703
# Eval_StdReturn : 5.527708053588867
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 185.0
# Eval_AverageEpLen : 197.33333333333334
# Train_AverageReturn : 197.1666717529297
# Train_StdReturn : 6.335525989532471
# Train_MaxReturn : 200.0
# Train_MinReturn : 183.0
# Train_AverageEpLen : 197.16666666666666
# Train_EnvstepsSoFar : 56572
# TimeSinceStart : 13.099985837936401
# Training Loss : 8.927558898925781
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     1129 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.2857208251953
# Eval_StdReturn : 43.14664077758789
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 81.0
# Eval_AverageEpLen : 158.28571428571428
# Train_AverageReturn : 188.1666717529297
# Train_StdReturn : 22.674631118774414
# Train_MaxReturn : 200.0
# Train_MinReturn : 138.0
# Train_AverageEpLen : 188.16666666666666
# Train_EnvstepsSoFar : 57701
# TimeSinceStart : 13.378187894821167
# Training Loss : 9.07132625579834
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     1014 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.1666717529297
# Eval_StdReturn : 22.799243927001953
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 132.0
# Eval_AverageEpLen : 178.16666666666666
# Train_AverageReturn : 169.0
# Train_StdReturn : 48.768157958984375
# Train_MaxReturn : 200.0
# Train_MinReturn : 70.0
# Train_AverageEpLen : 169.0
# Train_EnvstepsSoFar : 58715
# TimeSinceStart : 13.630845785140991
# Training Loss : 8.573555946350098
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.85714721679688
# Eval_StdReturn : 31.966182708740234
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 120.0
# Eval_AverageEpLen : 168.85714285714286
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 59715
# TimeSinceStart : 13.898674488067627
# Training Loss : 8.912052154541016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     1175 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 188.000
# Eval_StdReturn : 19.899747848510742
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 146.0
# Eval_AverageEpLen : 188.0
# Train_AverageReturn : 167.85714721679688
# Train_StdReturn : 50.20082092285156
# Train_MaxReturn : 200.0
# Train_MinReturn : 87.0
# Train_AverageEpLen : 167.85714285714286
# Train_EnvstepsSoFar : 60890
# TimeSinceStart : 14.177606582641602
# Training Loss : 8.57256031036377
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     1195 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 182.500
# Eval_StdReturn : 25.12468910217285
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 140.0
# Eval_AverageEpLen : 182.5
# Train_AverageReturn : 199.1666717529297
# Train_StdReturn : 1.8633898496627808
# Train_MaxReturn : 200.0
# Train_MinReturn : 195.0
# Train_AverageEpLen : 199.16666666666666
# Train_EnvstepsSoFar : 62085
# TimeSinceStart : 14.467423439025879
# Training Loss : 8.492654800415039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 178.3333282470703
# Eval_StdReturn : 24.910951614379883
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 133.0
# Eval_AverageEpLen : 178.33333333333334
# Train_AverageReturn : 181.1666717529297
# Train_StdReturn : 42.112613677978516
# Train_MaxReturn : 200.0
# Train_MinReturn : 87.0
# Train_AverageEpLen : 181.16666666666666
# Train_EnvstepsSoFar : 63172
# TimeSinceStart : 14.7333664894104
# Training Loss : 8.62319278717041
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.000
# Eval_StdReturn : 38.73413848876953
# Eval_MaxReturn : 196.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 172.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 64172
# TimeSinceStart : 14.987465143203735
# Training Loss : 8.952890396118164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     1096 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.500
# Eval_StdReturn : 21.746646881103516
# Eval_MaxReturn : 198.0
# Eval_MinReturn : 139.0
# Eval_AverageEpLen : 172.5
# Train_AverageReturn : 182.6666717529297
# Train_StdReturn : 21.257678985595703
# Train_MaxReturn : 200.0
# Train_MinReturn : 138.0
# Train_AverageEpLen : 182.66666666666666
# Train_EnvstepsSoFar : 65268
# TimeSinceStart : 15.251501321792603
# Training Loss : 8.372591018676758
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     1113 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.6666717529297
# Eval_StdReturn : 4.818943977355957
# Eval_MaxReturn : 181.0
# Eval_MinReturn : 166.0
# Eval_AverageEpLen : 171.66666666666666
# Train_AverageReturn : 185.5
# Train_StdReturn : 11.236102104187012
# Train_MaxReturn : 199.0
# Train_MinReturn : 169.0
# Train_AverageEpLen : 185.5
# Train_EnvstepsSoFar : 66381
# TimeSinceStart : 15.517911672592163
# Training Loss : 8.553945541381836
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     1055 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.3333282470703
# Eval_StdReturn : 12.697331428527832
# Eval_MaxReturn : 187.0
# Eval_MinReturn : 147.0
# Eval_AverageEpLen : 172.33333333333334
# Train_AverageReturn : 175.8333282470703
# Train_StdReturn : 8.78287410736084
# Train_MaxReturn : 194.0
# Train_MinReturn : 165.0
# Train_AverageEpLen : 175.83333333333334
# Train_EnvstepsSoFar : 67436
# TimeSinceStart : 15.770687341690063
# Training Loss : 8.335963249206543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     1065 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.6666717529297
# Eval_StdReturn : 21.304668426513672
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 134.0
# Eval_AverageEpLen : 174.66666666666666
# Train_AverageReturn : 152.14285278320312
# Train_StdReturn : 54.67939758300781
# Train_MaxReturn : 184.0
# Train_MinReturn : 21.0
# Train_AverageEpLen : 152.14285714285714
# Train_EnvstepsSoFar : 68501
# TimeSinceStart : 16.022167205810547
# Training Loss : 8.311871528625488
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 64 ************
#
# Collecting data to be used for training...
# At timestep:     1126 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 174.3333282470703
# Eval_StdReturn : 40.68442153930664
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 174.33333333333334
# Train_AverageReturn : 187.6666717529297
# Train_StdReturn : 10.624918937683105
# Train_MaxReturn : 200.0
# Train_MinReturn : 167.0
# Train_AverageEpLen : 187.66666666666666
# Train_EnvstepsSoFar : 69627
# TimeSinceStart : 16.297120809555054
# Training Loss : 8.56746768951416
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 65 ************
#
# Collecting data to be used for training...
# At timestep:     1174 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.6666717529297
# Eval_StdReturn : 7.453559875488281
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 180.0
# Eval_AverageEpLen : 196.66666666666666
# Train_AverageReturn : 167.7142791748047
# Train_StdReturn : 44.49627685546875
# Train_MaxReturn : 200.0
# Train_MinReturn : 89.0
# Train_AverageEpLen : 167.71428571428572
# Train_EnvstepsSoFar : 70801
# TimeSinceStart : 16.58189845085144
# Training Loss : 8.149275779724121
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 66 ************
#
# Collecting data to be used for training...
# At timestep:     1151 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.1666717529297
# Eval_StdReturn : 40.118228912353516
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 92.0
# Eval_AverageEpLen : 171.16666666666666
# Train_AverageReturn : 191.8333282470703
# Train_StdReturn : 18.26122283935547
# Train_MaxReturn : 200.0
# Train_MinReturn : 151.0
# Train_AverageEpLen : 191.83333333333334
# Train_EnvstepsSoFar : 71952
# TimeSinceStart : 16.858116388320923
# Training Loss : 8.08228874206543
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 67 ************
#
# Collecting data to be used for training...
# At timestep:     1189 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 198.1666717529297
# Train_StdReturn : 4.099457740783691
# Train_MaxReturn : 200.0
# Train_MinReturn : 189.0
# Train_AverageEpLen : 198.16666666666666
# Train_EnvstepsSoFar : 73141
# TimeSinceStart : 17.141467571258545
# Training Loss : 8.077061653137207
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 68 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.1666717529297
# Eval_StdReturn : 43.12159729003906
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 86.0
# Eval_AverageEpLen : 172.16666666666666
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 74141
# TimeSinceStart : 17.396196603775024
# Training Loss : 8.371787071228027
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 69 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 200.0
# Train_StdReturn : 0.0
# Train_MaxReturn : 200.0
# Train_MinReturn : 200.0
# Train_AverageEpLen : 200.0
# Train_EnvstepsSoFar : 75141
# TimeSinceStart : 17.65040111541748
# Training Loss : 8.103306770324707
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 70 ************
#
# Collecting data to be used for training...
# At timestep:     1128 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# Train_AverageReturn : 188.0
# Train_StdReturn : 26.832815170288086
# Train_MaxReturn : 200.0
# Train_MinReturn : 128.0
# Train_AverageEpLen : 188.0
# Train_EnvstepsSoFar : 76269
# TimeSinceStart : 17.91962742805481
# Training Loss : 8.152382850646973
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 22.0
# Done logging...
#
#
#
#
# ********** Iteration 71 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.000
# Eval_StdReturn : 0.0
# Eval_MaxReturn : 200.0
# Eval_MinReturn : 200.0
# Eval_AverageEpLen : 200.0
# ...
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 77 ************
#
# Collecting data to be used for training...
# At timestep:     1051 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.500
# Eval_StdReturn : 23.001087188720703
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 35.0
# Eval_AverageEpLen : 100.5
# Train_AverageReturn : 105.0999984741211
# Train_StdReturn : 26.609960556030273
# Train_MaxReturn : 134.0
# Train_MinReturn : 30.0
# Train_AverageEpLen : 105.1
# Train_EnvstepsSoFar : 83293
# TimeSinceStart : 20.808160066604614
# Training Loss : 6.417284965515137
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 78 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.33333587646484
# Eval_StdReturn : 27.62346076965332
# Eval_MaxReturn : 121.0
# Eval_MinReturn : 29.0
# Eval_AverageEpLen : 88.33333333333333
# Train_AverageReturn : 98.81818389892578
# Train_StdReturn : 26.051761627197266
# Train_MaxReturn : 127.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 98.81818181818181
# Train_EnvstepsSoFar : 84380
# TimeSinceStart : 21.058706283569336
# Training Loss : 6.224637985229492
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     1100 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 106.9000015258789
# Eval_StdReturn : 5.9405388832092285
# Eval_MaxReturn : 113.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 106.9
# Train_AverageReturn : 91.66666412353516
# Train_StdReturn : 28.639522552490234
# Train_MaxReturn : 119.0
# Train_MinReturn : 40.0
# Train_AverageEpLen : 91.66666666666667
# Train_EnvstepsSoFar : 85480
# TimeSinceStart : 21.301057815551758
# Training Loss : 6.449061393737793
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     1071 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.66666412353516
# Eval_StdReturn : 8.151346206665039
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 111.66666666666667
# Train_AverageReturn : 107.0999984741211
# Train_StdReturn : 6.236185073852539
# Train_MaxReturn : 118.0
# Train_MinReturn : 99.0
# Train_AverageEpLen : 107.1
# Train_EnvstepsSoFar : 86551
# TimeSinceStart : 21.535744667053223
# Training Loss : 6.33811092376709
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     1041 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.000
# Eval_StdReturn : 6.912147045135498
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 115.0
# Train_AverageReturn : 115.66666412353516
# Train_StdReturn : 5.96284818649292
# Train_MaxReturn : 124.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 115.66666666666667
# Train_EnvstepsSoFar : 87592
# TimeSinceStart : 21.780384302139282
# Training Loss : 6.3447265625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     1046 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.55555725097656
# Eval_StdReturn : 10.92510986328125
# Eval_MaxReturn : 142.0
# Eval_MinReturn : 107.0
# Eval_AverageEpLen : 123.55555555555556
# Train_AverageReturn : 116.22222137451172
# Train_StdReturn : 7.00440788269043
# Train_MaxReturn : 129.0
# Train_MinReturn : 107.0
# Train_AverageEpLen : 116.22222222222223
# Train_EnvstepsSoFar : 88638
# TimeSinceStart : 22.02165126800537
# Training Loss : 6.085250377655029
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     1059 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.77777862548828
# Eval_StdReturn : 10.453896522521973
# Eval_MaxReturn : 135.0
# Eval_MinReturn : 105.0
# Eval_AverageEpLen : 120.77777777777777
# Train_AverageReturn : 117.66666412353516
# Train_StdReturn : 8.550503730773926
# Train_MaxReturn : 131.0
# Train_MinReturn : 106.0
# Train_AverageEpLen : 117.66666666666667
# Train_EnvstepsSoFar : 89697
# TimeSinceStart : 22.27346444129944
# Training Loss : 6.458822250366211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     1013 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.22222137451172
# Eval_StdReturn : 9.040375709533691
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 123.22222222222223
# Train_AverageReturn : 112.55555725097656
# Train_StdReturn : 5.559998512268066
# Train_MaxReturn : 121.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 112.55555555555556
# Train_EnvstepsSoFar : 90710
# TimeSinceStart : 22.506023645401
# Training Loss : 6.114260673522949
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     1087 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.88888549804688
# Eval_StdReturn : 7.109374523162842
# Eval_MaxReturn : 133.0
# Eval_MinReturn : 109.0
# Eval_AverageEpLen : 123.88888888888889
# Train_AverageReturn : 120.77777862548828
# Train_StdReturn : 7.0518364906311035
# Train_MaxReturn : 129.0
# Train_MinReturn : 110.0
# Train_AverageEpLen : 120.77777777777777
# Train_EnvstepsSoFar : 91797
# TimeSinceStart : 22.752987146377563
# Training Loss : 6.407731533050537
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 117.000
# Eval_StdReturn : 6.863753318786621
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 104.0
# Eval_AverageEpLen : 117.0
# Train_AverageReturn : 115.88888549804688
# Train_StdReturn : 7.014975547790527
# Train_MaxReturn : 132.0
# Train_MinReturn : 108.0
# Train_AverageEpLen : 115.88888888888889
# Train_EnvstepsSoFar : 92840
# TimeSinceStart : 23.003371238708496
# Training Loss : 6.3403754234313965
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     1078 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.11111450195312
# Eval_StdReturn : 7.263981819152832
# Eval_MaxReturn : 127.0
# Eval_MinReturn : 104.0
# Eval_AverageEpLen : 115.11111111111111
# Train_AverageReturn : 119.77777862548828
# Train_StdReturn : 9.246954917907715
# Train_MaxReturn : 135.0
# Train_MinReturn : 110.0
# Train_AverageEpLen : 119.77777777777777
# Train_EnvstepsSoFar : 93918
# TimeSinceStart : 23.25268793106079
# Training Loss : 5.783600807189941
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     1043 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.80000305175781
# Eval_StdReturn : 9.130169868469238
# Eval_MaxReturn : 123.0
# Eval_MinReturn : 96.0
# Eval_AverageEpLen : 109.8
# Train_AverageReturn : 104.30000305175781
# Train_StdReturn : 21.410511016845703
# Train_MaxReturn : 121.0
# Train_MinReturn : 42.0
# Train_AverageEpLen : 104.3
# Train_EnvstepsSoFar : 94961
# TimeSinceStart : 23.50405740737915
# Training Loss : 5.937997817993164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     1061 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 109.000
# Eval_StdReturn : 8.820430755615234
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 100.0
# Eval_AverageEpLen : 109.0
# Train_AverageReturn : 117.88888549804688
# Train_StdReturn : 8.047697067260742
# Train_MaxReturn : 131.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 117.88888888888889
# Train_EnvstepsSoFar : 96022
# TimeSinceStart : 23.74853491783142
# Training Loss : 5.985374450683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     1092 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 111.22222137451172
# Eval_StdReturn : 9.964133262634277
# Eval_MaxReturn : 132.0
# Eval_MinReturn : 101.0
# Eval_AverageEpLen : 111.22222222222223
# Train_AverageReturn : 109.19999694824219
# Train_StdReturn : 5.095095634460449
# Train_MaxReturn : 115.0
# Train_MinReturn : 101.0
# Train_AverageEpLen : 109.2
# Train_EnvstepsSoFar : 97114
# TimeSinceStart : 23.978132247924805
# Training Loss : 6.097095012664795
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     1066 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 113.55555725097656
# Eval_StdReturn : 10.034507751464844
# Eval_MaxReturn : 129.0
# Eval_MinReturn : 98.0
# Eval_AverageEpLen : 113.55555555555556
# Train_AverageReturn : 106.5999984741211
# Train_StdReturn : 5.7827324867248535
# Train_MaxReturn : 114.0
# Train_MinReturn : 96.0
# Train_AverageEpLen : 106.6
# Train_EnvstepsSoFar : 98180
# TimeSinceStart : 24.210813760757446
# Training Loss : 6.0082621574401855
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     1007 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 115.11111450195312
# Eval_StdReturn : 8.748897552490234
# Eval_MaxReturn : 136.0
# Eval_MinReturn : 103.0
# Eval_AverageEpLen : 115.11111111111111
# Train_AverageReturn : 111.88888549804688
# Train_StdReturn : 8.999313354492188
# Train_MaxReturn : 125.0
# Train_MinReturn : 100.0
# Train_AverageEpLen : 111.88888888888889
# Train_EnvstepsSoFar : 99187
# TimeSinceStart : 24.430980443954468
# Training Loss : 5.622731685638428
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     1023 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 119.55555725097656
# Eval_StdReturn : 7.617393970489502
# Eval_MaxReturn : 128.0
# Eval_MinReturn : 102.0
# Eval_AverageEpLen : 119.55555555555556
# Train_AverageReturn : 113.66666412353516
# Train_StdReturn : 6.73300313949585
# Train_MaxReturn : 124.0
# Train_MinReturn : 102.0
# Train_AverageEpLen : 113.66666666666667
# Train_EnvstepsSoFar : 100210
# TimeSinceStart : 24.669151544570923
# Training Loss : 5.76061487197876
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     1021 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.44444274902344
# Eval_StdReturn : 10.393492698669434
# Eval_MaxReturn : 143.0
# Eval_MinReturn : 110.0
# Eval_AverageEpLen : 120.44444444444444
# Train_AverageReturn : 113.44444274902344
# Train_StdReturn : 9.58135986328125
# Train_MaxReturn : 128.0
# Train_MinReturn : 103.0
# Train_AverageEpLen : 113.44444444444444
# Train_EnvstepsSoFar : 101231
# TimeSinceStart : 24.90465784072876
# Training Loss : 5.9516987800598145
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     1115 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 127.000
# Eval_StdReturn : 10.828204154968262
# Eval_MaxReturn : 154.0
# Eval_MinReturn : 117.0
# Eval_AverageEpLen : 127.0
# Train_AverageReturn : 123.88888549804688
# Train_StdReturn : 6.740333557128906
# Train_MaxReturn : 136.0
# Train_MinReturn : 112.0
# Train_AverageEpLen : 123.88888888888889
# Train_EnvstepsSoFar : 102346
# TimeSinceStart : 25.154270887374878
# Training Loss : 6.170619964599609
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     1029 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 133.750
# Eval_StdReturn : 7.066647052764893
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 123.0
# Eval_AverageEpLen : 133.75
# Train_AverageReturn : 128.625
# Train_StdReturn : 9.109576225280762
# Train_MaxReturn : 144.0
# Train_MinReturn : 114.0
# Train_AverageEpLen : 128.625
# Train_EnvstepsSoFar : 103375
# TimeSinceStart : 25.408242225646973
# Training Loss : 5.742019176483154
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     1064 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 145.875
# Eval_StdReturn : 11.569761276245117
# Eval_MaxReturn : 168.0
# Eval_MinReturn : 130.0
# Eval_AverageEpLen : 145.875
# Train_AverageReturn : 133.0
# Train_StdReturn : 14.534441947937012
# Train_MaxReturn : 160.0
# Train_MinReturn : 117.0
# Train_AverageEpLen : 133.0
# Train_EnvstepsSoFar : 104439
# TimeSinceStart : 25.66547703742981
# Training Loss : 6.321371555328369
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     1000 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 142.875
# Eval_StdReturn : 9.292974472045898
# Eval_MaxReturn : 157.0
# Eval_MinReturn : 132.0
# Eval_AverageEpLen : 142.875
# Train_AverageReturn : 142.85714721679688
# Train_StdReturn : 8.998866081237793
# Train_MaxReturn : 156.0
# Train_MinReturn : 133.0
# Train_AverageEpLen : 142.85714285714286
# Train_EnvstepsSoFar : 105439
# TimeSinceStart : 25.914592266082764
# Training Loss : 5.8683180809021
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     1004 / 1000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.625
# Eval_StdReturn : 4.12121057510376
# Eval_MaxReturn : 147.0
# Eval_MinReturn : 133.0
# Eval_AverageEpLen : 138.625
# Train_AverageReturn : 143.42857360839844
# Train_StdReturn : 13.499811172485352
# Train_MaxReturn : 164.0
# Train_MinReturn : 128.0
# Train_AverageEpLen : 143.42857142857142
# Train_EnvstepsSoFar : 106443
# TimeSinceStart : 26.172744035720825
# Training Loss : 6.343075752258301
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 27.432432174682617
# Done logging...

# %% [markdown]
# We should see the reward to go estimator outperforming the full returns estimator, with some runs reaching the maximum reward of 200. There will likely however be high variance between runs.

# %%
### Visualize Policy Gradient results on CartPole
# !kill 278277
# !fuser 6006/tcp -k #clear the port 
# %reload_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/CartPole
# Out:
# 6006/tcp:            308663
#       <iframe id="tensorboard-frame-412b1d7172e7ab8c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-412b1d7172e7ab8c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# We can also compare our estimators on a more complex task, though you will probably see that they don't perform well (not getting much above 200 returns). Note that on this more complex task, we use a much larger batch size to reduce variance in the policy gradients.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = False
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/full_returns/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/full_returns/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/Hopper/full_returns/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/full_returns/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 61.34284210205078
# Eval_StdReturn : 57.76802062988281
# Eval_MaxReturn : 203.46632385253906
# Eval_MinReturn : 7.391658306121826
# Eval_AverageEpLen : 39.96153846153846
# Train_AverageReturn : 9.657980918884277
# Train_StdReturn : 5.853752613067627
# Train_MaxReturn : 87.45542907714844
# Train_MinReturn : 3.010934352874756
# Train_AverageEpLen : 13.215323645970939
# Train_EnvstepsSoFar : 10004
# TimeSinceStart : 4.071899175643921
# Training Loss : 34.30583572387695
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 72.8387222290039
# Eval_StdReturn : 11.639813423156738
# Eval_MaxReturn : 97.1689453125
# Eval_MinReturn : 56.68820571899414
# Eval_AverageEpLen : 45.65217391304348
# Train_AverageReturn : 54.50438690185547
# Train_StdReturn : 46.97917175292969
# Train_MaxReturn : 214.85650634765625
# Train_MinReturn : 5.630634784698486
# Train_AverageEpLen : 37.95454545454545
# Train_EnvstepsSoFar : 20024
# TimeSinceStart : 8.316957235336304
# Training Loss : 90.11448669433594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 62.79875183105469
# Eval_StdReturn : 9.179817199707031
# Eval_MaxReturn : 83.30668640136719
# Eval_MinReturn : 52.27299499511719
# Eval_AverageEpLen : 38.074074074074076
# Train_AverageReturn : 75.83659362792969
# Train_StdReturn : 19.88337516784668
# Train_MaxReturn : 161.70582580566406
# Train_MinReturn : 12.98355484008789
# Train_AverageEpLen : 47.97129186602871
# Train_EnvstepsSoFar : 30050
# TimeSinceStart : 12.402408361434937
# Training Loss : 99.64437866210938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 52.26776123046875
# Eval_StdReturn : 5.455423831939697
# Eval_MaxReturn : 68.46729278564453
# Eval_MinReturn : 44.55207061767578
# Eval_AverageEpLen : 31.09090909090909
# Train_AverageReturn : 60.45672607421875
# Train_StdReturn : 8.498208045959473
# Train_MaxReturn : 108.87381744384766
# Train_MinReturn : 46.84237289428711
# Train_AverageEpLen : 37.10740740740741
# Train_EnvstepsSoFar : 40069
# TimeSinceStart : 16.489992141723633
# Training Loss : 101.54632568359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.14884567260742
# Eval_StdReturn : 14.536173820495605
# Eval_MaxReturn : 114.8108139038086
# Eval_MinReturn : 46.10413360595703
# Eval_AverageEpLen : 36.06896551724138
# Train_AverageReturn : 53.69095993041992
# Train_StdReturn : 6.895584583282471
# Train_MaxReturn : 111.23048400878906
# Train_MinReturn : 41.2711181640625
# Train_AverageEpLen : 31.85987261146497
# Train_EnvstepsSoFar : 50073
# TimeSinceStart : 20.63226079940796
# Training Loss : 102.34545135498047
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000639 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 66.40575408935547
# Eval_StdReturn : 14.012945175170898
# Eval_MaxReturn : 102.32240295410156
# Eval_MinReturn : 47.63692855834961
# Eval_AverageEpLen : 38.370370370370374
# Train_AverageReturn : 57.791053771972656
# Train_StdReturn : 9.75520133972168
# Train_MaxReturn : 95.34403228759766
# Train_MinReturn : 43.168800354003906
# Train_AverageEpLen : 33.29235880398671
# Train_EnvstepsSoFar : 60094
# TimeSinceStart : 24.75870656967163
# Training Loss : 107.87123107910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 75.18194580078125
# Eval_StdReturn : 18.406030654907227
# Eval_MaxReturn : 144.75587463378906
# Eval_MinReturn : 52.417510986328125
# Eval_AverageEpLen : 42.75
# Train_AverageReturn : 73.6001205444336
# Train_StdReturn : 17.074445724487305
# Train_MaxReturn : 141.6881866455078
# Train_MinReturn : 44.51664733886719
# Train_AverageEpLen : 41.84937238493724
# Train_EnvstepsSoFar : 70096
# TimeSinceStart : 28.728729248046875
# Training Loss : 117.74435424804688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 69.56477355957031
# Eval_StdReturn : 16.246891021728516
# Eval_MaxReturn : 127.04954528808594
# Eval_MinReturn : 51.87811279296875
# Eval_AverageEpLen : 40.8
# Train_AverageReturn : 73.12445068359375
# Train_StdReturn : 19.103506088256836
# Train_MaxReturn : 150.7430419921875
# Train_MinReturn : 40.2024040222168
# Train_AverageEpLen : 41.95397489539749
# Train_EnvstepsSoFar : 80123
# TimeSinceStart : 32.666348457336426
# Training Loss : 118.02587127685547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 63.60788345336914
# Eval_StdReturn : 12.787737846374512
# Eval_MaxReturn : 96.92973327636719
# Eval_MinReturn : 41.384727478027344
# Eval_AverageEpLen : 37.925925925925924
# Train_AverageReturn : 66.75045013427734
# Train_StdReturn : 16.810911178588867
# Train_MaxReturn : 148.28884887695312
# Train_MinReturn : 38.72220230102539
# Train_AverageEpLen : 39.27843137254902
# Train_EnvstepsSoFar : 90139
# TimeSinceStart : 36.60485291481018
# Training Loss : 115.3628921508789
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 70.69017791748047
# Eval_StdReturn : 21.061920166015625
# Eval_MaxReturn : 119.20759582519531
# Eval_MinReturn : 40.2270622253418
# Eval_AverageEpLen : 40.64
# Train_AverageReturn : 62.52112579345703
# Train_StdReturn : 14.302521705627441
# Train_MaxReturn : 141.4912872314453
# Train_MinReturn : 2.5054173469543457
# Train_AverageEpLen : 37.52808988764045
# Train_EnvstepsSoFar : 100159
# TimeSinceStart : 40.578378677368164
# Training Loss : 113.4165267944336
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.49105834960938
# Eval_StdReturn : 101.17304992675781
# Eval_MaxReturn : 419.36773681640625
# Eval_MinReturn : 53.32986831665039
# Eval_AverageEpLen : 62.5
# Train_AverageReturn : 79.50668334960938
# Train_StdReturn : 20.757583618164062
# Train_MaxReturn : 136.48919677734375
# Train_MinReturn : 39.988853454589844
# Train_AverageEpLen : 45.34841628959276
# Train_EnvstepsSoFar : 110181
# TimeSinceStart : 44.40176248550415
# Training Loss : 122.65392303466797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.08952331542969
# Eval_StdReturn : 56.440982818603516
# Eval_MaxReturn : 308.40679931640625
# Eval_MinReturn : 48.22431564331055
# Eval_AverageEpLen : 50.85
# Train_AverageReturn : 85.77071380615234
# Train_StdReturn : 40.175758361816406
# Train_MaxReturn : 447.7596130371094
# Train_MinReturn : 12.14716625213623
# Train_AverageEpLen : 47.43601895734597
# Train_EnvstepsSoFar : 120190
# TimeSinceStart : 48.321826696395874
# Training Loss : 123.8788833618164
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 93.71907043457031
# Eval_StdReturn : 42.609737396240234
# Eval_MaxReturn : 210.71102905273438
# Eval_MinReturn : 55.33494567871094
# Eval_AverageEpLen : 52.73684210526316
# Train_AverageReturn : 94.77420806884766
# Train_StdReturn : 64.63707733154297
# Train_MaxReturn : 516.2953491210938
# Train_MinReturn : 41.81956481933594
# Train_AverageEpLen : 51.04081632653061
# Train_EnvstepsSoFar : 130194
# TimeSinceStart : 52.11230945587158
# Training Loss : 124.23973846435547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.23221588134766
# Eval_StdReturn : 62.730350494384766
# Eval_MaxReturn : 251.505859375
# Eval_MinReturn : 17.07705307006836
# Eval_AverageEpLen : 65.375
# Train_AverageReturn : 105.31327819824219
# Train_StdReturn : 60.2136116027832
# Train_MaxReturn : 354.47125244140625
# Train_MinReturn : -0.21114253997802734
# Train_AverageEpLen : 56.99431818181818
# Train_EnvstepsSoFar : 140225
# TimeSinceStart : 55.83100986480713
# Training Loss : 126.45145416259766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 131.51695251464844
# Eval_StdReturn : 57.62667465209961
# Eval_MaxReturn : 197.48687744140625
# Eval_MinReturn : 20.993236541748047
# Eval_AverageEpLen : 69.06666666666666
# Train_AverageReturn : 117.83574676513672
# Train_StdReturn : 74.5284423828125
# Train_MaxReturn : 558.9060668945312
# Train_MinReturn : 18.909822463989258
# Train_AverageEpLen : 62.22360248447205
# Train_EnvstepsSoFar : 150243
# TimeSinceStart : 59.556159019470215
# Training Loss : 126.91898345947266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 149.1865997314453
# Eval_StdReturn : 70.0601577758789
# Eval_MaxReturn : 291.8650207519531
# Eval_MinReturn : 20.96352195739746
# Eval_AverageEpLen : 76.78571428571429
# Train_AverageReturn : 108.84674072265625
# Train_StdReturn : 69.35640716552734
# Train_MaxReturn : 413.80474853515625
# Train_MinReturn : 14.731386184692383
# Train_AverageEpLen : 58.60233918128655
# Train_EnvstepsSoFar : 160264
# TimeSinceStart : 63.31852698326111
# Training Loss : 126.07318115234375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10032 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 140.27114868164062
# Eval_StdReturn : 75.1602554321289
# Eval_MaxReturn : 248.2835693359375
# Eval_MinReturn : 20.547435760498047
# Eval_AverageEpLen : 74.35714285714286
# Train_AverageReturn : 125.58338165283203
# Train_StdReturn : 80.51510620117188
# Train_MaxReturn : 426.2779235839844
# Train_MinReturn : 16.574363708496094
# Train_AverageEpLen : 64.72258064516129
# Train_EnvstepsSoFar : 170296
# TimeSinceStart : 67.00840544700623
# Training Loss : 127.63895416259766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.13514709472656
# Eval_StdReturn : 58.63132095336914
# Eval_MaxReturn : 259.4964294433594
# Eval_MinReturn : 85.47564697265625
# Eval_AverageEpLen : 85.5
# Train_AverageReturn : 164.01673889160156
# Train_StdReturn : 72.14675903320312
# Train_MaxReturn : 406.387451171875
# Train_MinReturn : 20.656972885131836
# Train_AverageEpLen : 83.48333333333333
# Train_EnvstepsSoFar : 180314
# TimeSinceStart : 70.6952452659607
# Training Loss : 131.39813232421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.58531188964844
# Eval_StdReturn : 39.16374588012695
# Eval_MaxReturn : 255.75062561035156
# Eval_MinReturn : 124.62738037109375
# Eval_AverageEpLen : 89.08333333333333
# Train_AverageReturn : 169.76414489746094
# Train_StdReturn : 61.259334564208984
# Train_MaxReturn : 357.4930419921875
# Train_MinReturn : 21.2346248626709
# Train_AverageEpLen : 86.37068965517241
# Train_EnvstepsSoFar : 190333
# TimeSinceStart : 74.31806588172913
# Training Loss : 133.7305145263672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 160.1634063720703
# Eval_StdReturn : 33.56018829345703
# Eval_MaxReturn : 243.42626953125
# Eval_MinReturn : 116.08638000488281
# Eval_AverageEpLen : 84.25
# Train_AverageReturn : 171.7947540283203
# Train_StdReturn : 52.2494010925293
# Train_MaxReturn : 332.35186767578125
# Train_MinReturn : 2.490445137023926
# Train_AverageEpLen : 87.86842105263158
# Train_EnvstepsSoFar : 200350
# TimeSinceStart : 77.9749174118042
# Training Loss : 133.5617218017578
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.43589782714844
# Eval_StdReturn : 47.65663146972656
# Eval_MaxReturn : 226.99478149414062
# Eval_MinReturn : 59.82909393310547
# Eval_AverageEpLen : 83.23076923076923
# Train_AverageReturn : 159.9815216064453
# Train_StdReturn : 59.20014572143555
# Train_MaxReturn : 369.3186340332031
# Train_MinReturn : 45.09149169921875
# Train_AverageEpLen : 82.44262295081967
# Train_EnvstepsSoFar : 210408
# TimeSinceStart : 81.6359179019928
# Training Loss : 133.8382568359375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 134.196044921875
# Eval_StdReturn : 53.16651153564453
# Eval_MaxReturn : 221.2831573486328
# Eval_MinReturn : 50.07925033569336
# Eval_AverageEpLen : 73.0
# Train_AverageReturn : 152.47987365722656
# Train_StdReturn : 54.55990982055664
# Train_MaxReturn : 292.83819580078125
# Train_MinReturn : 57.5848274230957
# Train_AverageEpLen : 80.048
# Train_EnvstepsSoFar : 220414
# TimeSinceStart : 85.35959839820862
# Training Loss : 134.3850555419922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 110.86808776855469
# Eval_StdReturn : 51.38865661621094
# Eval_MaxReturn : 236.19772338867188
# Eval_MinReturn : 51.88481140136719
# Eval_AverageEpLen : 63.4375
# Train_AverageReturn : 142.25497436523438
# Train_StdReturn : 57.469417572021484
# Train_MaxReturn : 331.713134765625
# Train_MinReturn : 49.08158493041992
# Train_AverageEpLen : 75.82575757575758
# Train_EnvstepsSoFar : 230423
# TimeSinceStart : 89.05741953849792
# Training Loss : 133.43850708007812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10063 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 86.00275421142578
# Eval_StdReturn : 38.98858642578125
# Eval_MaxReturn : 180.44720458984375
# Eval_MinReturn : 46.14714050292969
# Eval_AverageEpLen : 52.1
# Train_AverageReturn : 118.62569427490234
# Train_StdReturn : 57.76234436035156
# Train_MaxReturn : 329.5797119140625
# Train_MinReturn : 49.274742126464844
# Train_AverageEpLen : 66.20394736842105
# Train_EnvstepsSoFar : 240486
# TimeSinceStart : 92.77905917167664
# Training Loss : 130.24252319335938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 101.86869049072266
# Eval_StdReturn : 42.319244384765625
# Eval_MaxReturn : 176.8238067626953
# Eval_MinReturn : 47.060546875
# Eval_AverageEpLen : 60.8235294117647
# Train_AverageReturn : 100.71052551269531
# Train_StdReturn : 49.2806396484375
# Train_MaxReturn : 266.0931701660156
# Train_MinReturn : 43.79645919799805
# Train_AverageEpLen : 58.94705882352941
# Train_EnvstepsSoFar : 250507
# TimeSinceStart : 96.42647409439087
# Training Loss : 127.34777069091797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.6398696899414
# Eval_StdReturn : 44.28077697753906
# Eval_MaxReturn : 179.1323699951172
# Eval_MinReturn : 49.76311492919922
# Eval_AverageEpLen : 69.46666666666667
# Train_AverageReturn : 103.78912353515625
# Train_StdReturn : 50.70380401611328
# Train_MaxReturn : 313.80596923828125
# Train_MinReturn : 43.58221435546875
# Train_AverageEpLen : 60.10179640718563
# Train_EnvstepsSoFar : 260544
# TimeSinceStart : 100.12935280799866
# Training Loss : 128.39718627929688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 98.31094360351562
# Eval_StdReturn : 50.572994232177734
# Eval_MaxReturn : 241.44534301757812
# Eval_MinReturn : 44.285823822021484
# Eval_AverageEpLen : 57.05555555555556
# Train_AverageReturn : 113.23494720458984
# Train_StdReturn : 50.05651092529297
# Train_MaxReturn : 257.2220458984375
# Train_MinReturn : 41.236385345458984
# Train_AverageEpLen : 64.02547770700637
# Train_EnvstepsSoFar : 270596
# TimeSinceStart : 103.82392883300781
# Training Loss : 129.922607421875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.55315399169922
# Eval_StdReturn : 53.065673828125
# Eval_MaxReturn : 212.52931213378906
# Eval_MinReturn : 42.91816329956055
# Eval_AverageEpLen : 67.4
# Train_AverageReturn : 115.92313385009766
# Train_StdReturn : 52.34371566772461
# Train_MaxReturn : 253.9870147705078
# Train_MinReturn : 42.40928649902344
# Train_AverageEpLen : 65.31168831168831
# Train_EnvstepsSoFar : 280654
# TimeSinceStart : 107.51110100746155
# Training Loss : 129.81622314453125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 123.58348083496094
# Eval_StdReturn : 31.3983154296875
# Eval_MaxReturn : 194.26136779785156
# Eval_MinReturn : 80.60807037353516
# Eval_AverageEpLen : 68.46666666666667
# Train_AverageReturn : 114.88992309570312
# Train_StdReturn : 48.8942756652832
# Train_MaxReturn : 207.8988037109375
# Train_MinReturn : 41.12160873413086
# Train_AverageEpLen : 64.69032258064516
# Train_EnvstepsSoFar : 290681
# TimeSinceStart : 111.19240283966064
# Training Loss : 130.5397186279297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 131.87911987304688
# Eval_StdReturn : 36.5192985534668
# Eval_MaxReturn : 180.6790771484375
# Eval_MinReturn : 48.185447692871094
# Eval_AverageEpLen : 72.66666666666667
# Train_AverageReturn : 126.8795166015625
# Train_StdReturn : 45.40519714355469
# Train_MaxReturn : 207.01368713378906
# Train_MinReturn : 38.747825622558594
# Train_AverageEpLen : 69.67361111111111
# Train_EnvstepsSoFar : 300714
# TimeSinceStart : 114.94796681404114
# Training Loss : 132.7284698486328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.23023223876953
# Eval_StdReturn : 34.872005462646484
# Eval_MaxReturn : 194.96351623535156
# Eval_MinReturn : 45.54852294921875
# Eval_AverageEpLen : 68.33333333333333
# Train_AverageReturn : 140.1240234375
# Train_StdReturn : 42.41141128540039
# Train_MaxReturn : 207.14199829101562
# Train_MinReturn : 41.96757507324219
# Train_AverageEpLen : 75.21804511278195
# Train_EnvstepsSoFar : 310718
# TimeSinceStart : 118.65622878074646
# Training Loss : 133.50636291503906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10058 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 117.70587158203125
# Eval_StdReturn : 23.509370803833008
# Eval_MaxReturn : 152.8641815185547
# Eval_MinReturn : 77.03972625732422
# Eval_AverageEpLen : 63.9375
# Train_AverageReturn : 126.97855377197266
# Train_StdReturn : 36.38037872314453
# Train_MaxReturn : 216.16429138183594
# Train_MinReturn : 37.34449005126953
# Train_AverageEpLen : 68.421768707483
# Train_EnvstepsSoFar : 320776
# TimeSinceStart : 122.36903524398804
# Training Loss : 133.10122680664062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10081 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.14148712158203
# Eval_StdReturn : 14.751232147216797
# Eval_MaxReturn : 129.15496826171875
# Eval_MinReturn : 85.92543029785156
# Eval_AverageEpLen : 56.611111111111114
# Train_AverageReturn : 111.58787536621094
# Train_StdReturn : 33.61490249633789
# Train_MaxReturn : 187.884765625
# Train_MinReturn : 35.31318664550781
# Train_AverageEpLen : 61.096969696969694
# Train_EnvstepsSoFar : 330857
# TimeSinceStart : 126.08678007125854
# Training Loss : 130.8570098876953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10029 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.66219329833984
# Eval_StdReturn : 31.918458938598633
# Eval_MaxReturn : 151.39431762695312
# Eval_MinReturn : 36.759368896484375
# Eval_AverageEpLen : 50.95
# Train_AverageReturn : 103.59921264648438
# Train_StdReturn : 26.5778751373291
# Train_MaxReturn : 171.33627319335938
# Train_MinReturn : 37.130210876464844
# Train_AverageEpLen : 56.98295454545455
# Train_EnvstepsSoFar : 340886
# TimeSinceStart : 129.8368899822235
# Training Loss : 129.59068298339844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.80815887451172
# Eval_StdReturn : 17.82728385925293
# Eval_MaxReturn : 138.0428466796875
# Eval_MinReturn : 59.897796630859375
# Eval_AverageEpLen : 52.55
# Train_AverageReturn : 97.16329193115234
# Train_StdReturn : 23.037033081054688
# Train_MaxReturn : 159.3945770263672
# Train_MinReturn : 38.50404739379883
# Train_AverageEpLen : 53.481283422459896
# Train_EnvstepsSoFar : 350887
# TimeSinceStart : 133.50683879852295
# Training Loss : 128.47633361816406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 82.03057098388672
# Eval_StdReturn : 19.94808578491211
# Eval_MaxReturn : 124.39543151855469
# Eval_MinReturn : 48.250701904296875
# Eval_AverageEpLen : 45.54545454545455
# Train_AverageReturn : 92.24840545654297
# Train_StdReturn : 20.580204010009766
# Train_MaxReturn : 145.45364379882812
# Train_MinReturn : 22.597923278808594
# Train_AverageEpLen : 50.796954314720814
# Train_EnvstepsSoFar : 360894
# TimeSinceStart : 137.21791577339172
# Training Loss : 127.65552520751953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10039 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 77.77943420410156
# Eval_StdReturn : 16.500518798828125
# Eval_MaxReturn : 110.01080322265625
# Eval_MinReturn : 50.228111267089844
# Eval_AverageEpLen : 42.958333333333336
# Train_AverageReturn : 86.1993637084961
# Train_StdReturn : 17.859458923339844
# Train_MaxReturn : 143.62908935546875
# Train_MinReturn : 37.07295227050781
# Train_AverageEpLen : 47.5781990521327
# Train_EnvstepsSoFar : 370933
# TimeSinceStart : 140.94817066192627
# Training Loss : 126.16703033447266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 78.59605407714844
# Eval_StdReturn : 16.620569229125977
# Eval_MaxReturn : 108.08660125732422
# Eval_MinReturn : 50.32783508300781
# Eval_AverageEpLen : 43.69565217391305
# Train_AverageReturn : 80.43963623046875
# Train_StdReturn : 15.549235343933105
# Train_MaxReturn : 130.14578247070312
# Train_MinReturn : 37.40172576904297
# Train_AverageEpLen : 44.61333333333334
# Train_EnvstepsSoFar : 380971
# TimeSinceStart : 144.66805148124695
# Training Loss : 124.4603500366211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10060 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 86.6921615600586
# Eval_StdReturn : 13.38234806060791
# Eval_MaxReturn : 116.7852783203125
# Eval_MinReturn : 54.21843719482422
# Eval_AverageEpLen : 48.23809523809524
# Train_AverageReturn : 82.34645080566406
# Train_StdReturn : 14.880135536193848
# Train_MaxReturn : 121.48330688476562
# Train_MinReturn : 46.27012252807617
# Train_AverageEpLen : 45.72727272727273
# Train_EnvstepsSoFar : 391031
# TimeSinceStart : 148.38252472877502
# Training Loss : 124.99905395507812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 93.76551818847656
# Eval_StdReturn : 16.55943489074707
# Eval_MaxReturn : 129.2101593017578
# Eval_MinReturn : 58.562644958496094
# Eval_AverageEpLen : 51.75
# Train_AverageReturn : 88.69358825683594
# Train_StdReturn : 15.92227554321289
# Train_MaxReturn : 143.28536987304688
# Train_MinReturn : 43.92194366455078
# Train_AverageEpLen : 49.11764705882353
# Train_EnvstepsSoFar : 401051
# TimeSinceStart : 152.12998819351196
# Training Loss : 126.72847747802734
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.99425506591797
# Eval_StdReturn : 22.16654396057129
# Eval_MaxReturn : 137.09979248046875
# Eval_MinReturn : 23.135826110839844
# Eval_AverageEpLen : 53.10526315789474
# Train_AverageReturn : 93.14408874511719
# Train_StdReturn : 15.812093734741211
# Train_MaxReturn : 137.53102111816406
# Train_MinReturn : 17.083820343017578
# Train_AverageEpLen : 51.56185567010309
# Train_EnvstepsSoFar : 411054
# TimeSinceStart : 155.8177146911621
# Training Loss : 128.343017578125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 106.7667465209961
# Eval_StdReturn : 18.359737396240234
# Eval_MaxReturn : 142.03927612304688
# Eval_MinReturn : 78.58026885986328
# Eval_AverageEpLen : 58.27777777777778
# Train_AverageReturn : 100.96939849853516
# Train_StdReturn : 18.640474319458008
# Train_MaxReturn : 138.91571044921875
# Train_MinReturn : 14.642831802368164
# Train_AverageEpLen : 55.605555555555554
# Train_EnvstepsSoFar : 421063
# TimeSinceStart : 159.54808020591736
# Training Loss : 130.1767120361328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 128.7934112548828
# Eval_StdReturn : 16.894023895263672
# Eval_MaxReturn : 152.0611572265625
# Eval_MinReturn : 96.31391143798828
# Eval_AverageEpLen : 67.66666666666667
# Train_AverageReturn : 108.89578247070312
# Train_StdReturn : 21.63385581970215
# Train_MaxReturn : 152.73052978515625
# Train_MinReturn : 12.861465454101562
# Train_AverageEpLen : 59.248520710059175
# Train_EnvstepsSoFar : 431076
# TimeSinceStart : 163.28021240234375
# Training Loss : 131.8635711669922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10061 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.1943817138672
# Eval_StdReturn : 16.0640869140625
# Eval_MaxReturn : 176.5811309814453
# Eval_MinReturn : 124.31786346435547
# Eval_AverageEpLen : 74.35714285714286
# Train_AverageReturn : 124.27532958984375
# Train_StdReturn : 25.78171730041504
# Train_MaxReturn : 165.40402221679688
# Train_MinReturn : 12.299071311950684
# Train_AverageEpLen : 65.75816993464052
# Train_EnvstepsSoFar : 441137
# TimeSinceStart : 167.0434238910675
# Training Loss : 133.53480529785156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10011 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.64244079589844
# Eval_StdReturn : 44.31842803955078
# Eval_MaxReturn : 176.14405822753906
# Eval_MinReturn : 14.227534294128418
# Eval_AverageEpLen : 65.5
# Train_AverageReturn : 132.35670471191406
# Train_StdReturn : 30.32261848449707
# Train_MaxReturn : 177.6813507080078
# Train_MinReturn : 18.25987434387207
# Train_AverageEpLen : 68.56849315068493
# Train_EnvstepsSoFar : 451148
# TimeSinceStart : 170.76198959350586
# Training Loss : 134.29287719726562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 150.3507537841797
# Eval_StdReturn : 17.588666915893555
# Eval_MaxReturn : 177.97348022460938
# Eval_MinReturn : 112.5879898071289
# Eval_AverageEpLen : 76.21428571428571
# Train_AverageReturn : 138.928955078125
# Train_StdReturn : 27.50916290283203
# Train_MaxReturn : 177.36227416992188
# Train_MinReturn : 20.57927131652832
# Train_AverageEpLen : 71.44285714285714
# Train_EnvstepsSoFar : 461150
# TimeSinceStart : 174.48599004745483
# Training Loss : 135.3843231201172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 159.08665466308594
# Eval_StdReturn : 34.70197296142578
# Eval_MaxReturn : 177.115234375
# Eval_MinReturn : 44.81084442138672
# Eval_AverageEpLen : 78.84615384615384
# Train_AverageReturn : 150.30801391601562
# Train_StdReturn : 33.608673095703125
# Train_MaxReturn : 180.10476684570312
# Train_MinReturn : 18.89841079711914
# Train_AverageEpLen : 75.26315789473684
# Train_EnvstepsSoFar : 471160
# TimeSinceStart : 178.16377115249634
# Training Loss : 136.68260192871094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.0750732421875
# Eval_StdReturn : 2.299009084701538
# Eval_MaxReturn : 175.2388153076172
# Eval_MinReturn : 167.69879150390625
# Eval_AverageEpLen : 84.91666666666667
# Train_AverageReturn : 165.7056121826172
# Train_StdReturn : 20.78539276123047
# Train_MaxReturn : 182.04727172851562
# Train_MinReturn : 24.282934188842773
# Train_AverageEpLen : 81.47967479674797
# Train_EnvstepsSoFar : 481182
# TimeSinceStart : 181.84998965263367
# Training Loss : 137.0007781982422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 149.4269256591797
# Eval_StdReturn : 53.725650787353516
# Eval_MaxReturn : 176.0715789794922
# Eval_MinReturn : 15.933306694030762
# Eval_AverageEpLen : 75.0
# Train_AverageReturn : 159.3872528076172
# Train_StdReturn : 40.34165573120117
# Train_MaxReturn : 179.21194458007812
# Train_MinReturn : 18.74356460571289
# Train_AverageEpLen : 79.03149606299213
# Train_EnvstepsSoFar : 491219
# TimeSinceStart : 185.59705471992493
# Training Loss : 136.26785278320312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.57139587402344
# Eval_StdReturn : 1.9106013774871826
# Eval_MaxReturn : 173.91192626953125
# Eval_MinReturn : 166.5130157470703
# Eval_AverageEpLen : 85.16666666666667
# Train_AverageReturn : 159.93386840820312
# Train_StdReturn : 36.42148971557617
# Train_MaxReturn : 178.56231689453125
# Train_MinReturn : 13.241260528564453
# Train_AverageEpLen : 79.76190476190476
# Train_EnvstepsSoFar : 501269
# TimeSinceStart : 189.3088195323944
# Training Loss : 136.1548309326172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 163.62977600097656
# Eval_StdReturn : 13.407233238220215
# Eval_MaxReturn : 172.84469604492188
# Eval_MinReturn : 126.84798431396484
# Eval_AverageEpLen : 82.0
# Train_AverageReturn : 168.2841033935547
# Train_StdReturn : 20.021215438842773
# Train_MaxReturn : 179.86737060546875
# Train_MinReturn : 24.097082138061523
# Train_AverageEpLen : 83.50833333333334
# Train_EnvstepsSoFar : 511290
# TimeSinceStart : 193.1021659374237
# Training Loss : 137.6942596435547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 153.90390014648438
# Eval_StdReturn : 18.257511138916016
# Eval_MaxReturn : 176.54293823242188
# Eval_MinReturn : 118.31675720214844
# Eval_AverageEpLen : 77.92307692307692
# Train_AverageReturn : 167.94790649414062
# Train_StdReturn : 10.090065002441406
# Train_MaxReturn : 183.08934020996094
# Train_MinReturn : 128.24681091308594
# Train_AverageEpLen : 83.0909090909091
# Train_EnvstepsSoFar : 521344
# TimeSinceStart : 196.83940887451172
# Training Loss : 139.1542510986328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.62258911132812
# Eval_StdReturn : 16.724536895751953
# Eval_MaxReturn : 130.77090454101562
# Eval_MinReturn : 68.02300262451172
# Eval_AverageEpLen : 52.63157894736842
# Train_AverageReturn : 145.26498413085938
# Train_StdReturn : 20.539072036743164
# Train_MaxReturn : 179.5684814453125
# Train_MinReturn : 84.20035552978516
# Train_AverageEpLen : 74.47407407407407
# Train_EnvstepsSoFar : 531398
# TimeSinceStart : 200.56988215446472
# Training Loss : 138.00596618652344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 78.12335968017578
# Eval_StdReturn : 13.746768951416016
# Eval_MaxReturn : 100.62397766113281
# Eval_MinReturn : 47.271549224853516
# Eval_AverageEpLen : 43.65217391304348
# Train_AverageReturn : 96.38733673095703
# Train_StdReturn : 17.405467987060547
# Train_MaxReturn : 143.66015625
# Train_MinReturn : 60.02995681762695
# Train_AverageEpLen : 53.18518518518518
# Train_EnvstepsSoFar : 541450
# TimeSinceStart : 204.3210859298706
# Training Loss : 132.04278564453125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 68.98177337646484
# Eval_StdReturn : 9.73865032196045
# Eval_MaxReturn : 92.70104217529297
# Eval_MinReturn : 44.07231521606445
# Eval_AverageEpLen : 38.57692307692308
# Train_AverageReturn : 72.52889251708984
# Train_StdReturn : 10.925904273986816
# Train_MaxReturn : 105.62384033203125
# Train_MinReturn : 47.870582580566406
# Train_AverageEpLen : 40.554655870445345
# Train_EnvstepsSoFar : 551467
# TimeSinceStart : 208.0778272151947
# Training Loss : 123.55882263183594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 65.33587646484375
# Eval_StdReturn : 8.639914512634277
# Eval_MaxReturn : 82.12549591064453
# Eval_MinReturn : 45.384761810302734
# Eval_AverageEpLen : 36.67857142857143
# Train_AverageReturn : 67.2869644165039
# Train_StdReturn : 10.538039207458496
# Train_MaxReturn : 105.990478515625
# Train_MinReturn : 43.49590301513672
# Train_AverageEpLen : 37.71052631578947
# Train_EnvstepsSoFar : 561498
# TimeSinceStart : 211.91612458229065
# Training Loss : 120.5276107788086
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.6038818359375
# Eval_StdReturn : 13.265512466430664
# Eval_MaxReturn : 107.05905151367188
# Eval_MinReturn : 54.968055725097656
# Eval_AverageEpLen : 41.958333333333336
# Train_AverageReturn : 67.13154602050781
# Train_StdReturn : 10.970938682556152
# Train_MaxReturn : 111.5554428100586
# Train_MinReturn : 43.890071868896484
# Train_AverageEpLen : 37.69924812030075
# Train_EnvstepsSoFar : 571526
# TimeSinceStart : 215.835107088089
# Training Loss : 120.35222625732422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 89.41249084472656
# Eval_StdReturn : 17.887306213378906
# Eval_MaxReturn : 133.1710968017578
# Eval_MinReturn : 64.0351333618164
# Eval_AverageEpLen : 49.476190476190474
# Train_AverageReturn : 74.08794403076172
# Train_StdReturn : 12.45932674407959
# Train_MaxReturn : 120.2807846069336
# Train_MinReturn : 48.913055419921875
# Train_AverageEpLen : 41.601659751037346
# Train_EnvstepsSoFar : 581552
# TimeSinceStart : 219.60757517814636
# Training Loss : 123.80300903320312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10024 / 1000000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 104.9821548461914
# Eval_StdReturn : 23.459150314331055
# Eval_MaxReturn : 156.93023681640625
# Eval_MinReturn : 63.63268280029297
# Eval_AverageEpLen : 56.72222222222222
# Train_AverageReturn : 88.72652435302734
# Train_StdReturn : 16.498979568481445
# Train_MaxReturn : 157.69903564453125
# Train_MinReturn : 57.847923278808594
# Train_AverageEpLen : 49.37931034482759
# Train_EnvstepsSoFar : 591576
# TimeSinceStart : 223.34975695610046
# Training Loss : 128.42723083496094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.92695617675781
# Eval_StdReturn : 15.92951488494873
# Eval_MaxReturn : 157.7980194091797
# Eval_MinReturn : 99.44721984863281
# Eval_AverageEpLen : 65.625
# Train_AverageReturn : 107.97962951660156
# Train_StdReturn : 20.466745376586914
# Train_MaxReturn : 157.22653198242188
# Train_MinReturn : 67.93350982666016
# Train_AverageEpLen : 58.343023255813954
# Train_EnvstepsSoFar : 601611
# TimeSinceStart : 227.13225507736206
# Training Loss : 131.7991180419922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10041 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 162.2919921875
# Eval_StdReturn : 23.76430320739746
# Eval_MaxReturn : 197.15158081054688
# Eval_MinReturn : 100.2401123046875
# Eval_AverageEpLen : 76.71428571428571
# Train_AverageReturn : 133.6638946533203
# Train_StdReturn : 22.143709182739258
# Train_MaxReturn : 192.8091583251953
# Train_MinReturn : 86.50883483886719
# Train_AverageEpLen : 67.8445945945946
# Train_EnvstepsSoFar : 611652
# TimeSinceStart : 230.87218832969666
# Training Loss : 134.7899169921875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.65234375
# Eval_StdReturn : 68.21249389648438
# Eval_MaxReturn : 186.78038024902344
# Eval_MinReturn : 26.16952133178711
# Eval_AverageEpLen : 62.05882352941177
# Train_AverageReturn : 162.06053161621094
# Train_StdReturn : 31.780277252197266
# Train_MaxReturn : 203.3453369140625
# Train_MinReturn : 27.192968368530273
# Train_AverageEpLen : 76.54198473282443
# Train_EnvstepsSoFar : 621679
# TimeSinceStart : 234.61100912094116
# Training Loss : 135.7525177001953
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 120.11892700195312
# Eval_StdReturn : 70.82867431640625
# Eval_MaxReturn : 204.40342712402344
# Eval_MinReturn : 20.956369400024414
# Eval_AverageEpLen : 59.5
# Train_AverageReturn : 135.0397491455078
# Train_StdReturn : 65.61478424072266
# Train_MaxReturn : 201.13365173339844
# Train_MinReturn : 17.30191993713379
# Train_AverageEpLen : 65.3896103896104
# Train_EnvstepsSoFar : 631749
# TimeSinceStart : 238.3613784313202
# Training Loss : 128.59451293945312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# ...
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.41728591918945
# Eval_StdReturn : 1.4652819633483887
# Eval_MaxReturn : 44.67605209350586
# Eval_MinReturn : 39.09672546386719
# Eval_AverageEpLen : 24.238095238095237
# Train_AverageReturn : 41.20857238769531
# Train_StdReturn : 1.6789065599441528
# Train_MaxReturn : 46.20045471191406
# Train_MinReturn : 36.85935974121094
# Train_AverageEpLen : 24.17149758454106
# Train_EnvstepsSoFar : 802001
# TimeSinceStart : 308.98610496520996
# Training Loss : 95.02247619628906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10021 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.253509521484375
# Eval_StdReturn : 1.7323559522628784
# Eval_MaxReturn : 46.399925231933594
# Eval_MinReturn : 39.1839714050293
# Eval_AverageEpLen : 24.634146341463413
# Train_AverageReturn : 41.65866470336914
# Train_StdReturn : 1.6470887660980225
# Train_MaxReturn : 47.92290115356445
# Train_MinReturn : 37.45978546142578
# Train_AverageEpLen : 24.381995133819952
# Train_EnvstepsSoFar : 812022
# TimeSinceStart : 313.14663529396057
# Training Loss : 96.20179748535156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.133880615234375
# Eval_StdReturn : 1.1217564344406128
# Eval_MaxReturn : 44.62654495239258
# Eval_MinReturn : 39.21855545043945
# Eval_AverageEpLen : 24.48780487804878
# Train_AverageReturn : 42.45100402832031
# Train_StdReturn : 1.6778723001480103
# Train_MaxReturn : 46.656044006347656
# Train_MinReturn : 37.510047912597656
# Train_AverageEpLen : 24.735802469135802
# Train_EnvstepsSoFar : 822040
# TimeSinceStart : 317.3390429019928
# Training Loss : 97.28495025634766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 43.1128044128418
# Eval_StdReturn : 1.8105180263519287
# Eval_MaxReturn : 46.91419982910156
# Eval_MinReturn : 39.455936431884766
# Eval_AverageEpLen : 25.05
# Train_AverageReturn : 42.88911437988281
# Train_StdReturn : 1.7276543378829956
# Train_MaxReturn : 47.98725891113281
# Train_MinReturn : 38.908782958984375
# Train_AverageEpLen : 24.922885572139304
# Train_EnvstepsSoFar : 832059
# TimeSinceStart : 321.5389151573181
# Training Loss : 97.46500396728516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.145381927490234
# Eval_StdReturn : 1.598261833190918
# Eval_MaxReturn : 46.50283432006836
# Eval_MinReturn : 38.94102478027344
# Eval_AverageEpLen : 24.48780487804878
# Train_AverageReturn : 43.029972076416016
# Train_StdReturn : 1.772732138633728
# Train_MaxReturn : 48.384830474853516
# Train_MinReturn : 37.72090148925781
# Train_AverageEpLen : 25.01
# Train_EnvstepsSoFar : 842063
# TimeSinceStart : 325.6241888999939
# Training Loss : 97.39523315429688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10005 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 42.02845001220703
# Eval_StdReturn : 1.3685826063156128
# Eval_MaxReturn : 45.16954803466797
# Eval_MinReturn : 39.210716247558594
# Eval_AverageEpLen : 24.4390243902439
# Train_AverageReturn : 42.50571060180664
# Train_StdReturn : 1.784428358078003
# Train_MaxReturn : 48.555633544921875
# Train_MinReturn : 37.7459831237793
# Train_AverageEpLen : 24.703703703703702
# Train_EnvstepsSoFar : 852068
# TimeSinceStart : 329.8480648994446
# Training Loss : 96.88815307617188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.77303695678711
# Eval_StdReturn : 2.05654239654541
# Eval_MaxReturn : 46.59153747558594
# Eval_MinReturn : 37.526424407958984
# Eval_AverageEpLen : 24.285714285714285
# Train_AverageReturn : 42.0922966003418
# Train_StdReturn : 1.6704026460647583
# Train_MaxReturn : 48.33454895019531
# Train_MinReturn : 37.35982894897461
# Train_AverageEpLen : 24.459657701711492
# Train_EnvstepsSoFar : 862072
# TimeSinceStart : 333.87465238571167
# Training Loss : 96.58721160888672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 100002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.88026428222656
# Eval_StdReturn : 1.4331071376800537
# Eval_MaxReturn : 46.240909576416016
# Eval_MinReturn : 38.9355583190918
# Eval_AverageEpLen : 24.4390243902439
# Train_AverageReturn : 41.61915588378906
# Train_StdReturn : 1.5790002346038818
# Train_MaxReturn : 46.24339294433594
# Train_MinReturn : 37.377254486083984
# Train_AverageEpLen : 24.220338983050848
# Train_EnvstepsSoFar : 872075
# TimeSinceStart : 337.8906338214874
# Training Loss : 96.06627655029297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 41.18578338623047
# Eval_StdReturn : 1.5249067544937134
# Eval_MaxReturn : 45.173526763916016
# Eval_MinReturn : 37.33751678466797
# Eval_AverageEpLen : 24.047619047619047
# Train_AverageReturn : 41.19816970825195
# Train_StdReturn : 1.6560949087142944
# Train_MaxReturn : 46.59083938598633
# Train_MinReturn : 35.67771911621094
# Train_AverageEpLen : 24.01199040767386
# Train_EnvstepsSoFar : 882088
# TimeSinceStart : 342.0075376033783
# Training Loss : 94.79735565185547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 40.22524642944336
# Eval_StdReturn : 1.4842510223388672
# Eval_MaxReturn : 43.448699951171875
# Eval_MinReturn : 37.08255386352539
# Eval_AverageEpLen : 23.58139534883721
# Train_AverageReturn : 40.61313247680664
# Train_StdReturn : 1.5134702920913696
# Train_MaxReturn : 46.609779357910156
# Train_MinReturn : 37.24627685546875
# Train_AverageEpLen : 23.72748815165877
# Train_EnvstepsSoFar : 892101
# TimeSinceStart : 346.0589735507965
# Training Loss : 93.85144805908203
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 39.941444396972656
# Eval_StdReturn : 1.3090087175369263
# Eval_MaxReturn : 42.80738830566406
# Eval_MinReturn : 37.463905334472656
# Eval_AverageEpLen : 23.441860465116278
# Train_AverageReturn : 39.941383361816406
# Train_StdReturn : 1.445513367652893
# Train_MaxReturn : 44.3900260925293
# Train_MinReturn : 36.687286376953125
# Train_AverageEpLen : 23.406542056074766
# Train_EnvstepsSoFar : 902119
# TimeSinceStart : 350.24744391441345
# Training Loss : 93.3196792602539
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 39.66938018798828
# Eval_StdReturn : 1.2459454536437988
# Eval_MaxReturn : 43.01422882080078
# Eval_MinReturn : 37.146785736083984
# Eval_AverageEpLen : 23.302325581395348
# Train_AverageReturn : 39.74378204345703
# Train_StdReturn : 1.3949370384216309
# Train_MaxReturn : 44.65604782104492
# Train_MinReturn : 35.78535461425781
# Train_AverageEpLen : 23.324009324009324
# Train_EnvstepsSoFar : 912125
# TimeSinceStart : 354.47873401641846
# Training Loss : 92.97514343261719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 39.699344635009766
# Eval_StdReturn : 1.1159051656723022
# Eval_MaxReturn : 42.235286712646484
# Eval_MinReturn : 37.357200622558594
# Eval_AverageEpLen : 23.348837209302324
# Train_AverageReturn : 39.7923469543457
# Train_StdReturn : 1.4935336112976074
# Train_MaxReturn : 44.702308654785156
# Train_MinReturn : 35.71806335449219
# Train_AverageEpLen : 23.364485981308412
# Train_EnvstepsSoFar : 922125
# TimeSinceStart : 358.68630957603455
# Training Loss : 92.47004699707031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10016 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.76352310180664
# Eval_StdReturn : 1.187689185142517
# Eval_MaxReturn : 41.18475341796875
# Eval_MinReturn : 36.81100845336914
# Eval_AverageEpLen : 22.84090909090909
# Train_AverageReturn : 39.61172866821289
# Train_StdReturn : 1.5238220691680908
# Train_MaxReturn : 44.7213134765625
# Train_MinReturn : 35.82837677001953
# Train_AverageEpLen : 23.293023255813953
# Train_EnvstepsSoFar : 932141
# TimeSinceStart : 362.8529562950134
# Training Loss : 92.30120086669922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10014 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.37027359008789
# Eval_StdReturn : 1.2665318250656128
# Eval_MaxReturn : 41.10552215576172
# Eval_MinReturn : 35.25660705566406
# Eval_AverageEpLen : 22.711111111111112
# Train_AverageReturn : 39.019744873046875
# Train_StdReturn : 1.4180107116699219
# Train_MaxReturn : 43.12035369873047
# Train_MinReturn : 35.44253158569336
# Train_AverageEpLen : 23.020689655172415
# Train_EnvstepsSoFar : 942155
# TimeSinceStart : 366.9646112918854
# Training Loss : 91.08879089355469
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 38.31401062011719
# Eval_StdReturn : 1.0492137670516968
# Eval_MaxReturn : 40.914093017578125
# Eval_MinReturn : 36.89099884033203
# Eval_AverageEpLen : 22.711111111111112
# Train_AverageReturn : 38.465702056884766
# Train_StdReturn : 1.2757922410964966
# Train_MaxReturn : 42.37416458129883
# Train_MinReturn : 35.20988845825195
# Train_AverageEpLen : 22.756818181818183
# Train_EnvstepsSoFar : 952168
# TimeSinceStart : 370.9716935157776
# Training Loss : 90.83687591552734
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.83064651489258
# Eval_StdReturn : 1.0444649457931519
# Eval_MaxReturn : 40.28437042236328
# Eval_MinReturn : 35.176231384277344
# Eval_AverageEpLen : 22.511111111111113
# Train_AverageReturn : 38.14840316772461
# Train_StdReturn : 1.2242871522903442
# Train_MaxReturn : 41.15391540527344
# Train_MinReturn : 35.206932067871094
# Train_AverageEpLen : 22.618510158013542
# Train_EnvstepsSoFar : 962188
# TimeSinceStart : 374.9995367527008
# Training Loss : 89.71353912353516
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.43921661376953
# Eval_StdReturn : 1.0824390649795532
# Eval_MaxReturn : 40.09156036376953
# Eval_MinReturn : 35.364532470703125
# Eval_AverageEpLen : 22.31111111111111
# Train_AverageReturn : 37.80799865722656
# Train_StdReturn : 1.0261402130126953
# Train_MaxReturn : 40.85700225830078
# Train_MinReturn : 35.059959411621094
# Train_AverageEpLen : 22.474157303370788
# Train_EnvstepsSoFar : 972189
# TimeSinceStart : 379.0167443752289
# Training Loss : 89.53067779541016
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10012 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.27388381958008
# Eval_StdReturn : 1.0974290370941162
# Eval_MaxReturn : 40.462093353271484
# Eval_MinReturn : 34.98478317260742
# Eval_AverageEpLen : 22.244444444444444
# Train_AverageReturn : 37.40652084350586
# Train_StdReturn : 0.9579145908355713
# Train_MaxReturn : 40.87410354614258
# Train_MinReturn : 35.103172302246094
# Train_AverageEpLen : 22.298440979955455
# Train_EnvstepsSoFar : 982201
# TimeSinceStart : 383.06987404823303
# Training Loss : 88.89396667480469
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10003 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.14036178588867
# Eval_StdReturn : 0.9926949143409729
# Eval_MaxReturn : 38.756771087646484
# Eval_MinReturn : 34.81123733520508
# Eval_AverageEpLen : 22.217391304347824
# Train_AverageReturn : 37.38826370239258
# Train_StdReturn : 0.9774695038795471
# Train_MaxReturn : 40.262603759765625
# Train_MinReturn : 34.95270538330078
# Train_AverageEpLen : 22.328125
# Train_EnvstepsSoFar : 992204
# TimeSinceStart : 387.09859919548035
# Training Loss : 88.10403442382812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 1000010000 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 37.274845123291016
# Eval_StdReturn : 0.896681547164917
# Eval_MaxReturn : 38.81358337402344
# Eval_MinReturn : 35.10451889038086
# Eval_AverageEpLen : 22.333333333333332
# Train_AverageReturn : 37.17388153076172
# Train_StdReturn : 0.9245229363441467
# Train_MaxReturn : 40.22592544555664
# Train_MinReturn : 34.846343994140625
# Train_AverageEpLen : 22.235555555555557
# Train_EnvstepsSoFar : 1002210
# TimeSinceStart : 391.2881064414978
# Training Loss : 87.9344253540039
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/return_to_go/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/return_to_go/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()
# Out:
# Folder logs/policy_gradient/Hopper/return_to_go/ does not exist yet. No old results to delete
# Running policy gradient experiment with seed 0
# ########################
# logging outputs to  logs/policy_gradient/Hopper/return_to_go/seed0
# ########################
# Using CPU for this assignment. There may be some bugs with using GPU that cause test cases to not match. You can uncomment the code below if you want to try using it.
# Hopper-v2
#
#
# ********** Iteration 0 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 97.36431121826172
# Eval_StdReturn : 56.1705207824707
# Eval_MaxReturn : 247.20233154296875
# Eval_MinReturn : 17.86540985107422
# Eval_AverageEpLen : 61.64705882352941
# Train_AverageReturn : 9.657980918884277
# Train_StdReturn : 5.853752613067627
# Train_MaxReturn : 87.45542907714844
# Train_MinReturn : 3.010934352874756
# Train_AverageEpLen : 13.215323645970939
# Train_EnvstepsSoFar : 10004
# TimeSinceStart : 4.179918050765991
# Training Loss : 18.090417861938477
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 1 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 74.83673095703125
# Eval_StdReturn : 12.586797714233398
# Eval_MaxReturn : 109.0075912475586
# Eval_MinReturn : 55.418758392333984
# Eval_AverageEpLen : 44.95652173913044
# Train_AverageReturn : 86.47571563720703
# Train_StdReturn : 52.808433532714844
# Train_MaxReturn : 252.57847595214844
# Train_MinReturn : 6.542727947235107
# Train_AverageEpLen : 54.5
# Train_EnvstepsSoFar : 20032
# TimeSinceStart : 8.334426164627075
# Training Loss : 102.84622192382812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 2 ************
#
# Collecting data to be used for training...
# At timestep:     10022 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 88.26393127441406
# Eval_StdReturn : 14.384305000305176
# Eval_MaxReturn : 124.45770263671875
# Eval_MinReturn : 65.53836059570312
# Eval_AverageEpLen : 51.2
# Train_AverageReturn : 79.2903060913086
# Train_StdReturn : 17.705259323120117
# Train_MaxReturn : 178.68356323242188
# Train_MinReturn : 55.416194915771484
# Train_AverageEpLen : 47.72380952380952
# Train_EnvstepsSoFar : 30054
# TimeSinceStart : 12.407664775848389
# Training Loss : 98.99421691894531
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 3 ************
#
# Collecting data to be used for training...
# At timestep:     10010 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 122.05274963378906
# Eval_StdReturn : 34.17659378051758
# Eval_MaxReturn : 192.69754028320312
# Eval_MinReturn : 78.61380004882812
# Eval_AverageEpLen : 63.9375
# Train_AverageReturn : 87.70250701904297
# Train_StdReturn : 19.838712692260742
# Train_MaxReturn : 171.647216796875
# Train_MinReturn : 59.1412353515625
# Train_AverageEpLen : 50.55555555555556
# Train_EnvstepsSoFar : 40064
# TimeSinceStart : 16.52573537826538
# Training Loss : 106.54765319824219
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 4 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 204.439208984375
# Eval_StdReturn : 37.10128402709961
# Eval_MaxReturn : 253.41510009765625
# Eval_MinReturn : 127.92462158203125
# Eval_AverageEpLen : 101.27272727272727
# Train_AverageReturn : 117.80029296875
# Train_StdReturn : 33.66783142089844
# Train_MaxReturn : 235.24742126464844
# Train_MinReturn : 75.37960815429688
# Train_AverageEpLen : 63.22641509433962
# Train_EnvstepsSoFar : 50117
# TimeSinceStart : 20.69614577293396
# Training Loss : 124.14750671386719
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 5 ************
#
# Collecting data to be used for training...
# At timestep:     10069 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.0036163330078
# Eval_StdReturn : 37.31689453125
# Eval_MaxReturn : 233.3486328125
# Eval_MinReturn : 117.33634185791016
# Eval_AverageEpLen : 86.58333333333333
# Train_AverageReturn : 208.6101531982422
# Train_StdReturn : 29.258203506469727
# Train_MaxReturn : 249.9329833984375
# Train_MinReturn : 90.5279769897461
# Train_AverageEpLen : 97.75728155339806
# Train_EnvstepsSoFar : 60186
# TimeSinceStart : 24.91555118560791
# Training Loss : 158.02334594726562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 6 ************
#
# Collecting data to be used for training...
# At timestep:     10085 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.24102783203125
# Eval_StdReturn : 33.963134765625
# Eval_MaxReturn : 214.28529357910156
# Eval_MinReturn : 108.93869018554688
# Eval_AverageEpLen : 83.0
# Train_AverageReturn : 173.17965698242188
# Train_StdReturn : 36.935935974121094
# Train_MaxReturn : 234.86814880371094
# Train_MinReturn : 75.32490539550781
# Train_AverageEpLen : 84.74789915966386
# Train_EnvstepsSoFar : 70271
# TimeSinceStart : 29.14409637451172
# Training Loss : 147.06405639648438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 7 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 204.34104919433594
# Eval_StdReturn : 6.015242576599121
# Eval_MaxReturn : 212.8243408203125
# Eval_MinReturn : 194.9951934814453
# Eval_AverageEpLen : 92.36363636363636
# Train_AverageReturn : 164.35433959960938
# Train_StdReturn : 40.764888763427734
# Train_MaxReturn : 226.33026123046875
# Train_MinReturn : 65.3590316772461
# Train_AverageEpLen : 80.208
# Train_EnvstepsSoFar : 80297
# TimeSinceStart : 33.223843574523926
# Training Loss : 145.63157653808594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 8 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 209.54371643066406
# Eval_StdReturn : 3.834822416305542
# Eval_MaxReturn : 217.867919921875
# Eval_MinReturn : 204.47509765625
# Eval_AverageEpLen : 93.18181818181819
# Train_AverageReturn : 201.54019165039062
# Train_StdReturn : 19.115367889404297
# Train_MaxReturn : 220.65673828125
# Train_MinReturn : 73.4827880859375
# Train_AverageEpLen : 91.08181818181818
# Train_EnvstepsSoFar : 90316
# TimeSinceStart : 37.469082832336426
# Training Loss : 162.21112060546875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 9 ************
#
# Collecting data to be used for training...
# At timestep:     10074 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 198.4326934814453
# Eval_StdReturn : 14.318503379821777
# Eval_MaxReturn : 213.56265258789062
# Eval_MinReturn : 170.51968383789062
# Eval_AverageEpLen : 88.0
# Train_AverageReturn : 206.35398864746094
# Train_StdReturn : 5.464110374450684
# Train_MaxReturn : 223.58761596679688
# Train_MinReturn : 185.19419860839844
# Train_AverageEpLen : 91.58181818181818
# Train_EnvstepsSoFar : 100390
# TimeSinceStart : 41.80641269683838
# Training Loss : 164.51707458496094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 10 ************
#
# Collecting data to be used for training...
# At timestep:     10001 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 161.2552490234375
# Eval_StdReturn : 12.773508071899414
# Eval_MaxReturn : 180.13121032714844
# Eval_MinReturn : 139.32969665527344
# Eval_AverageEpLen : 76.78571428571429
# Train_AverageReturn : 189.26333618164062
# Train_StdReturn : 13.608909606933594
# Train_MaxReturn : 214.14674377441406
# Train_MinReturn : 157.03042602539062
# Train_AverageEpLen : 85.47863247863248
# Train_EnvstepsSoFar : 110391
# TimeSinceStart : 46.04731464385986
# Training Loss : 159.10665893554688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 11 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 140.23858642578125
# Eval_StdReturn : 10.992063522338867
# Eval_MaxReturn : 162.62258911132812
# Eval_MinReturn : 119.21286010742188
# Eval_AverageEpLen : 70.93333333333334
# Train_AverageReturn : 159.1195831298828
# Train_StdReturn : 12.775726318359375
# Train_MaxReturn : 198.3740234375
# Train_MinReturn : 123.71128845214844
# Train_AverageEpLen : 76.03030303030303
# Train_EnvstepsSoFar : 120427
# TimeSinceStart : 50.199158906936646
# Training Loss : 145.79638671875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 12 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 131.26942443847656
# Eval_StdReturn : 12.774483680725098
# Eval_MaxReturn : 154.12969970703125
# Eval_MinReturn : 105.26417541503906
# Eval_AverageEpLen : 67.6
# Train_AverageReturn : 140.7150115966797
# Train_StdReturn : 10.505805969238281
# Train_MaxReturn : 178.30657958984375
# Train_MinReturn : 113.86709594726562
# Train_AverageEpLen : 70.61971830985915
# Train_EnvstepsSoFar : 130455
# TimeSinceStart : 54.241318464279175
# Training Loss : 135.0846405029297
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 13 ************
#
# Collecting data to be used for training...
# At timestep:     10046 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 125.27049255371094
# Eval_StdReturn : 10.049093246459961
# Eval_MaxReturn : 148.419921875
# Eval_MinReturn : 110.34635162353516
# Eval_AverageEpLen : 66.1875
# Train_AverageReturn : 131.15570068359375
# Train_StdReturn : 10.915165901184082
# Train_MaxReturn : 167.1441192626953
# Train_MinReturn : 105.14949798583984
# Train_AverageEpLen : 67.87837837837837
# Train_EnvstepsSoFar : 140501
# TimeSinceStart : 58.28421878814697
# Training Loss : 129.59658813476562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 14 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 138.60755920410156
# Eval_StdReturn : 15.219644546508789
# Eval_MaxReturn : 175.6961212158203
# Eval_MinReturn : 114.1953353881836
# Eval_AverageEpLen : 71.64285714285714
# Train_AverageReturn : 131.0641632080078
# Train_StdReturn : 14.592915534973145
# Train_MaxReturn : 173.2026824951172
# Train_MinReturn : 98.16301727294922
# Train_AverageEpLen : 68.58219178082192
# Train_EnvstepsSoFar : 150514
# TimeSinceStart : 62.282886028289795
# Training Loss : 127.68852996826172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 15 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.47877502441406
# Eval_StdReturn : 28.021360397338867
# Eval_MaxReturn : 224.84576416015625
# Eval_MinReturn : 138.9549102783203
# Eval_AverageEpLen : 89.33333333333333
# Train_AverageReturn : 137.39425659179688
# Train_StdReturn : 16.997339248657227
# Train_MaxReturn : 189.712158203125
# Train_MinReturn : 105.09909057617188
# Train_AverageEpLen : 71.80714285714286
# Train_EnvstepsSoFar : 160567
# TimeSinceStart : 66.38264346122742
# Training Loss : 129.9507293701172
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 16 ************
#
# Collecting data to be used for training...
# At timestep:     10019 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 201.80967712402344
# Eval_StdReturn : 13.153191566467285
# Eval_MaxReturn : 219.28799438476562
# Eval_MinReturn : 174.58328247070312
# Eval_AverageEpLen : 104.4
# Train_AverageReturn : 165.91244506835938
# Train_StdReturn : 21.7536563873291
# Train_MaxReturn : 218.23179626464844
# Train_MinReturn : 110.58609771728516
# Train_AverageEpLen : 84.19327731092437
# Train_EnvstepsSoFar : 170586
# TimeSinceStart : 70.46817755699158
# Training Loss : 138.342041015625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 17 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 200.42782592773438
# Eval_StdReturn : 5.375544548034668
# Eval_MaxReturn : 206.199951171875
# Eval_MinReturn : 186.7787322998047
# Eval_AverageEpLen : 105.3
# Train_AverageReturn : 199.4655303955078
# Train_StdReturn : 17.905969619750977
# Train_MaxReturn : 228.84002685546875
# Train_MinReturn : 137.13107299804688
# Train_AverageEpLen : 101.34343434343434
# Train_EnvstepsSoFar : 180619
# TimeSinceStart : 74.61341619491577
# Training Loss : 143.31674194335938
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 18 ************
#
# Collecting data to be used for training...
# At timestep:     10073 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 196.05873107910156
# Eval_StdReturn : 12.14769172668457
# Eval_MaxReturn : 214.01220703125
# Eval_MinReturn : 172.02487182617188
# Eval_AverageEpLen : 106.4
# Train_AverageReturn : 200.97427368164062
# Train_StdReturn : 18.72409439086914
# Train_MaxReturn : 223.53195190429688
# Train_MinReturn : 94.47469329833984
# Train_AverageEpLen : 103.84536082474227
# Train_EnvstepsSoFar : 190692
# TimeSinceStart : 78.75502038002014
# Training Loss : 140.61561584472656
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 19 ************
#
# Collecting data to be used for training...
# At timestep:     10109 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 188.43031311035156
# Eval_StdReturn : 31.755346298217773
# Eval_MaxReturn : 215.36964416503906
# Eval_MinReturn : 107.61174774169922
# Eval_AverageEpLen : 102.1
# Train_AverageReturn : 187.63259887695312
# Train_StdReturn : 37.21247863769531
# Train_MaxReturn : 215.7736358642578
# Train_MinReturn : 46.698795318603516
# Train_AverageEpLen : 100.08910891089108
# Train_EnvstepsSoFar : 200801
# TimeSinceStart : 82.95621132850647
# Training Loss : 134.64065551757812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 20 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 192.36474609375
# Eval_StdReturn : 33.07021713256836
# Eval_MaxReturn : 222.39292907714844
# Eval_MinReturn : 122.65591430664062
# Eval_AverageEpLen : 99.18181818181819
# Train_AverageReturn : 181.9349822998047
# Train_StdReturn : 49.51546859741211
# Train_MaxReturn : 222.49473571777344
# Train_MinReturn : 29.660518646240234
# Train_AverageEpLen : 96.6923076923077
# Train_EnvstepsSoFar : 210857
# TimeSinceStart : 87.20281434059143
# Training Loss : 135.39137268066406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 21 ************
#
# Collecting data to be used for training...
# At timestep:     10089 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 197.78404235839844
# Eval_StdReturn : 8.72984504699707
# Eval_MaxReturn : 210.07962036132812
# Eval_MinReturn : 177.74998474121094
# Eval_AverageEpLen : 96.0909090909091
# Train_AverageReturn : 199.0493621826172
# Train_StdReturn : 23.830904006958008
# Train_MaxReturn : 225.06964111328125
# Train_MinReturn : 48.69042205810547
# Train_AverageEpLen : 101.9090909090909
# Train_EnvstepsSoFar : 220946
# TimeSinceStart : 91.36685991287231
# Training Loss : 142.53271484375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 22 ************
#
# Collecting data to be used for training...
# At timestep:     10084 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 191.65496826171875
# Eval_StdReturn : 13.562765121459961
# Eval_MaxReturn : 215.64971923828125
# Eval_MinReturn : 169.80752563476562
# Eval_AverageEpLen : 92.63636363636364
# Train_AverageReturn : 200.20040893554688
# Train_StdReturn : 10.449891090393066
# Train_MaxReturn : 219.17135620117188
# Train_MinReturn : 167.64268493652344
# Train_AverageEpLen : 97.90291262135922
# Train_EnvstepsSoFar : 231030
# TimeSinceStart : 95.52759623527527
# Training Loss : 148.35800170898438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 23 ************
#
# Collecting data to be used for training...
# At timestep:     10071 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.81092834472656
# Eval_StdReturn : 17.677886962890625
# Eval_MaxReturn : 196.5238037109375
# Eval_MinReturn : 130.8544158935547
# Eval_AverageEpLen : 83.83333333333333
# Train_AverageReturn : 182.9649200439453
# Train_StdReturn : 20.923179626464844
# Train_MaxReturn : 220.8953857421875
# Train_MinReturn : 122.9230728149414
# Train_AverageEpLen : 89.12389380530973
# Train_EnvstepsSoFar : 241101
# TimeSinceStart : 99.63612151145935
# Training Loss : 145.794189453125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 24 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 150.61122131347656
# Eval_StdReturn : 12.697397232055664
# Eval_MaxReturn : 176.34852600097656
# Eval_MinReturn : 130.8314971923828
# Eval_AverageEpLen : 75.28571428571429
# Train_AverageReturn : 166.52606201171875
# Train_StdReturn : 20.318090438842773
# Train_MaxReturn : 206.48934936523438
# Train_MinReturn : 120.48098754882812
# Train_AverageEpLen : 81.58536585365853
# Train_EnvstepsSoFar : 251136
# TimeSinceStart : 103.70215702056885
# Training Loss : 142.5225372314453
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 25 ************
#
# Collecting data to be used for training...
# At timestep:     10006 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 162.72695922851562
# Eval_StdReturn : 14.773974418640137
# Eval_MaxReturn : 181.1416778564453
# Eval_MinReturn : 130.03256225585938
# Eval_AverageEpLen : 80.0
# Train_AverageReturn : 155.5658721923828
# Train_StdReturn : 17.737834930419922
# Train_MaxReturn : 210.06723022460938
# Train_MinReturn : 116.9234848022461
# Train_AverageEpLen : 76.96923076923076
# Train_EnvstepsSoFar : 261142
# TimeSinceStart : 107.67468047142029
# Training Loss : 139.1630096435547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 26 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.05235290527344
# Eval_StdReturn : 5.573741436004639
# Eval_MaxReturn : 183.11676025390625
# Eval_MinReturn : 162.59837341308594
# Eval_AverageEpLen : 85.25
# Train_AverageReturn : 160.34173583984375
# Train_StdReturn : 15.238381385803223
# Train_MaxReturn : 189.51553344726562
# Train_MinReturn : 114.21886444091797
# Train_AverageEpLen : 78.81102362204724
# Train_EnvstepsSoFar : 271151
# TimeSinceStart : 111.68702745437622
# Training Loss : 139.75347900390625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 27 ************
#
# Collecting data to be used for training...
# At timestep:     10066 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.5614471435547
# Eval_StdReturn : 6.5150251388549805
# Eval_MaxReturn : 185.81765747070312
# Eval_MinReturn : 161.80520629882812
# Eval_AverageEpLen : 86.41666666666667
# Train_AverageReturn : 172.1941375732422
# Train_StdReturn : 11.68779468536377
# Train_MaxReturn : 188.6632537841797
# Train_MinReturn : 123.8778305053711
# Train_AverageEpLen : 83.88333333333334
# Train_EnvstepsSoFar : 281217
# TimeSinceStart : 115.75215578079224
# Training Loss : 142.75308227539062
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 28 ************
#
# Collecting data to be used for training...
# At timestep:     10035 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 176.14369201660156
# Eval_StdReturn : 4.194316387176514
# Eval_MaxReturn : 179.93643188476562
# Eval_MinReturn : 165.73818969726562
# Eval_AverageEpLen : 86.75
# Train_AverageReturn : 176.80384826660156
# Train_StdReturn : 6.183959484100342
# Train_MaxReturn : 189.55459594726562
# Train_MinReturn : 139.20944213867188
# Train_AverageEpLen : 86.50862068965517
# Train_EnvstepsSoFar : 291252
# TimeSinceStart : 119.80444431304932
# Training Loss : 143.7069091796875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 29 ************
#
# Collecting data to be used for training...
# At timestep:     10004 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 175.79344177246094
# Eval_StdReturn : 3.754462480545044
# Eval_MaxReturn : 182.17420959472656
# Eval_MinReturn : 169.69761657714844
# Eval_AverageEpLen : 87.33333333333333
# Train_AverageReturn : 176.1944122314453
# Train_StdReturn : 4.19139289855957
# Train_MaxReturn : 184.52157592773438
# Train_MinReturn : 159.125244140625
# Train_AverageEpLen : 86.99130434782609
# Train_EnvstepsSoFar : 301256
# TimeSinceStart : 123.86821150779724
# Training Loss : 142.37600708007812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 30 ************
#
# Collecting data to be used for training...
# At timestep:     10056 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 172.4336395263672
# Eval_StdReturn : 4.045168399810791
# Eval_MaxReturn : 177.62930297851562
# Eval_MinReturn : 161.71327209472656
# Eval_AverageEpLen : 85.83333333333333
# Train_AverageReturn : 173.9627227783203
# Train_StdReturn : 4.983688831329346
# Train_MaxReturn : 184.6565704345703
# Train_MinReturn : 158.70791625976562
# Train_AverageEpLen : 86.6896551724138
# Train_EnvstepsSoFar : 311312
# TimeSinceStart : 127.97910380363464
# Training Loss : 139.8732147216797
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 31 ************
#
# Collecting data to be used for training...
# At timestep:     10081 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.42266845703125
# Eval_StdReturn : 3.0837016105651855
# Eval_MaxReturn : 178.4999542236328
# Eval_MinReturn : 166.96298217773438
# Eval_AverageEpLen : 86.41666666666667
# Train_AverageReturn : 171.8046417236328
# Train_StdReturn : 3.351032257080078
# Train_MaxReturn : 177.6395263671875
# Train_MinReturn : 161.56187438964844
# Train_AverageEpLen : 86.16239316239316
# Train_EnvstepsSoFar : 321393
# TimeSinceStart : 132.06918668746948
# Training Loss : 138.97532653808594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 32 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 173.43971252441406
# Eval_StdReturn : 2.5997512340545654
# Eval_MaxReturn : 177.48516845703125
# Eval_MinReturn : 168.19578552246094
# Eval_AverageEpLen : 85.75
# Train_AverageReturn : 171.6461639404297
# Train_StdReturn : 3.5957834720611572
# Train_MaxReturn : 178.58084106445312
# Train_MinReturn : 155.33151245117188
# Train_AverageEpLen : 85.91452991452991
# Train_EnvstepsSoFar : 331445
# TimeSinceStart : 136.10516929626465
# Training Loss : 139.17825317382812
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 33 ************
#
# Collecting data to be used for training...
# At timestep:     10057 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.8186492919922
# Eval_StdReturn : 3.929903030395508
# Eval_MaxReturn : 175.43850708007812
# Eval_MinReturn : 159.2039031982422
# Eval_AverageEpLen : 85.58333333333333
# Train_AverageReturn : 170.44850158691406
# Train_StdReturn : 3.3584916591644287
# Train_MaxReturn : 178.0572967529297
# Train_MinReturn : 156.7540283203125
# Train_AverageEpLen : 85.95726495726495
# Train_EnvstepsSoFar : 341502
# TimeSinceStart : 140.28247547149658
# Training Loss : 137.38636779785156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 34 ************
#
# Collecting data to be used for training...
# At timestep:     10033 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 169.24180603027344
# Eval_StdReturn : 2.456702947616577
# Eval_MaxReturn : 173.14425659179688
# Eval_MinReturn : 164.43954467773438
# Eval_AverageEpLen : 86.08333333333333
# Train_AverageReturn : 169.6229248046875
# Train_StdReturn : 3.578451156616211
# Train_MaxReturn : 178.60874938964844
# Train_MinReturn : 154.74221801757812
# Train_AverageEpLen : 85.75213675213675
# Train_EnvstepsSoFar : 351535
# TimeSinceStart : 144.38204622268677
# Training Loss : 136.84352111816406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 35 ************
#
# Collecting data to be used for training...
# At timestep:     10061 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 171.12489318847656
# Eval_StdReturn : 2.2950291633605957
# Eval_MaxReturn : 174.9005889892578
# Eval_MinReturn : 166.77430725097656
# Eval_AverageEpLen : 86.41666666666667
# Train_AverageReturn : 170.347900390625
# Train_StdReturn : 3.126692771911621
# Train_MaxReturn : 176.67945861816406
# Train_MinReturn : 161.21649169921875
# Train_AverageEpLen : 85.99145299145299
# Train_EnvstepsSoFar : 361596
# TimeSinceStart : 148.49119329452515
# Training Loss : 137.47735595703125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 36 ************
#
# Collecting data to be used for training...
# At timestep:     10064 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.97142028808594
# Eval_StdReturn : 2.8976047039031982
# Eval_MaxReturn : 175.73565673828125
# Eval_MinReturn : 166.42178344726562
# Eval_AverageEpLen : 86.0
# Train_AverageReturn : 170.39297485351562
# Train_StdReturn : 2.823627233505249
# Train_MaxReturn : 176.9832305908203
# Train_MinReturn : 163.1257781982422
# Train_AverageEpLen : 86.01709401709402
# Train_EnvstepsSoFar : 371660
# TimeSinceStart : 152.5982801914215
# Training Loss : 137.03634643554688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 37 ************
#
# Collecting data to be used for training...
# At timestep:     10027 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.26426696777344
# Eval_StdReturn : 20.854480743408203
# Eval_MaxReturn : 172.88687133789062
# Eval_MinReturn : 101.27407836914062
# Eval_AverageEpLen : 80.92307692307692
# Train_AverageReturn : 170.04527282714844
# Train_StdReturn : 7.163579940795898
# Train_MaxReturn : 177.1591796875
# Train_MinReturn : 105.70809936523438
# Train_AverageEpLen : 85.7008547008547
# Train_EnvstepsSoFar : 381687
# TimeSinceStart : 156.71803879737854
# Training Loss : 136.85279846191406
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 38 ************
#
# Collecting data to be used for training...
# At timestep:     10073 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 159.55368041992188
# Eval_StdReturn : 8.999040603637695
# Eval_MaxReturn : 172.98361206054688
# Eval_MinReturn : 144.49954223632812
# Eval_AverageEpLen : 81.0
# Train_AverageReturn : 160.29344177246094
# Train_StdReturn : 22.732851028442383
# Train_MaxReturn : 182.18978881835938
# Train_MinReturn : 56.107826232910156
# Train_AverageEpLen : 81.23387096774194
# Train_EnvstepsSoFar : 391760
# TimeSinceStart : 160.85903310775757
# Training Loss : 134.83908081054688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 39 ************
#
# Collecting data to be used for training...
# At timestep:     10054 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 152.76992797851562
# Eval_StdReturn : 29.296409606933594
# Eval_MaxReturn : 174.13726806640625
# Eval_MinReturn : 92.4282455444336
# Eval_AverageEpLen : 78.3076923076923
# Train_AverageReturn : 150.98556518554688
# Train_StdReturn : 26.91316795349121
# Train_MaxReturn : 177.5681915283203
# Train_MinReturn : 73.19557189941406
# Train_AverageEpLen : 77.33846153846154
# Train_EnvstepsSoFar : 401814
# TimeSinceStart : 164.98275661468506
# Training Loss : 131.1933135986328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 40 ************
#
# Collecting data to be used for training...
# At timestep:     10025 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 170.59837341308594
# Eval_StdReturn : 3.108614921569824
# Eval_MaxReturn : 173.75265502929688
# Eval_MinReturn : 162.70213317871094
# Eval_AverageEpLen : 86.16666666666667
# Train_AverageReturn : 157.3570098876953
# Train_StdReturn : 26.232698440551758
# Train_MaxReturn : 177.86497497558594
# Train_MinReturn : 62.3250617980957
# Train_AverageEpLen : 80.2
# Train_EnvstepsSoFar : 411839
# TimeSinceStart : 169.04050374031067
# Training Loss : 133.10655212402344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 41 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.24020385742188
# Eval_StdReturn : 3.9293336868286133
# Eval_MaxReturn : 172.90151977539062
# Eval_MinReturn : 159.57733154296875
# Eval_AverageEpLen : 85.5
# Train_AverageReturn : 168.0321807861328
# Train_StdReturn : 11.440220832824707
# Train_MaxReturn : 177.83078002929688
# Train_MinReturn : 95.41902923583984
# Train_AverageEpLen : 85.19491525423729
# Train_EnvstepsSoFar : 421892
# TimeSinceStart : 173.13967061042786
# Training Loss : 135.896240234375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 42 ************
#
# Collecting data to be used for training...
# At timestep:     10040 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.33018493652344
# Eval_StdReturn : 3.6947832107543945
# Eval_MaxReturn : 171.53822326660156
# Eval_MinReturn : 159.83917236328125
# Eval_AverageEpLen : 85.91666666666667
# Train_AverageReturn : 167.73336791992188
# Train_StdReturn : 8.304762840270996
# Train_MaxReturn : 173.82913208007812
# Train_MinReturn : 84.5905990600586
# Train_AverageEpLen : 85.8119658119658
# Train_EnvstepsSoFar : 431932
# TimeSinceStart : 177.27502346038818
# Training Loss : 134.6708526611328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 43 ************
#
# Collecting data to be used for training...
# At timestep:     10067 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.343017578125
# Eval_StdReturn : 3.220643997192383
# Eval_MaxReturn : 169.5284423828125
# Eval_MinReturn : 156.59274291992188
# Eval_AverageEpLen : 85.83333333333333
# Train_AverageReturn : 167.09715270996094
# Train_StdReturn : 3.1175074577331543
# Train_MaxReturn : 173.31446838378906
# Train_MinReturn : 158.96287536621094
# Train_AverageEpLen : 86.04273504273505
# Train_EnvstepsSoFar : 441999
# TimeSinceStart : 181.37071657180786
# Training Loss : 133.58641052246094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 44 ************
#
# Collecting data to be used for training...
# At timestep:     10070 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.28369140625
# Eval_StdReturn : 2.699766159057617
# Eval_MaxReturn : 167.32635498046875
# Eval_MinReturn : 158.0760955810547
# Eval_AverageEpLen : 86.16666666666667
# Train_AverageReturn : 166.2052459716797
# Train_StdReturn : 3.3594095706939697
# Train_MaxReturn : 171.6836395263672
# Train_MinReturn : 151.90206909179688
# Train_AverageEpLen : 86.06837606837607
# Train_EnvstepsSoFar : 452069
# TimeSinceStart : 185.4870798587799
# Training Loss : 132.44847106933594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 45 ************
#
# Collecting data to be used for training...
# At timestep:     10053 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 163.84915161132812
# Eval_StdReturn : 4.529066562652588
# Eval_MaxReturn : 168.9875946044922
# Eval_MinReturn : 153.5375518798828
# Eval_AverageEpLen : 85.41666666666667
# Train_AverageReturn : 165.15130615234375
# Train_StdReturn : 3.2805287837982178
# Train_MaxReturn : 171.84429931640625
# Train_MinReturn : 152.49615478515625
# Train_AverageEpLen : 85.92307692307692
# Train_EnvstepsSoFar : 462122
# TimeSinceStart : 189.63883781433105
# Training Loss : 131.638671875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 46 ************
#
# Collecting data to be used for training...
# At timestep:     10023 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 161.14515686035156
# Eval_StdReturn : 5.872198104858398
# Eval_MaxReturn : 166.67018127441406
# Eval_MinReturn : 146.13394165039062
# Eval_AverageEpLen : 84.83333333333333
# Train_AverageReturn : 164.21495056152344
# Train_StdReturn : 3.8293402194976807
# Train_MaxReturn : 171.17974853515625
# Train_MinReturn : 153.71250915527344
# Train_AverageEpLen : 85.66666666666667
# Train_EnvstepsSoFar : 472145
# TimeSinceStart : 193.74338293075562
# Training Loss : 131.4870147705078
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 47 ************
#
# Collecting data to be used for training...
# At timestep:     10074 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 161.4141082763672
# Eval_StdReturn : 4.598514080047607
# Eval_MaxReturn : 165.91392517089844
# Eval_MinReturn : 150.4883575439453
# Eval_AverageEpLen : 85.08333333333333
# Train_AverageReturn : 163.16802978515625
# Train_StdReturn : 4.276065826416016
# Train_MaxReturn : 169.763916015625
# Train_MinReturn : 145.9982147216797
# Train_AverageEpLen : 85.37288135593221
# Train_EnvstepsSoFar : 482219
# TimeSinceStart : 197.8601529598236
# Training Loss : 130.40896606445312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 48 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 162.3170166015625
# Eval_StdReturn : 4.345329284667969
# Eval_MaxReturn : 167.50408935546875
# Eval_MinReturn : 152.80999755859375
# Eval_AverageEpLen : 85.25
# Train_AverageReturn : 160.0402374267578
# Train_StdReturn : 5.971047878265381
# Train_MaxReturn : 169.40748596191406
# Train_MinReturn : 122.59687042236328
# Train_AverageEpLen : 84.34453781512605
# Train_EnvstepsSoFar : 492256
# TimeSinceStart : 201.9162917137146
# Training Loss : 129.63290405273438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 49 ************
#
# Collecting data to be used for training...
# At timestep:     10047 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 160.6864013671875
# Eval_StdReturn : 5.394297122955322
# Eval_MaxReturn : 170.73434448242188
# Eval_MinReturn : 149.89324951171875
# Eval_AverageEpLen : 84.25
# Train_AverageReturn : 159.18431091308594
# Train_StdReturn : 6.13748836517334
# Train_MaxReturn : 168.59255981445312
# Train_MinReturn : 123.52387237548828
# Train_AverageEpLen : 83.725
# Train_EnvstepsSoFar : 502303
# TimeSinceStart : 206.0882112979889
# Training Loss : 129.206298828125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 50 ************
#
# Collecting data to be used for training...
# At timestep:     10055 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 164.00601196289062
# Eval_StdReturn : 2.9939730167388916
# Eval_MaxReturn : 168.014404296875
# Eval_MinReturn : 157.91049194335938
# Eval_AverageEpLen : 84.66666666666667
# Train_AverageReturn : 160.40708923339844
# Train_StdReturn : 5.617321014404297
# Train_MaxReturn : 172.47332763671875
# Train_MinReturn : 143.56239318847656
# Train_AverageEpLen : 83.79166666666667
# Train_EnvstepsSoFar : 512358
# TimeSinceStart : 210.19527649879456
# Training Loss : 130.7919921875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 51 ************
#
# Collecting data to be used for training...
# At timestep:     10020 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 163.42027282714844
# Eval_StdReturn : 6.2832794189453125
# Eval_MaxReturn : 172.0360107421875
# Eval_MinReturn : 150.08152770996094
# Eval_AverageEpLen : 83.5
# Train_AverageReturn : 161.76956176757812
# Train_StdReturn : 6.093257427215576
# Train_MaxReturn : 175.08819580078125
# Train_MinReturn : 140.55712890625
# Train_AverageEpLen : 83.5
# Train_EnvstepsSoFar : 522378
# TimeSinceStart : 214.29236030578613
# Training Loss : 133.12716674804688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 52 ************
#
# Collecting data to be used for training...
# At timestep:     10073 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 157.44468688964844
# Eval_StdReturn : 16.41434669494629
# Eval_MaxReturn : 181.7279815673828
# Eval_MinReturn : 130.6550750732422
# Eval_AverageEpLen : 79.0
# Train_AverageReturn : 166.52366638183594
# Train_StdReturn : 5.223931312561035
# Train_MaxReturn : 188.42861938476562
# Train_MinReturn : 151.1299285888672
# Train_AverageEpLen : 83.94166666666666
# Train_EnvstepsSoFar : 532451
# TimeSinceStart : 218.41774106025696
# Training Loss : 136.74942016601562
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 53 ************
#
# Collecting data to be used for training...
# At timestep:     10045 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 112.3839340209961
# Eval_StdReturn : 25.5761775970459
# Eval_MaxReturn : 146.20074462890625
# Eval_MinReturn : 66.97029113769531
# Eval_AverageEpLen : 60.411764705882355
# Train_AverageReturn : 154.62124633789062
# Train_StdReturn : 23.066173553466797
# Train_MaxReturn : 190.2095489501953
# Train_MinReturn : 77.70006561279297
# Train_AverageEpLen : 77.86821705426357
# Train_EnvstepsSoFar : 542496
# TimeSinceStart : 222.55509519577026
# Training Loss : 134.95216369628906
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 54 ************
#
# Collecting data to be used for training...
# At timestep:     10009 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 139.9556121826172
# Eval_StdReturn : 28.10193634033203
# Eval_MaxReturn : 172.17654418945312
# Eval_MinReturn : 79.48255920410156
# Eval_AverageEpLen : 71.85714285714286
# Train_AverageReturn : 121.56352233886719
# Train_StdReturn : 31.347272872924805
# Train_MaxReturn : 178.75997924804688
# Train_MinReturn : 49.685935974121094
# Train_AverageEpLen : 63.7515923566879
# Train_EnvstepsSoFar : 552505
# TimeSinceStart : 226.60305881500244
# Training Loss : 121.99620056152344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 55 ************
#
# Collecting data to be used for training...
# At timestep:     10043 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 158.06109619140625
# Eval_StdReturn : 13.909029006958008
# Eval_MaxReturn : 173.5242156982422
# Eval_MinReturn : 120.47148132324219
# Eval_AverageEpLen : 80.61538461538461
# Train_AverageReturn : 134.47265625
# Train_StdReturn : 29.54437828063965
# Train_MaxReturn : 178.2360076904297
# Train_MinReturn : 62.28641891479492
# Train_AverageEpLen : 69.74305555555556
# Train_EnvstepsSoFar : 562548
# TimeSinceStart : 230.72830986976624
# Training Loss : 126.58821105957031
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 56 ************
#
# Collecting data to be used for training...
# At timestep:     10044 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 162.48114013671875
# Eval_StdReturn : 6.323020935058594
# Eval_MaxReturn : 168.4224853515625
# Eval_MinReturn : 145.90936279296875
# Eval_AverageEpLen : 83.38461538461539
# Train_AverageReturn : 161.46043395996094
# Train_StdReturn : 14.203215599060059
# Train_MaxReturn : 181.75875854492188
# Train_MinReturn : 97.11221313476562
# Train_AverageEpLen : 81.65853658536585
# Train_EnvstepsSoFar : 572592
# TimeSinceStart : 234.8517713546753
# Training Loss : 135.6805877685547
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 57 ************
#
# Collecting data to be used for training...
# At timestep:     10031 / 10000195 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 130.08775329589844
# Eval_StdReturn : 23.585460662841797
# Eval_MaxReturn : 163.9867706298828
# Eval_MinReturn : 103.609375
# Eval_AverageEpLen : 72.14285714285714
# Train_AverageReturn : 161.12039184570312
# Train_StdReturn : 5.9546003341674805
# Train_MaxReturn : 173.72911071777344
# Train_MinReturn : 143.1514434814453
# Train_AverageEpLen : 83.59166666666667
# Train_EnvstepsSoFar : 582623
# TimeSinceStart : 238.8895378112793
# Training Loss : 132.94285583496094
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 58 ************
#
# Collecting data to be used for training...
# At timestep:     10047 / 10000132 / 100006676 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 126.30890655517578
# Eval_StdReturn : 23.179046630859375
# Eval_MaxReturn : 162.03077697753906
# Eval_MinReturn : 87.10437774658203
# Eval_AverageEpLen : 70.26666666666667
# Train_AverageReturn : 132.49607849121094
# Train_StdReturn : 25.039819717407227
# Train_MaxReturn : 173.65843200683594
# Train_MinReturn : 68.97811889648438
# Train_AverageEpLen : 72.80434782608695
# Train_EnvstepsSoFar : 592670
# TimeSinceStart : 242.9525625705719
# Training Loss : 119.8216781616211
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 59 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 157.38487243652344
# Eval_StdReturn : 11.603043556213379
# Eval_MaxReturn : 167.19544982910156
# Eval_MinReturn : 130.7833709716797
# Eval_AverageEpLen : 83.23076923076923
# Train_AverageReturn : 128.4490966796875
# Train_StdReturn : 25.765369415283203
# Train_MaxReturn : 165.99403381347656
# Train_MinReturn : 63.1456413269043
# Train_AverageEpLen : 71.1063829787234
# Train_EnvstepsSoFar : 602696
# TimeSinceStart : 247.00864934921265
# Training Loss : 117.62327575683594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 60 ************
#
# Collecting data to be used for training...
# At timestep:     10036 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 165.2706756591797
# Eval_StdReturn : 4.512200832366943
# Eval_MaxReturn : 171.53843688964844
# Eval_MinReturn : 153.8861083984375
# Eval_AverageEpLen : 85.33333333333333
# Train_AverageReturn : 157.87562561035156
# Train_StdReturn : 11.545751571655273
# Train_MaxReturn : 170.25350952148438
# Train_MinReturn : 111.12437438964844
# Train_AverageEpLen : 83.63333333333334
# Train_EnvstepsSoFar : 612732
# TimeSinceStart : 251.09920001029968
# Training Loss : 129.6580047607422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 61 ************
#
# Collecting data to be used for training...
# At timestep:     10082 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.89686584472656
# Eval_StdReturn : 3.6711528301239014
# Eval_MaxReturn : 173.2344512939453
# Eval_MinReturn : 161.35272216796875
# Eval_AverageEpLen : 85.5
# Train_AverageReturn : 164.9949188232422
# Train_StdReturn : 4.8719987869262695
# Train_MaxReturn : 172.83721923828125
# Train_MinReturn : 143.5275115966797
# Train_AverageEpLen : 85.44067796610169
# Train_EnvstepsSoFar : 622814
# TimeSinceStart : 255.23892760276794
# Training Loss : 134.1962432861328
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 62 ************
#
# Collecting data to be used for training...
# At timestep:     10028 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.4259796142578
# Eval_StdReturn : 15.915050506591797
# Eval_MaxReturn : 177.42213439941406
# Eval_MinReturn : 119.86872863769531
# Eval_AverageEpLen : 76.71428571428571
# Train_AverageReturn : 166.5369873046875
# Train_StdReturn : 7.361189365386963
# Train_MaxReturn : 175.82696533203125
# Train_MinReturn : 120.07424926757812
# Train_AverageEpLen : 84.98305084745763
# Train_EnvstepsSoFar : 632842
# TimeSinceStart : 259.396603345871
# Training Loss : 136.50189208984375
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 9.657980918884277
# Done logging...
#
#
#
#
# ********** Iteration 63 ************
#
# Collecting data to be used for training...
# At timestep:     10052 / 10000
# ...
# Training Loss : 127.27127838134766
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 79 ************
#
# Collecting data to be used for training...
# At timestep:     10044 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 163.5855712890625
# Eval_StdReturn : 6.584655284881592
# Eval_MaxReturn : 170.34393310546875
# Eval_MinReturn : 147.8828582763672
# Eval_AverageEpLen : 84.08333333333333
# Train_AverageReturn : 153.47573852539062
# Train_StdReturn : 14.517644882202148
# Train_MaxReturn : 172.9756622314453
# Train_MinReturn : 114.47418975830078
# Train_AverageEpLen : 80.352
# Train_EnvstepsSoFar : 803473
# TimeSinceStart : 332.49139285087585
# Training Loss : 125.90255737304688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 80 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.54539489746094
# Eval_StdReturn : 6.100388050079346
# Eval_MaxReturn : 173.4226531982422
# Eval_MinReturn : 154.67495727539062
# Eval_AverageEpLen : 85.58333333333333
# Train_AverageReturn : 158.38685607910156
# Train_StdReturn : 12.984870910644531
# Train_MaxReturn : 175.68894958496094
# Train_MinReturn : 120.34635925292969
# Train_AverageEpLen : 82.09016393442623
# Train_EnvstepsSoFar : 813488
# TimeSinceStart : 336.72868394851685
# Training Loss : 128.88778686523438
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 81 ************
#
# Collecting data to be used for training...
# At timestep:     10002 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 166.17286682128906
# Eval_StdReturn : 9.191998481750488
# Eval_MaxReturn : 173.95571899414062
# Eval_MinReturn : 142.2412567138672
# Eval_AverageEpLen : 85.5
# Train_AverageReturn : 166.4130096435547
# Train_StdReturn : 6.3158440589904785
# Train_MaxReturn : 175.0166473388672
# Train_MinReturn : 140.1812744140625
# Train_AverageEpLen : 85.48717948717949
# Train_EnvstepsSoFar : 823490
# TimeSinceStart : 340.88630986213684
# Training Loss : 130.90728759765625
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 82 ************
#
# Collecting data to be used for training...
# At timestep:     10042 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 167.34820556640625
# Eval_StdReturn : 6.897635459899902
# Eval_MaxReturn : 172.21653747558594
# Eval_MinReturn : 147.75082397460938
# Eval_AverageEpLen : 85.58333333333333
# Train_AverageReturn : 167.62033081054688
# Train_StdReturn : 6.631587982177734
# Train_MaxReturn : 175.84335327148438
# Train_MinReturn : 143.66932678222656
# Train_AverageEpLen : 85.82905982905983
# Train_EnvstepsSoFar : 833532
# TimeSinceStart : 345.0610933303833
# Training Loss : 130.87998962402344
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 83 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 164.50396728515625
# Eval_StdReturn : 7.784155368804932
# Eval_MaxReturn : 174.2543487548828
# Eval_MinReturn : 146.58213806152344
# Eval_AverageEpLen : 84.33333333333333
# Train_AverageReturn : 167.17396545410156
# Train_StdReturn : 5.666919231414795
# Train_MaxReturn : 175.93301391601562
# Train_MinReturn : 139.63336181640625
# Train_AverageEpLen : 85.78632478632478
# Train_EnvstepsSoFar : 843569
# TimeSinceStart : 349.234482049942
# Training Loss : 130.6165008544922
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 84 ************
#
# Collecting data to be used for training...
# At timestep:     10071 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 164.1438751220703
# Eval_StdReturn : 8.241191864013672
# Eval_MaxReturn : 174.20065307617188
# Eval_MinReturn : 151.14942932128906
# Eval_AverageEpLen : 84.41666666666667
# Train_AverageReturn : 164.59068298339844
# Train_StdReturn : 9.397290229797363
# Train_MaxReturn : 174.8345947265625
# Train_MinReturn : 131.27085876464844
# Train_AverageEpLen : 84.63025210084034
# Train_EnvstepsSoFar : 853640
# TimeSinceStart : 353.54120087623596
# Training Loss : 129.8422393798828
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 85 ************
#
# Collecting data to be used for training...
# At timestep:     10013 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 146.96588134765625
# Eval_StdReturn : 13.12193489074707
# Eval_MaxReturn : 169.91397094726562
# Eval_MinReturn : 116.69379425048828
# Eval_AverageEpLen : 77.6923076923077
# Train_AverageReturn : 162.15211486816406
# Train_StdReturn : 9.983572006225586
# Train_MaxReturn : 175.71661376953125
# Train_MinReturn : 128.60980224609375
# Train_AverageEpLen : 83.44166666666666
# Train_EnvstepsSoFar : 863653
# TimeSinceStart : 357.7601716518402
# Training Loss : 129.27566528320312
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 86 ************
#
# Collecting data to be used for training...
# At timestep:     10040 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 132.54501342773438
# Eval_StdReturn : 14.194093704223633
# Eval_MaxReturn : 166.57240295410156
# Eval_MinReturn : 102.66777038574219
# Eval_AverageEpLen : 71.78571428571429
# Train_AverageReturn : 145.94078063964844
# Train_StdReturn : 12.6659574508667
# Train_MaxReturn : 172.06851196289062
# Train_MinReturn : 104.7107162475586
# Train_AverageEpLen : 77.23076923076923
# Train_EnvstepsSoFar : 873693
# TimeSinceStart : 361.9357125759125
# Training Loss : 122.95326232910156
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 87 ************
#
# Collecting data to be used for training...
# At timestep:     10023 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 119.77349853515625
# Eval_StdReturn : 14.428714752197266
# Eval_MaxReturn : 149.3072509765625
# Eval_MinReturn : 98.4184799194336
# Eval_AverageEpLen : 66.0
# Train_AverageReturn : 131.8700714111328
# Train_StdReturn : 12.269133567810059
# Train_MaxReturn : 167.3498077392578
# Train_MinReturn : 101.66590881347656
# Train_AverageEpLen : 71.59285714285714
# Train_EnvstepsSoFar : 883716
# TimeSinceStart : 366.10427379608154
# Training Loss : 116.02047729492188
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 88 ************
#
# Collecting data to be used for training...
# At timestep:     10048 / 10000880 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 105.41059875488281
# Eval_StdReturn : 9.210980415344238
# Eval_MaxReturn : 124.59518432617188
# Eval_MinReturn : 91.7694091796875
# Eval_AverageEpLen : 58.94117647058823
# Train_AverageReturn : 119.46134948730469
# Train_StdReturn : 11.625903129577637
# Train_MaxReturn : 146.78375244140625
# Train_MinReturn : 88.25470733642578
# Train_AverageEpLen : 66.10526315789474
# Train_EnvstepsSoFar : 893764
# TimeSinceStart : 370.194216966629
# Training Loss : 110.57344818115234
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 89 ************
#
# Collecting data to be used for training...
# At timestep:     10050 / 1000010000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 100.69068908691406
# Eval_StdReturn : 10.000114440917969
# Eval_MaxReturn : 117.44479370117188
# Eval_MinReturn : 84.7907485961914
# Eval_AverageEpLen : 56.388888888888886
# Train_AverageReturn : 107.90986633300781
# Train_StdReturn : 12.085444450378418
# Train_MaxReturn : 143.0353240966797
# Train_MinReturn : 80.78990173339844
# Train_AverageEpLen : 60.17964071856287
# Train_EnvstepsSoFar : 903814
# TimeSinceStart : 374.2719044685364
# Training Loss : 106.79024505615234
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 90 ************
#
# Collecting data to be used for training...
# At timestep:     10026 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 104.42317962646484
# Eval_StdReturn : 8.827422142028809
# Eval_MaxReturn : 117.72826385498047
# Eval_MinReturn : 87.57310485839844
# Eval_AverageEpLen : 58.666666666666664
# Train_AverageReturn : 102.93025207519531
# Train_StdReturn : 11.444486618041992
# Train_MaxReturn : 132.53424072265625
# Train_MinReturn : 75.00878143310547
# Train_AverageEpLen : 57.62068965517241
# Train_EnvstepsSoFar : 913840
# TimeSinceStart : 378.33354210853577
# Training Loss : 104.42901611328125
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 91 ************
#
# Collecting data to be used for training...
# At timestep:     10037 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 99.03577423095703
# Eval_StdReturn : 12.112102508544922
# Eval_MaxReturn : 121.38004302978516
# Eval_MinReturn : 81.38028717041016
# Eval_AverageEpLen : 55.666666666666664
# Train_AverageReturn : 103.6775894165039
# Train_StdReturn : 11.11868667602539
# Train_MaxReturn : 133.32725524902344
# Train_MinReturn : 72.10552978515625
# Train_AverageEpLen : 58.017341040462426
# Train_EnvstepsSoFar : 923877
# TimeSinceStart : 382.48821926116943
# Training Loss : 104.5379867553711
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 92 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 94.215576171875
# Eval_StdReturn : 11.203170776367188
# Eval_MaxReturn : 113.86408233642578
# Eval_MinReturn : 73.54824829101562
# Eval_AverageEpLen : 52.8
# Train_AverageReturn : 100.08104705810547
# Train_StdReturn : 11.751420974731445
# Train_MaxReturn : 140.6046905517578
# Train_MinReturn : 75.0202407836914
# Train_AverageEpLen : 56.07821229050279
# Train_EnvstepsSoFar : 933915
# TimeSinceStart : 386.6134614944458
# Training Loss : 102.85794830322266
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 93 ************
#
# Collecting data to be used for training...
# At timestep:     10015 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.03173065185547
# Eval_StdReturn : 14.10984992980957
# Eval_MaxReturn : 120.96553039550781
# Eval_MinReturn : 62.158687591552734
# Eval_AverageEpLen : 51.75
# Train_AverageReturn : 95.51583099365234
# Train_StdReturn : 10.244404792785645
# Train_MaxReturn : 124.51206970214844
# Train_MinReturn : 71.50621032714844
# Train_AverageEpLen : 53.55614973262032
# Train_EnvstepsSoFar : 943930
# TimeSinceStart : 390.69210386276245
# Training Loss : 101.83562469482422
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 94 ************
#
# Collecting data to be used for training...
# At timestep:     10000 / 10000 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 92.80709838867188
# Eval_StdReturn : 10.635530471801758
# Eval_MaxReturn : 110.57533264160156
# Eval_MinReturn : 67.2857437133789
# Eval_AverageEpLen : 52.55
# Train_AverageReturn : 91.59337615966797
# Train_StdReturn : 9.645426750183105
# Train_MaxReturn : 119.52368927001953
# Train_MinReturn : 65.51972961425781
# Train_AverageEpLen : 51.54639175257732
# Train_EnvstepsSoFar : 953930
# TimeSinceStart : 394.8014371395111
# Training Loss : 99.9537124633789
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 95 ************
#
# Collecting data to be used for training...
# At timestep:     10007 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 95.11319732666016
# Eval_StdReturn : 12.971415519714355
# Eval_MaxReturn : 122.9452896118164
# Eval_MinReturn : 70.65412139892578
# Eval_AverageEpLen : 53.526315789473685
# Train_AverageReturn : 92.6014404296875
# Train_StdReturn : 11.64816951751709
# Train_MaxReturn : 125.81608581542969
# Train_MinReturn : 61.026004791259766
# Train_AverageEpLen : 52.119791666666664
# Train_EnvstepsSoFar : 963937
# TimeSinceStart : 398.83866000175476
# Training Loss : 99.72539520263672
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 96 ************
#
# Collecting data to be used for training...
# At timestep:     10017 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 103.20157623291016
# Eval_StdReturn : 18.70525360107422
# Eval_MaxReturn : 138.40826416015625
# Eval_MinReturn : 66.85740661621094
# Eval_AverageEpLen : 57.44444444444444
# Train_AverageReturn : 95.72611999511719
# Train_StdReturn : 13.595099449157715
# Train_MaxReturn : 132.37493896484375
# Train_MinReturn : 62.1855354309082
# Train_AverageEpLen : 53.854838709677416
# Train_EnvstepsSoFar : 973954
# TimeSinceStart : 402.89717411994934
# Training Loss : 102.04917907714844
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 97 ************
#
# Collecting data to be used for training...
# At timestep:     10018 / 100000000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 129.99459838867188
# Eval_StdReturn : 15.037461280822754
# Eval_MaxReturn : 156.58880615234375
# Eval_MinReturn : 108.52457427978516
# Eval_AverageEpLen : 70.2
# Train_AverageReturn : 109.54354095458984
# Train_StdReturn : 14.286799430847168
# Train_MaxReturn : 136.31103515625
# Train_MinReturn : 63.37034606933594
# Train_AverageEpLen : 61.08536585365854
# Train_EnvstepsSoFar : 983972
# TimeSinceStart : 406.8938229084015
# Training Loss : 107.225341796875
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 98 ************
#
# Collecting data to be used for training...
# At timestep:     10051 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 156.55877685546875
# Eval_StdReturn : 13.30778980255127
# Eval_MaxReturn : 170.8872833251953
# Eval_MinReturn : 128.9486541748047
# Eval_AverageEpLen : 81.3076923076923
# Train_AverageReturn : 129.5167999267578
# Train_StdReturn : 15.260693550109863
# Train_MaxReturn : 164.87176513671875
# Train_MinReturn : 74.13948059082031
# Train_AverageEpLen : 70.2867132867133
# Train_EnvstepsSoFar : 994023
# TimeSinceStart : 411.0074088573456
# Training Loss : 115.08860778808594
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...
#
#
#
#
# ********** Iteration 99 ************
#
# Collecting data to be used for training...
# At timestep:     10038 / 10000
# Training agent...
#
# Beginning logging procedure...
#
# Collecting data for eval...
# Eval_AverageReturn : 168.698974609375
# Eval_StdReturn : 3.771549701690674
# Eval_MaxReturn : 175.447998046875
# Eval_MinReturn : 161.60557556152344
# Eval_AverageEpLen : 86.25
# Train_AverageReturn : 155.81922912597656
# Train_StdReturn : 14.353776931762695
# Train_MaxReturn : 173.41403198242188
# Train_MinReturn : 82.28414154052734
# Train_AverageEpLen : 80.95161290322581
# Train_EnvstepsSoFar : 1004061
# TimeSinceStart : 415.21861267089844
# Training Loss : 125.74093627929688
# Baseline Loss : 0
# Initial_DataCollection_AverageReturn : 18.039928436279297
# Done logging...

# %%
### Visualize Policy Gradient results on Hopper
# !fuser 6006/tcp -k #clear the port 
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
# Out:
# 6006/tcp:            321024
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-f2e44eeccfc30a37" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f2e44eeccfc30a37");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Variance Reduction with a Value Function Baseline
# We can further reduce the policy gradient variance by including state-dependent baselines. In this section, we will train a value function network to predict the value of the policy at a state, then use the value function as a baseline by subtracting it from our reward-to-go estimate.
#
# Implement the value function baseline loss in the update method of the MLPPolicyPG class in <code>policies/MLP_policy.py</code>.

# %%
# Test value function gradient
torch.manual_seed(0)
ac_dim = 2
ob_dim = 3
batch_size = 5

policy = MLPPolicyPG(
            ac_dim=ac_dim,
            ob_dim=ob_dim,
            n_layers=1,
            size=2,
            learning_rate=0.25,
            nn_baseline=True)

np.random.seed(0)
obs = np.random.normal(size=(batch_size, ob_dim))
acts = np.random.normal(size=(batch_size, ac_dim))
advs = 1000 * np.random.normal(size=(batch_size,))
qvals = advs

first_weight_before = np.array(ptu.to_numpy(next(policy.baseline.parameters())))
print("Weight before update", first_weight_before)

for i in range(5):
    loss = policy.update(obs, acts, advs, qvals=qvals)['Baseline Loss']

print(loss)
expected_loss = 0.925361
loss_error = rel_error(loss, expected_loss)
print("Loss Error", loss_error, "should be on the order of 1e-6 or lower")

first_weight_after = ptu.to_numpy(next(policy.baseline.parameters()))
print('Weight after update', first_weight_after)

weight_change = first_weight_after - first_weight_before
print("Change in weights", weight_change)

expected_change = np.array([[ 0.38988823,  0.70297027,  0.2609921 ],
                            [-1.0340402,  -0.84166795,  0.7254925 ]])
updated_weight_error = rel_error(weight_change, expected_change)
print("Weight Update Error", updated_weight_error, "should be on the order of 1e-6 or lower")

# %% [markdown]
# In the estimate_advantage function in <code>agents/pg_agent.py</code>, fill out the advantage estimate using the baseline and test your implementation below.

# %%
### Test return computation
pg_args = dict(pg_base_args_dict)

env_str = 'CartPole'
pg_args['env_name'] = '{}-v0'.format(env_str)
pg_args['nn_baseline'] = True
pgtrainer = PG_Trainer(pg_args)
pgagent = pgtrainer.rl_trainer.agent

obs_dim = 4
N = 10
np.random.seed(0)
obs = np.random.normal(size=(N, obs_dim))
qs = np.random.normal(size=N)

baseline_advantages = pgagent.estimate_advantage(obs, qs)
expected_advantages = np.array([-0.44662586, -0.89629588, -1.14574752,  2.43957172, -0.06601728,
       -0.00501807, -0.74720337,  1.27468092, -1.20184486,  0.25312274])

advantage_error = rel_error(expected_advantages, baseline_advantages)
print("Advantage error", advantage_error, "should be on the order of 1e-6 or lower")

# %% [markdown]
# ## Train your policies!
# In this section, we will train our policies using the reward-to-go estimator and learning a value function baseline. On Hopper, you should see your methods get over 300 rewards consistently, and sometimes over 400. Returns will tend to oscillate during training. You should also see that using a value function baseline greatly improves performance over our earlier experiments without it.

# %%
pg_args = dict(pg_base_args_dict)

env_str = 'Hopper'
pg_args['env_name'] = '{}-v2'.format(env_str)
pg_args['learning_rate'] = 0.01
pg_args['reward_to_go'] = True
pg_args['nn_baseline'] = True
pg_args['batch_size'] = 10000
pg_args['train_batch_size'] = 10000
pg_args['n_iter'] = 100

# Delete all previous logs
remove_folder('logs/policy_gradient/{}/with_baseline/'.format(env_str))

for seed in range(3):
    print("Running policy gradient experiment with seed", seed)
    pg_args['seed'] = seed
    pg_args['logdir'] = 'logs/policy_gradient/{}/with_baseline/seed{}'.format(env_str, seed)
    pgtrainer = PG_Trainer(pg_args)
    pgtrainer.run_training_loop()

# %%
# Plot learning curves
### Visualize Policy Gradient results on Hopper
# %load_ext tensorboard
# %tensorboard --logdir logs/policy_gradient/Hopper
